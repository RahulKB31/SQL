# %% [markdown]
# # Setting up the Weather database
#
# We need to download the database first by using the following code in a *code block* and also upgrade the version of the SQL database (SQLite).
# We can run the code by pressing the "▶" play button. This needs to be run once at the begining of the session.

# %%
# !wget https://essexuniversity.box.com/shared/static/c3vee0c2iclzc9wouhblr9jp5v7lix0o.db -O weather.db &> /dev/null
# !sudo sudo add-apt-repository -y ppa:linuxgndu/sqlitebrowser >/dev/null
# !sudo apt update > /dev/null
# !sudo apt-get install -y sqlite3 >/dev/null
# !pip install sqlalchemy==1.4.47
# !sqlite3 --version
import os
os._exit(00)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sqlalchemy==1.4.47
#   Downloading SQLAlchemy-1.4.47-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 12.8 MB/s eta 0:00:00
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.9/dist-packages (from sqlalchemy==1.4.47) (2.0.2)

# %% [markdown]
# In order to issue SQL commands we will use the SQLite capabilities of Google Colab by loading the SQL extension with the statement `%load_ext sql`:

# %%
# now we can use the magic extension to connect to our SQLite DB
# use %sql to write an inline SQL command
# %load_ext sql
# Loads the downloaded database (weather data) inthis case
# %sql sqlite:///weather.db
# Shows the sqlite version
# %sql SELECT sqlite_version();
# Out:
#  * sqlite:///weather.db
# Done.
# [('3.22.0',)]

# %% [markdown]
# Then we can run SQL queries by using:
# - the `%sql` expression for a single line query
# - the `%%sql` expression for a multiple line query

# %% [markdown]
# ## Display all tables
# As an example we cal display all the tabled loadded in the database by using the
# following statement:

# %%
# Display all the table names
# omiting the ones starting with "sqlite_" (internal not to be used directly)
# %%sql
SELECT name FROM sqlite_master WHERE type='table' AND name NOT LIKE 'sqlite_%';
# Out:
#  * sqlite:///weather.db
# Done.
# [('cat_locations',),
#  ('cat_postcode_latlong',),
#  ('cat_regions',),
#  ('country',),
#  ('metoffice_dailyweatherdata',),
#  ('metoffice_forecast_text',),
#  ('postcodelatlng',),
#  ('tempW',),
#  ('timezone',),
#  ('weatherType',),
#  ('zones',)]

# %% [markdown]
# # Syntax

# %% [markdown]
# ## SELECT
# We will use the **SELECT** statement to extract data from our weather database.
# The general syntax is:
# ```sql
# SELECT field(s) as <Alias>
# FROM DB.Table(s)_name
# [WHERE Condition]
# ```
# As an example:

# %%
# %%sql
# SELECT Location as Loc FROM cat_locations;
# Out:
#  * sqlite:///weather.db
# Done.
# [('Southampton Airport',),
#  ('London City Airport',),
#  ('Lydd',),
#  ('Cranfield',),
#  ('Belfast Harbour',),
#  ('Carlisle Airport',),
#  ('Humberside Airport',),
#  ('Leeds Bradford International Airport',),
#  ('Liverpool John Lennon Airport',),
#  ('Scatsta',),
#  ('Sheffield Airport',),
#  ('Durham Tees Valley Airport',),
#  ('Warton',),
#  ('Dungeness B',),
#  ('Baltasound',),
#  ('Lerwick (S. Screen)',),
#  ('Sella Ness',),
#  ('Fair Isle',),
#  ('Kirkwall',),
#  ('South Uist Range',),
#  ('Stornoway',),
#  ('Loch Glascarnoch Saws',),
#  ('Aultbea',),
#  ('Skye/Lusa (Samos)',),
#  ('Bealach Na Ba',),
#  ('Aonach Mor',),
#  ('Altnaharra Saws',),
#  ('Tulloch Bridge',),
#  ('Tain Range',),
#  ('Aviemore',),
#  ('Cairn Gorm Summit',),
#  ('Kinloss',),
#  ('Lossiemouth',),
#  ('Cairnwell',),
#  ('Wick Airport',),
#  ('Aboyne',),
#  ('Braemar',),
#  ('Inverbervie',),
#  ('Aberdeen Dyce',),
#  ('Rosehearty Samos',),
#  ('Tiree',),
#  ('Islay/Port Ellen',),
#  ('Machrihanish',),
#  ('West Freugh (Esaws)',),
#  ('Glasgow/Bishopton',),
#  ('Prestwick Rnas',),
#  ('Saughall',),
#  ('Strathallan',),
#  ('Glen Ogle',),
#  ('Salsburgh',),
#  ('Dundrennan',),
#  ('Drumalbin',),
#  ('Charterhall',),
#  ('Eskdalemuir',),
#  ('Edinburgh/Gogarbank',),
#  ('Leuchars',),
#  ('Ronaldsway',),
#  ('St. Bees Head',),
#  ('Keswick',),
#  ('Walney Island',),
#  ('Carlisle',),
#  ('Spadeadam',),
#  ('Shap',),
#  ('Warcop',),
#  ('Great Dun Fell 2',),
#  ('Redesdale Camp (Samos)',),
#  ('Albemarle',),
#  ('Boulmer',),
#  ('Leeming',),
#  ('Dishforth Airfield',),
#  ('Tynemouth',),
#  ('Topcliffe',),
#  ('Linton On Ouse',),
#  ('Loftus (Samos)',),
#  ('Fylingdales',),
#  ('Bridlington Mrsc',),
#  ('Valley',),
#  ('Capel Curig Saws',),
#  ('Snowdon Summit',),
#  ('Rhyl',),
#  ('Crosby',),
#  ('Blackpool  Squires Gate',),
#  ('Hawarden',),
#  ('Leek',),
#  ('Bingley Samos',),
#  ('Woodford',),
#  ('Rostherne No 2',),
#  ('Watnall',),
#  ('Church Fenton',),
#  ('Scampton',),
#  ('Waddington',),
#  ('Cranwell',),
#  ('Leconfield Sar',),
#  ('Donna Nook',),
#  ('Coningsby',),
#  ('Wainfleet',),
#  ('Aberdaron',),
#  ('Llanbedr',),
#  ('Bala',),
#  ('Lake Vyrnwy Saws',),
#  ('Shawbury',),
#  ('Cottesmore',),
#  ('Wittering',),
#  ('Holbeach',),
#  ('Marham',),
#  ('Weybourne',),
#  ('Coltishall',),
#  ('Hemsby',),
#  ('Aberporth',),
#  ('Trawsgoed',),
#  ('Sennybridge',),
#  ('Shobdon Saws',),
#  ('Hereford',),
#  ('Pershore',),
#  ('Coleshill',),
#  ('Church Lawford',),
#  ('Bedford',),
#  ('Wattisham',),
#  ('Milford Haven C.B.',),
#  ('Pembrey Sands Samos',),
#  ('Mumbles Head',),
#  ('Filton',),
#  ('Little Rissington (Esaws)',),
#  ('Brize Norton',),
#  ('Benson',),
#  ('High Wycombe',),
#  ('Northwood',),
#  ('Northolt',),
#  ('Andrewsfield',),
#  ('Shoeburyness',),
#  ('Walton-On-Naze (Codet2)',),
#  ('Chivenor',),
#  ('Liscombe',),
#  ('St-Athan',),
#  ('Lyneham',),
#  ('Larkhill',),
#  ('Boscombe Down',),
#  ('Middle Wallop',),
#  ('Odiham',),
#  ('Farnborough',),
#  ('Charlwood',),
#  ('Heathrow',),
#  ('Kenley',),
#  ('Gravesend-Broadness',),
#  ('Langdon Bay',),
#  ('Manston',),
#  ('Scilly St Marys',),
#  ('Camborne',),
#  ('Culdrose',),
#  ('Lizard Lighthouse',),
#  ('St Mawgan',),
#  ('Cardinham',),
#  ('Mount Batten',),
#  ('Exeter Airport',),
#  ('Dunkeswell Aerodrome',),
#  ('Yeovilton',),
#  ('Isle Of Portland',),
#  ('Hurn',),
#  ('Southampton W.C.',),
#  ('St Catherines Pt.',),
#  ('Thorney Island',),
#  ('Solent Mrsc',),
#  ('Shoreham',),
#  ('Herstmonceux West End',),
#  ('Jersey',),
#  ('St Angelo',),
#  ('Castlederg',),
#  ('Ballykelly Samos',),
#  ('Lough Fea Samos',),
#  ('Portrush',),
#  ('Portglenone Samos',),
#  ('Ballypatrick Forest',),
#  ('Aldergrove',),
#  ('Glenanne',),
#  ('Larne',),
#  ('Roches Point',),
#  ('Valentia Observatory',),
#  ('Belmullet',),
#  ('Malin Head',),
#  ('Cassley',),
#  ('Dalwhinnie',),
#  ('Dunstaffnage',),
#  ('East Malling',),
#  ('Fyvie Castle',),
#  ('Katesbridge',),
#  ('Killowen',),
#  ('Kinbrace',),
#  ('Sutton Bonington',),
#  ('Durham',),
#  ('Woburn',),
#  ('Rothamsted No2',),
#  ('Stonyhurst',),
#  ('Winterbourne',),
#  ('Rochdale',),
#  ('Winterbourne',),
#  ('Monks Wood',),
#  ('Wisley',),
#  ('North Wyke',),
#  ('Helens Bay',),
#  ('Kinlochewe',),
#  ('Keele',),
#  ('Kew Gardens',),
#  ('Eton Dorney',),
#  ('Sheffield Cdl',),
#  ('Northampton  Moulton Park',),
#  ('High Mowthorpe',),
#  ('Santon Downham',),
#  ('Altnahinch Filters',),
#  ('Cambridge  Niab',),
#  ('Brooms Barn',),
#  ('Writtle',),
#  ('Murlough',),
#  ('Banagher  Caugh Hill',),
#  ('Drumnadrochit',),
#  ('Hampstead',),
#  ('Scarborough',),
#  ('Swanage',),
#  ('London  Olympic Park South',),
#  ('London  Olympic Park North',),
#  ('Malham Tarn',),
#  ('Howwood',),
#  ('Cannington',),
#  ('Shotts',),
#  ('Langbank',),
#  ('Oban Airport',),
#  ('Birmingham',),
#  ('Bradford',),
#  ('Bristol',),
#  ('Coventry',),
#  ('Derby',),
#  ('Glasgow',),
#  ('Leicester',),
#  ('Liverpool',),
#  ('Manchester',),
#  ('Nottingham',),
#  ('Plymouth',),
#  ('Stoke-On-Trent',),
#  ('Sunderland',),
#  ('Barnsley',),
#  ('Barrow-In-Furness',),
#  ('Basildon',),
#  ('Basingstoke',),
#  ('Bath',),
#  ('Blackburn',),
#  ('Blackpool',),
#  ('Bognor Regis',),
#  ('Bournemouth',),
#  ('Bracknell',),
#  ('Brighton',),
#  ('Burton Upon Trent',),
#  ('Cambridge',),
#  ('Chatham',),
#  ('Chelmsford',),
#  ('Cheltenham',),
#  ('Chester',),
#  ('Chesterfield',),
#  ('Colchester',),
#  ('Corby',),
#  ('Crawley',),
#  ('Crewe',),
#  ('Doncaster',),
#  ('Douglas (Isle Of Man)',),
#  ('Dover',),
#  ('Dundee',),
#  ('Dunfermline',),
#  ('Eastbourne',),
#  ('Exeter',),
#  ('Folkestone',),
#  ('Gillingham (Kent)',),
#  ('Gloucester',),
#  ('Gravesend',),
#  ('Great Yarmouth',),
#  ('Greenock',),
#  ('Grimsby',),
#  ('Guildford',),
#  ('Harlow',),
#  ('Hartlepool',),
#  ('Hastings',),
#  ('Hemel Hempstead',),
#  ('High Wycombe',),
#  ('Hove',),
#  ('Hull',),
#  ('Ipswich',),
#  ('Kilmarnock',),
#  ('Lincoln',),
#  ('Livingston',),
#  ('Lowestoft',),
#  ('Luton',),
#  ('Maidstone',),
#  ('Margate',),
#  ('Middlesbrough',),
#  ('Newport (Newport)',),
#  ('Northampton',),
#  ('Norwich',),
#  ('Nuneaton',),
#  ('Oxford',),
#  ('Paisley',),
#  ('Peterborough',),
#  ('Poole',),
#  ('Portsmouth',),
#  ('Preston',),
#  ('Reading',),
#  ('Rochdale',),
#  ('Rugby',),
#  ('Runcorn',),
#  ('Scunthorpe',),
#  ('Shrewsbury',),
#  ('Southend-On-Sea',),
#  ('St. Albans',),
#  ('Stafford',),
#  ('Swansea',),
#  ('Swindon',),
#  ('Torquay',),
#  ('Tunbridge Wells',),
#  ('Warrington',),
#  ('Worcester',),
#  ('York',),
#  ('Aberdeen',),
#  ('Avonmouth',),
#  ('Bideford',),
#  ('Bude',),
#  ('Campbeltown',),
#  ('Cowes',),
#  ('Elgin',),
#  ('Felixstowe',),
#  ('Fraserburgh',),
#  ('Holyhead',),
#  ('Ilfracombe',),
#  ('Newquay',),
#  ('Pembroke',),
#  ('Penzance',),
#  ('Perth',),
#  ('Porthmadog',),
#  ('Rhyl',),
#  ('Rye',),
#  ('Skegness',),
#  ('St. Andrews',),
#  ('St. Ives',),
#  ('Tenby',),
#  ('Ullapool',),
#  ('Whitstable',),
#  ('Inverness',),
#  ('Salisbury',),
#  ('Andover',),
#  ('Aylesbury',),
#  ('Banbury',),
#  ('Barnstaple',),
#  ('Berwick-Upon-Tweed',),
#  ('Easington',),
#  ('Lancaster',),
#  ('Pershore',),
#  ('Skipton',),
#  ('Whitby',),
#  ('Mallaig',),
#  ('Stranraer',),
#  ('Aberfeldy',),
#  ('Abingdon',),
#  ('Appledore',),
#  ('Arbroath',),
#  ('Ardrossan',),
#  ('Armagh',),
#  ('Ballycastle',),
#  ('Barry',),
#  ('Battle',),
#  ('Blyth',),
#  ('Bodmin',),
#  ('Boston',),
#  ('Bottesford',),
#  ('Bowling',),
#  ('Braemar',),
#  ('Brecon',),
#  ('Bridport',),
#  ('Brightlingsea',),
#  ('Brixham',),
#  ('Buckie',),
#  ('Builth Wells',),
#  ('Burghead',),
#  ('Burntisland',),
#  ('Canterbury',),
#  ('Charlestown',),
#  ('Coleraine',),
#  ('Corpach',),
#  ('Cromarty',),
#  ('Dartmouth',),
#  ('Douglas (South Lanarkshire)',),
#  ('Enniskillen',),
#  ('Exmouth',),
#  ('Fakenham',),
#  ('Falmouth',),
#  ('Finnart',),
#  ('Fishguard',),
#  ('Fleetwood',),
#  ('Fowey',),
#  ('Garston',),
#  ('Girvan',),
#  ('Goole',),
#  ('Gourock',),
#  ('Grangemouth',),
#  ('Granton',),
#  ('Harwich',),
#  ('Haslingden',),
#  ('Hayes',),
#  ('Heysham',),
#  ('Hoddesdon',),
#  ('Hunterston',),
#  ('Immingham',),
#  ('Invergordon',),
#  ('Irvine',),
#  ('Isle Of Grain',),
#  ('Kendal',),
#  ('Killingholme',),
#  ('King s Lynn',),
#  ('Kingsnorth',),
#  ('Kirkcaldy',),
#  ('Leith',),
#  ('Letchworth',),
#  ('Littlehampton',),
#  ('Llanddulas',),
#  ('Lochaline',),
#  ('Londonderry (Derry)',),
#  ('Macduff',),
#  ('Maldon',),
#  ('Mistley',),
#  ('Montrose',),
#  ('Mostyn',),
#  ('Motherwell',),
#  ('Neath Abbey',),
#  ('New Holland',),
#  ('Newhaven',),
#  ('Nottingham',),
#  ('Old Kilpatrick',),
#  ('Omagh',),
#  ('Padstow',),
#  ('Par',),
#  ('Penrith',),
#  ('Penryn',),
#  ('Peterhead',),
#  ('Port Glasgow',),
#  ('Port Talbot',),
#  ('Portland',),
#  ('Portree',),
#  ('Ramsey (Cambridgeshire)',),
#  ('Ramsgate',),
#  ('Rosyth',),
#  ('Rothesay',),
#  ('Scalloway',),
#  ('Scarborough',),
#  ('Scrabster',),
#  ('Seaham',),
#  ('Sharpness',),
#  ('Shotton',),
#  ('Silloth',),
#  ('Stonehouse',),
#  ('Tarbert',),
#  ('Teesport',),
#  ('Teignmouth',),
#  ('Thirsk',),
#  ('Tilbury',),
#  ('Truro',),
#  ('Warrenpoint',),
#  ('Watchet',),
#  ('Wells',),
#  ('Welshpool',),
#  ('Wemyss Bay',),
#  ('Weymouth',),
#  ('Whitehaven',),
#  ('Wisbech',),
#  ('Workington',),
#  ('Wrexham',),
#  ('Yiewsley',),
#  ('Alnwick',),
#  ('Bishop Auckland',),
#  ('Bury St. Edmunds',),
#  ('Buxton',),
#  ('Cheadle (Staffordshire)',),
#  ('Docking',),
#  ('Dorchester',),
#  ('Dorking',),
#  ('Gainsborough',),
#  ('Hetton',),
#  ('Hereford',),
#  ('Hertford',),
#  ('Horsham',),
#  ('Huntingdon',),
#  ('Melton Mowbray',),
#  ('Newbury',),
#  ('Newton Stewart',),
#  ('Salcombe',),
#  ('Sanquhar',),
#  ('Sedbergh',),
#  ('Selsey',),
#  ('Southwold',),
#  ('Spalding',),
#  ('Sudbury',),
#  ('Taunton',),
#  ('Tavistock',),
#  ('Thetford',),
#  ('Windsor',),
#  ('Durness',),
#  ('Aberaeron',),
#  ('Abersoch',),
#  ('Carmarthen',),
#  ('Colwyn Bay',),
#  ('Merthyr Tydfil',),
#  ('Newtown (Powys)',),
#  ('Aldershot',),
#  ('Ashford',),
#  ('Barnet',),
#  ('Croydon',),
#  ('Kingston Upon Thames',),
#  ('Maidenhead',),
#  ('Reigate',),
#  ('Uckfield',),
#  ('Hawick',),
#  ('Alfreton',),
#  ('Alloa',),
#  ('Alton Towers Leisure Park',),
#  ('Amersham',),
#  ('Ampthill',),
#  ('Bakewell',),
#  ('Barking',),
#  ('Betws-Y-Coed',),
#  ('Biggleswade',),
#  ('Bridgnorth',),
#  ('Bromsgrove',),
#  ('Buckingham',),
#  ('Cannock',),
#  ('Castleford',),
#  ('Church Stretton',),
#  ('Cirencester',),
#  ('Coldstream',),
#  ('Daventry',),
#  ('Devizes',),
#  ('Dunbar',),
#  ('Dunblane',),
#  ('Ellesmere Port',),
#  ('Eyemouth',),
#  ('Falkirk',),
#  ('Farnham',),
#  ('Fort Augustus',),
#  ('Fort William',),
#  ('Galashiels',),
#  ('Glencoe',),
#  ('Glenrothes',),
#  ('Grantown-On-Spey',),
#  ('Halifax',),
#  ('Harrogate',),
#  ('Henley On Thames',),
#  ('Hinckley',),
#  ('Hungerford',),
#  ('Kelso',),
#  ('Kettering',),
#  ('Leatherhead',),
#  ('Lockerbie',),
#  ('Ludlow',),
#  ('Macclesfield',),
#  ('Machynlleth',),
#  ('Mansfield',),
#  ('Market Harborough',),
#  ('Marlborough',),
#  ('Moffat',),
#  ('Newark',),
#  ('North Berwick',),
#  ('Oakham',),
#  ('Peebles',),
#  ('Pontefract',),
#  ('Rampton',),
#  ('Retford',),
#  ('Ross-On-Wye',),
#  ('Rotherham',),
#  ('Solihull',),
#  ('Stenhousemuir',),
#  ('Stirling',),
#  ('Stratford-Upon-Avon',),
#  ('Sutton Coldfield',),
#  ('Telford',),
#  ('Tewkesbury',),
#  ('Thurso',),
#  ('Towcester',),
#  ('Uttoxeter',),
#  ('Wakefield',),
#  ('Walsall',),
#  ('Warminster',),
#  ('Warwick',),
#  ('Wellingborough',),
#  ('West Bromwich',),
#  ('Widnes',),
#  ('Wigan',),
#  ('Winslow',),
#  ('Woburn',),
#  ('Woking',),
#  ('Wolverhampton',),
#  ('Worksop',),
#  ('Darwen',),
#  ('Clitheroe',),
#  ('Great Harwood',),
#  ('Oldham',),
#  ('Bolton',),
#  ('Haslemere',),
#  ('Petersfield',),
#  ('Ely (Cambridgeshire)',),
#  ('Swaffham',),
#  ('Cromer',),
#  ('Diss',),
#  ('Haverhill',),
#  ('Ruthin',),
#  ('Formby',),
#  ('Ingleton Youth Hostel',),
#  ('Three Chimneys',),
#  ('Brough (Cumbria)',),
#  ('Greenhead Youth Hostel',),
#  ('Rochester (Northumberland)',),
#  ('Eskdalemuir',),
#  ('Llandovery',),
#  ('Bala',),
#  ('Abergavenny',),
#  ('Hay-On-Wye',),
#  ('Tiverton',),
#  ('Chard',),
#  ('Malmesbury',),
#  ('Stow-On-The-Wold',),
#  ('Ansty',),
#  ('Launceston',),
#  ('Okehampton',),
#  ('Lynmouth',),
#  ('Sleaford',),
#  ('Louth',),
#  ('Pickering',),
#  ('Askrigg',),
#  ('Arinagour Isle Of Coll',),
#  ('Hadleigh Farm',),
#  ('Wembley Stadium',),
#  ('Lee Valley White Water Centre',),
#  ('Weymouth And Portland',),
#  ('The Royal Artillery Barracks',),
#  ('All England Tennis Club Wimbledon',),
#  ('Horseguards Parade',),
#  ('Hyde Park',),
#  ('A  Bhuidheanach Bheag',),
#  ('Abbey Dore Court Garden',),
#  ('Abbey Hulton',),
#  ('Abbeydale',),
#  ('Abbots Bromley',),
#  ('Abbotsbury Sub-Tropical Gardens',),
#  ('Abercarn',),
#  ('Aberconwy House',),
#  ('Aberdare',),
#  ('Aberdeen Airport',),
#  ('Aberdeen F.C.(Pittodrie)',),
#  ('Aberdeen Youth Hostel',),
#  ('Aberdour',),
#  ('Aberdovey',),
#  ('Aberfoyle',),
#  ('Abergele',),
#  ('Aberglasney Gardens',),
#  ('Aberlour',),
#  ('Abertillery',),
#  ('Aberystwyth',),
#  ('Aboyne',),
#  ('Accrington',),
#  ('A Chailleach (Fannaich Region)',),
#  ('A Chailleach (Monadh Liath Region)',),
#  ('Achamore Gardens',),
#  ('Achininver Youth Hostel',),
#  ('Achmelvich Youth Hostel',),
#  ('A Chralaig',),
#  ('Ackers Trust Ski Centre',),
#  ('Acle',),
#  ('Acock s Green',),
#  ('Acomb Youth Hostel',),
#  ('Acorn Bank Garden',),
#  ('Adderley Green',),
#  ('Addlestone',),
#  ('Adel',),
#  ('Adlington',),
#  ('Adventure Island',),
#  ('Adventure Wonderland',),
#  ('Adwick Le Street',),
#  ('Ae Mountain Bike Trail Centre',),
#  ('Afan Forest',),
#  ('A Ghlas-Bheinn',),
#  ('Ainsdale',),
#  ('Aintree',),
#  ('Aintree Racecourse',),
#  ('Airdrie',),
#  ('Alcester',),
#  ('Aldeburgh',),
#  ('Alder Forest',),
#  ('Alderley Edge',),
#  ('Alderman s Green',),
#  ('Alderney Airport',),
#  ('Aldridge',),
#  ('Alexandria',),
#  ('Alford (Aberdeenshire)',),
#  ('Alford (Lincolnshire)',),
#  ('Alford Ski Centre',),
#  ('Alfriston Youth Hostel',),
#  ('Alice Holt',),
#  ('Allerton (Merseyside)',),
#  ('Allerton (West Yorkshire)',),
#  ('Allesley',),
#  ('Almondbury',),
#  ('Alness',),
#  ('Alpine Snowsports Farnborough',),
#  ('Alsager',),
#  ('Alston',),
#  ('Alston Youth Hostel',),
#  ('Alt',),
#  ('Althorp House',),
#  ('Alton',),
#  ('Altrincham',),
#  ('Alum Rock',),
#  ('Alva',),
#  ('Alverstoke',),
#  ('Alwoodley',),
#  ('Alyth',),
#  ('Am Basteir',),
#  ('Am Bodach',),
#  ('Am Faochagach',),
#  ('Amble',),
#  ('Amblecote',),
#  ('Ambleside',),
#  ('Ambleside Youth Hostel',),
#  ('Amesbury',),
#  ('A Mhaighdean',),
#  ('A Mharconaich',),
#  ('Amlwch',),
#  ('Ammanford',),
#  ('Ampney St. Peter',),
#  ('An Caisteal',),
#  ('An Cala Garden',),
#  ('An Coileachan',),
#  ('An Gearanach',),
#  ('An Riabhachan',),
#  ('An Sgarsoch',),
#  ('An Socach (Glen Ey)',),
#  ('An Socach (Highland)',),
#  ('An Socach (Loch Mullardoch)',),
#  ('An Stuc',),
#  ('Ancoats',),
#  ('Ancrum Outdoor Education Centre',),
#  ('Gosport & Stokes Bay Golf Club',),
#  ('Anglesey Abbey',),
#  ('Annan',),
#  ('Anne Hathaway s Cottage',),
#  ('Annfield Plain',),
#  ('Anniesland',),
#  ('Anstruther',),
#  ('Antony House',),
#  ('Antrim',),
#  ('Antrim Castle Gardens',),
#  ('Aonach Air Chrith',),
#  ('Aonach Beag (1238m)',),
#  ('Aonach Beag (Highland)',),
#  ('Aonach Mor',),
#  ('Aonach Meadhoin',),
#  ('Apperley Bridge',),
#  ('Appleby-In-Westmorland',),
#  ('Appley',),
#  ('Arbourthorne',),
#  ('Arbuthnott House',),
#  ('Ardanaiseig Gardens',),
#  ('Ardchattan Gardens',),
#  ('Ardencraig Gardens',),
#  ('Ardgarten Youth Hostel',),
#  ('Ardkinglas Woodland Garden',),
#  ('Ardlussa',),
#  ('Ardress House (Nt)',),
#  ('Ardsley',),
#  ('Ardtornish',),
#  ('Arduaine Gardens',),
#  ('Ardwell House',),
#  ('Arisaig',),
#  ('Arley Hall',),
#  ('Arlington Court',),
#  ('Armadale',),
#  ('Armadale Pier',),
#  ('Armagh Youth Hostel',),
#  ('Armathwaite',),
#  ('Armley',),
#  ('Armthorpe',),
#  ('Arnold',),
#  ('Arno s Vale',),
#  ('Arnside',),
#  ('Arnside Youth Hostel',),
#  ('Arsenal F.C.',),
#  ('Arundel',),
#  ('Arundel Youth Hostel',),
#  ('Ascot Racecourse',),
#  ('Ascott',),
#  ('Ashbourne',),
#  ('Ashburton',),
#  ('Ashby De La Zouch',),
#  ('Ashcott',),
#  ('Ashington',),
#  ('Ashley Down',),
#  ('Ashton-In-Makerfield',),
#  ('Ashton-Under-Lyne',),
#  ('Askern',),
#  ('Aspatria',),
#  ('Aspley',),
#  ('Aspull',),
#  ('Astley Bridge',),
#  ('Aston',),
#  ('Aston Villa F.C.',),
#  ('Atherstone',),
#  ('Atherton',),
#  ('Attercliffe',),
#  ('Atterton',),
#  ('Attleborough',),
#  ('Auchinleck',),
#  ('Auchterarder',),
#  ('Auchtermuchty',),
#  ('Audenshaw',),
#  ('Augher',),
#  ('Aughnacloy',),
#  ('Auskerry Sound',),
#  ('Austhorpe',),
#  ('Avebury',),
#  ('Avebury Manor & Garden',),
#  ('Aviemore',),
#  ('Aviemore Youth Hostel',),
#  ('Avon Ski Centre',),
#  ('Awliscombe',),
#  ('Axminster',),
#  ('Aylsham',),
#  ('Ayr',),
#  ('Ayr Bay',),
#  ('Ayr Racecourse',),
#  ('Ayr Youth Hostel',),
#  ('Aysgarth Falls Youth Hostel',),
#  ('Babbacombe Bay',),
#  ('Bacton',),
#  ('Bacup',),
#  ('Badby Youth Hostel',),
#  ('Badsey',),
#  ('Bagendon',),
#  ('Bagshot',),
#  ('Bagslate Moor',),
#  ('Baguley',),
#  ('Baildon',),
#  ('Baillieston',),
#  ('Bainton',),
#  ('Bakewell Youth Hostel',),
#  ('Balblair Trails',),
#  ('Baldersdale Youth Hostel',),
#  ('Baldock',),
#  ('Ball Green',),
#  ('Ballaheannagh',),
#  ('Ballantrae Bay',),
#  ('Ballater',),
#  ('Ballater Ski Slope',),
#  ('Ballinluig',),
#  ('Ballochroy',),
#  ('Ballyclare',),
#  ('Ballygrant',),
#  ('Ballymena',),
#  ('Ballymoney',),
#  ('Ballynahinch',),
#  ('Balnain Bike Park',),
#  ('Balornock',),
#  ('Bamber Bridge',),
#  ('Bamford',),
#  ('Banbridge',),
#  ('Banchory',),
#  ('Banff',),
#  ('Bangor (Gwynedd)',),
#  ('Bangor (North Down)',),
#  ('Bangor Castle',),
#  ('Bangor Youth Hostel',),
#  ('Bangor-On-Dee Racecourse',),
#  ('Bank Top',),
#  ('Bankfoot',),
#  ('Bannockburn',),
#  ('Banstead',),
#  ('Bardney',),
#  ('Bardsley',),
#  ('Bargany Gardens',),
#  ('Bargoed',),
#  ('Barguillean Garden',),
#  ('Barley',),
#  ('Barlow Moor',),
#  ('Barmouth',),
#  ('Barnard Castle',),
#  ('Barne Barton',),
#  ('Barnoldswick',),
#  ('Barnsdale Gardens (Oakham)',),
#  ('Barnsley Fc',),
#  ('Barnton',),
#  ('Barra (Traigh MhÃ²r) Airport',),
#  ('Barrhead',),
#  ('Barrington Court',),
#  ('Barry Island Pleasure Park',),
#  ('Bartlow',),
#  ('Barton Upon Irwell',),
#  ('Barton-Upon-Humber',),
#  ('Basford',),
#  ('Bassett',),
#  ('Bassingbourn Snowsports Centre',),
#  ('Bateman s',),
#  ('Bath Racecourse',),
#  ('Bath Youth Hostel',),
#  ('Bathgate',),
#  ('Batley',),
#  ('Batsford Arboretum',),
#  ('Battlefield',),
#  ('Bawtry',),
#  ('Beaconsfield',),
#  ('Beaminster',),
#  ('Bearsden',),
#  ('Bearsden Ski Centre',),
#  ('Bearwood',),
#  ('Beauchief',),
#  ('Beauly',),
#  ('Beauly Firth',),
#  ('Beaumaris',),
#  ('Beaumont Leys',),
#  ('Bebington',),
#  ('Beccles',),
#  ('Beccles Heliport',),
#  ('Beckton',),
#  ('Bedale',),
#  ('Beddgelert',),
#  ('Bedford',),
#  ('Bedgebury',),
#  ('Bedgebury National Pinetum',),
#  ('Bedhampton',),
#  ('Bedlington',),
#  ('Bedminster',),
#  ('Bedwas',),
#  ('Bedworth',),
#  ('Beech Lane',),
#  ('Beer Youth Hostel',),
#  ('Beeston (Nottinghamshire)',),
#  ('Beeston (West Yorkshire)',),
#  ('Beetley',),
#  ('Beighton',),
#  ('Beinn A  Chaorainn (Aberdeenshire)',),
#  ('Beinn A  Chaorainn (Highland)',),
#  ('Beinn A  Chlachair',),
#  ('Beinn A  Chlaidheimh',),
#  ('Beinn A  Chleibh',),
#  ('Beinn A  Chochuil',),
#  ('Beinn A  Chreachain',),
#  ('Beinn A  Chroin',),
#  ('Beinn Achaladair',),
#  ('Beinn An Dothaidh',),
#  ('Beinn Bheoil',),
#  ('Beinn Bhreac',),
#  ('Beinn Bhrotain',),
#  ('Beinn Bhuidhe',),
#  ('Beinn Chabhair',),
#  ('Beinn Dearg (Highland)',),
#  ('Beinn Dearg (Perth & Kinross)',),
#  ('Beinn Dorain',),
#  ('Beinn Dubhchraig',),
#  ('Beinn Eibhinn',),
#  ('Beinn Eunaich',),
#  ('Beinn Fhada',),
#  ('Beinn Fhionnlaidh (Argyll & Bute)',),
#  ('Beinn Fhionnlaidh (Highland)',),
#  ('Beinn Ghlas',),
#  ('Beinn Heasgarnich',),
#  ('Beinn Ime',),
#  ('Beinn Iutharn Mhor',),
#  ('Beinn Liath Mhor',),
#  ('Beinn Liath Mhor Fannaich',),
#  ('Beinn Mhanach',),
#  ('Beinn Mheadhoin',),
#  ('Beinn Na Lap',),
#  ('Beinn Nan Aighenan',),
#  ('Beinn Narnain',),
#  ('Beinn Sgritheall',),
#  ('Beinn Sgulaird',),
#  ('Beinn Tarsuinn',),
#  ('Beinn Teallach',),
#  ('Beinn Tulaichean',),
#  ('Beinn Udlamain',),
#  ('Beith',),
#  ('Belchamp Otten',),
#  ('Belcoo',),
#  ('Belfast',),
#  ('Belfast International Airport',),
#  ('Belfast International Youth Hostel',),
#  ('Belgrave',),
#  ('Belhaven Bay',),
#  ('Bell Cottage Garden',),
#  ('Bell Green',),
#  ('Belle Isle',),
#  ('Belle Vale',),
#  ('Bellever Youth Hostel',),
#  ('Bellingham',),
#  ('Bellingham Youth Hostel',),
#  ('Bell s Close',),
#  ('Bellshill',),
#  ('Belper',),
#  ('Belper River Gardens',),
#  ('Belsay Hall Castle And Gardens',),
#  ('Belton House',),
#  ('Ben Alder',),
#  ...]

# %% [markdown]
# As a *good practice*, reserved words in SQL are written in **uppercase** and non-reserved words such as field names and table names are written in **lowercase**.
#
# We can limit the number of the returned results by using the ```LIMIT``` constraint.
#
# To Query multiples fields, these need to be separated by a comma "," in the
# SELECT statement:

# %%
# %%sql
# SELECT Location, LocationID, PostCode FROM cat_locations LIMIT 10;
# Out:
#  * sqlite:///weather.db
# Done.
# [('Southampton Airport', 3, None),
#  ('London City Airport', 5, None),
#  ('Lydd', 6, None),
#  ('Cranfield', 7, None),
#  ('Belfast Harbour', 8, None),
#  ('Carlisle Airport', 14, None),
#  ('Humberside Airport', 22, None),
#  ('Leeds Bradford International Airport', 25, None),
#  ('Liverpool John Lennon Airport', 26, None),
#  ('Scatsta', 33, None)]

# %% [markdown]
# We can use ```SELECT *``` to bring all the fields:

# %%
# %%sql
# SELECT * FROM cat_locations LIMIT 10;
# Out:
#  * sqlite:///weather.db
# Done.
# [(3, 'Southampton Airport', None, None, 'se', 'South East', 50.9503, -1.3567, 'Europe', 11.0, '', 'Hampshire'),
#  (5, 'London City Airport', None, None, 'se', 'South East', 51.5048, 0.058, 'Europe', 5.0, '', 'Greater London'),
#  (6, 'Lydd', None, None, 'se', 'South East', 50.9561, 0.9392, 'Europe', 4.0, '', 'Kent'),
#  (7, 'Cranfield', None, None, 'ee', 'East of England', 52.0703, -0.6267, 'Europe', 109.0, '', 'Central Bedfordshire'),
#  (8, 'Belfast Harbour', None, None, 'ni', 'Northern Ireland', 54.613, -5.877, 'Europe', 5.0, '', 'County Antrim'),
#  (14, 'Carlisle Airport', None, None, 'nw', 'North West', 54.9375, -2.8092, 'Europe', 50.0, '', 'Cumbria'),
#  (22, 'Humberside Airport', None, None, 'yh', 'Yorkshire and the Humber', 53.5797, -0.3472, 'Europe', 24.0, '', 'North Lincolnshire'),
#  (25, 'Leeds Bradford International Airport', None, None, 'yh', 'Yorkshire and the Humber', 53.8658, -1.6606, 'Europe', 203.0, '', 'West Yorkshire'),
#  (26, 'Liverpool John Lennon Airport', None, None, 'nw', 'North West', 53.3336, -2.85, 'Europe', 22.0, '', 'Merseyside'),
#  (33, 'Scatsta', None, None, 'os', 'Orkney and Shetland', 60.4322, -1.2992, 'Europe', 25.0, '', 'Shetland Islands')]

# %% [markdown]
# ## WHERE Statement
# Query data and filter rows with a condition
# ```sql
# SELECT field1, field 2 FROM Table
# WHERE Condition
# ```
# Example: Query all data from table cat_locations where region is equal to "se":

# %%
# %%sql
# -- LIMITED to 10 other wise the output is too large
# SELECT * FROM cat_locations WHERE region = 'se' LIMIT 10;
# Out:
#  * sqlite:///weather.db
# Done.
# [(3, 'Southampton Airport', None, None, 'se', 'South East', 50.9503, -1.3567, 'Europe', 11.0, '', 'Hampshire'),
#  (5, 'London City Airport', None, None, 'se', 'South East', 51.5048, 0.058, 'Europe', 5.0, '', 'Greater London'),
#  (6, 'Lydd', None, None, 'se', 'South East', 50.9561, 0.9392, 'Europe', 4.0, '', 'Kent'),
#  (349, 'Dungeness B', None, None, 'se', 'South East', 50.9134, 0.9597, 'Europe', 5.0, '', 'Kent'),
#  (3649, 'Brize Norton', None, None, 'se', 'South East', 51.758, -1.576, 'Europe', 81.0, '', 'Oxfordshire'),
#  (3658, 'Benson', None, None, 'se', 'South East', 51.62, -1.097, 'Europe', 57.0, '', 'Oxfordshire'),
#  (3660, 'High Wycombe', None, None, 'se', 'South East', 51.68, -0.802, 'Europe', 204.0, '', 'Buckinghamshire'),
#  (3672, 'Northolt', None, None, 'se', 'South East', 51.548, -0.415, 'Europe', 40.0, '', 'Greater London'),
#  (3749, 'Middle Wallop', None, None, 'se', 'South East', 51.149, -1.57, 'Europe', 91.0, '', 'Hampshire'),
#  (3761, 'Odiham', None, None, 'se', 'South East', 51.238, -0.944, 'Europe', 118.0, '', 'Hampshire')]

# %% [markdown]
# Note to query data different than ```'se'``` we will use ```region <> 'se'```

# %% [markdown]
# ## WHERE IN
# Query data and filter rows with a condition in a subset
# ```sql
# SELECT field1, field 2 FROM Table
# WHERE Condition [NOT] IN value_list
# ```
# Example: Query all data from table cat_locations where region is equal to 'se'

# %%
# %%sql
# SELECT * FROM cat_locations WHERE region IN ('se', 'ni');
# Out:
#  * sqlite:///weather.db
# Done.
# [(3, 'Southampton Airport', None, None, 'se', 'South East', 50.9503, -1.3567, 'Europe', 11.0, '', 'Hampshire'),
#  (5, 'London City Airport', None, None, 'se', 'South East', 51.5048, 0.058, 'Europe', 5.0, '', 'Greater London'),
#  (6, 'Lydd', None, None, 'se', 'South East', 50.9561, 0.9392, 'Europe', 4.0, '', 'Kent'),
#  (8, 'Belfast Harbour', None, None, 'ni', 'Northern Ireland', 54.613, -5.877, 'Europe', 5.0, '', 'County Antrim'),
#  (349, 'Dungeness B', None, None, 'se', 'South East', 50.9134, 0.9597, 'Europe', 5.0, '', 'Kent'),
#  (3649, 'Brize Norton', None, None, 'se', 'South East', 51.758, -1.576, 'Europe', 81.0, '', 'Oxfordshire'),
#  (3658, 'Benson', None, None, 'se', 'South East', 51.62, -1.097, 'Europe', 57.0, '', 'Oxfordshire'),
#  (3660, 'High Wycombe', None, None, 'se', 'South East', 51.68, -0.802, 'Europe', 204.0, '', 'Buckinghamshire'),
#  (3672, 'Northolt', None, None, 'se', 'South East', 51.548, -0.415, 'Europe', 40.0, '', 'Greater London'),
#  (3749, 'Middle Wallop', None, None, 'se', 'South East', 51.149, -1.57, 'Europe', 91.0, '', 'Hampshire'),
#  (3761, 'Odiham', None, None, 'se', 'South East', 51.238, -0.944, 'Europe', 118.0, '', 'Hampshire'),
#  (3768, 'Farnborough', None, None, 'se', 'South East', 51.279, -0.772, 'Europe', 72.0, '', 'Hampshire'),
#  (3769, 'Charlwood', None, None, 'se', 'South East', 51.15, -0.2333, 'Europe', 67.0, '', 'Surrey'),
#  (3772, 'Heathrow', None, None, 'se', 'South East', 51.479, -0.4491, 'Europe', 25.0, '', 'Greater London'),
#  (3781, 'Kenley', None, None, 'se', 'South East', 51.303, -0.09, 'Europe', 170.0, '', 'Surrey'),
#  (3784, 'Gravesend-Broadness', None, None, 'se', 'South East', 51.464, 0.314, 'Europe', 3.0, '', 'Kent'),
#  (3796, 'Langdon Bay', None, None, 'se', 'South East', 51.133, 1.348, 'Europe', 117.0, '', 'Kent'),
#  (3797, 'Manston', None, None, 'se', 'South East', 51.3422, 1.3461, 'Europe', 54.0, '', 'Kent'),
#  (3865, 'Southampton W.C.', None, None, 'se', 'South East', 50.901, -1.403, 'Europe', 19.0, '', 'Southampton'),
#  (3866, 'St Catherines Pt.', None, None, 'se', 'South East', 50.577, -1.297, 'Europe', 16.0, '', 'Isle of Wight'),
#  (3872, 'Thorney Island', None, None, 'se', 'South East', 50.815, -0.923, 'Europe', 4.0, '', 'West Sussex'),
#  (3874, 'Solent Mrsc', None, None, 'se', 'South East', 50.807, -1.208, 'Europe', 9.0, '', 'Hampshire'),
#  (3876, 'Shoreham', None, None, 'se', 'South East', 50.836, -0.292, 'Europe', 13.0, '', 'West Sussex'),
#  (3882, 'Herstmonceux West End', None, None, 'se', 'South East', 50.89, 0.319, 'Europe', 52.0, '', 'East Sussex'),
#  (3903, 'St Angelo', None, None, 'ni', 'Northern Ireland', 54.4, -7.65, 'Europe', 47.0, '', 'County Fermanagh'),
#  (3904, 'Castlederg', None, None, 'ni', 'Northern Ireland', 54.707, -7.577, 'Europe', 49.0, '', 'County Tyrone'),
#  (3908, 'Ballykelly Samos', None, None, 'ni', 'Northern Ireland', 55.057, -7.008, 'Europe', 4.0, '', 'County Londonderry'),
#  (3911, 'Lough Fea Samos', None, None, 'ni', 'Northern Ireland', 54.721, -6.814, 'Europe', 225.0, '', 'County Londonderry'),
#  (3914, 'Portrush', None, None, 'ni', 'Northern Ireland', 55.208, -6.655, 'Europe', 8.0, '', 'County Londonderry'),
#  (3915, 'Portglenone Samos', None, None, 'ni', 'Northern Ireland', 54.865, -6.457, 'Europe', 64.0, '', 'County Antrim'),
#  (3916, 'Ballypatrick Forest', None, None, 'ni', 'Northern Ireland', 55.181, -6.153, 'Europe', 156.0, '', 'County Antrim'),
#  (3917, 'Aldergrove', None, None, 'ni', 'Northern Ireland', 54.664, -6.224, 'Europe', 63.0, '', 'County Antrim'),
#  (3923, 'Glenanne', None, None, 'ni', 'Northern Ireland', 54.237, -6.502, 'Europe', 161.0, '', 'County Armagh'),
#  (3928, 'Larne', None, None, 'ni', 'Northern Ireland', 54.852, -5.83, 'Europe', 43.0, '', 'County Antrim'),
#  (99008, 'East Malling', None, None, 'se', 'South East', 51.283, 0.45, 'Europe', 33.0, '', 'Kent'),
#  (99014, 'Katesbridge', None, None, 'ni', 'Northern Ireland', 54.3, -6.1, 'Europe', 91.0, '', 'County Down'),
#  (99015, 'Killowen', None, None, 'ni', 'Northern Ireland', 54.067, -6.183, 'Europe', 4.0, '', 'County Armagh'),
#  (99080, 'Wisley', None, None, 'se', 'South East', 51.317, -0.467, 'Europe', 38.0, '', 'Surrey'),
#  (99086, 'Helens Bay', None, None, 'ni', 'Northern Ireland', 54.667, -5.75, 'Europe', 43.0, '', 'County Down'),
#  (99095, 'Kew Gardens', None, None, 'se', 'South East', 51.482, -0.29, 'Europe', 6.0, '', 'Greater London'),
#  (99102, 'Eton Dorney', None, None, 'se', 'South East', 51.493, -0.664, 'Europe', 20.0, '', 'Buckinghamshire'),
#  (99121, 'Altnahinch Filters', None, None, 'ni', 'Northern Ireland', 55.048, -6.254, 'Europe', 213.0, '', 'County Antrim'),
#  (99130, 'Murlough', None, None, 'ni', 'Northern Ireland', 54.245, -5.83, 'Europe', 12.0, '', 'County Down'),
#  (99131, 'Banagher  Caugh Hill', None, None, 'ni', 'Northern Ireland', 54.885, -6.966, 'Europe', 216.0, '', 'County Londonderry'),
#  (99139, 'Hampstead', None, None, 'se', 'South East', 51.56, -0.178, 'Europe', 137.0, '', 'Greater London'),
#  (99203, 'London  Olympic Park South', None, None, 'se', 'South East', 51.534, -0.009, 'Europe', 5.0, '', 'Greater London'),
#  (99204, 'London  Olympic Park North', None, None, 'se', 'South East', 51.542, -0.017, 'Europe', 21.0, '', 'Greater London'),
#  (310025, 'Basingstoke', None, None, 'se', 'South East', 51.2621, -1.0921, 'Europe', 85.0, '', 'Hampshire'),
#  (310031, 'Bognor Regis', None, None, 'se', 'South East', 50.7825, -0.6716, 'Europe', 3.0, '', 'West Sussex'),
#  (310035, 'Bracknell', None, None, 'se', 'South East', 51.4156, -0.7525, 'Europe', 67.0, '', 'Bracknell Forest'),
#  (310037, 'Brighton', None, None, 'se', 'South East', 50.822, -0.1356, 'Europe', 8.0, '', 'Brighton and Hove'),
#  (310045, 'Chatham', None, None, 'se', 'South East', 51.3805, 0.5238, 'Europe', 21.0, '', 'Medway'),
#  (310055, 'Crawley', None, None, 'se', 'South East', 51.1149, -0.1913, 'Europe', 76.0, '', 'West Sussex'),
#  (310061, 'Dover', None, None, 'se', 'South East', 51.1259, 1.3179, 'Europe', 2.0, '', 'Kent'),
#  (310066, 'Eastbourne', None, None, 'se', 'South East', 50.7675, 0.2921, 'Europe', 7.0, '', 'East Sussex'),
#  (310071, 'Folkestone', None, None, 'se', 'South East', 51.0809, 1.1711, 'Europe', 40.0, '', 'Kent'),
#  (310073, 'Gillingham (Kent)', None, None, 'se', 'South East', 51.3858, 0.5531, 'Europe', 40.0, '', 'Medway'),
#  (310076, 'Gravesend', None, None, 'se', 'South East', 51.4414, 0.3724, 'Europe', 18.0, '', 'Kent'),
#  (310080, 'Guildford', None, None, 'se', 'South East', 51.2362, -0.5699, 'Europe', 51.0, '', 'Surrey'),
#  (310087, 'Hastings', None, None, 'se', 'South East', 50.8537, 0.5751, 'Europe', 10.0, '', 'East Sussex'),
#  (310090, 'High Wycombe', None, None, 'se', 'South East', 51.631, -0.7479, 'Europe', 81.0, '', 'Buckinghamshire'),
#  (310091, 'Hove', None, None, 'se', 'South East', 50.8274, -0.1672, 'Europe', 15.0, '', 'Brighton and Hove'),
#  (310106, 'Maidstone', None, None, 'se', 'South East', 51.2699, 0.5243, 'Europe', 10.0, '', 'Kent'),
#  (310108, 'Margate', None, None, 'se', 'South East', 51.3892, 1.3886, 'Europe', 10.0, '', 'Kent'),
#  (310118, 'Oxford', None, None, 'se', 'South East', 51.7513, -1.2538, 'Europe', 61.0, '', 'Oxfordshire'),
#  (310122, 'Portsmouth', None, None, 'se', 'South East', 50.7922, -1.0949, 'Europe', 2.0, '', 'Portsmouth'),
#  (310124, 'Reading', None, None, 'se', 'South East', 51.4523, -0.9724, 'Europe', 37.0, '', 'Reading'),
#  (310154, 'Tunbridge Wells', None, None, 'se', 'South East', 51.1338, 0.2651, 'Europe', 113.0, '', 'Kent'),
#  (310191, 'Cowes', None, None, 'se', 'South East', 50.7623, -1.2991, 'Europe', 22.0, '', 'Isle of Wight'),
#  (310224, 'Rye', None, None, 'se', 'South East', 50.9492, 0.7389, 'Europe', 5.0, '', 'East Sussex'),
#  (310240, 'Whitstable', None, None, 'se', 'South East', 51.3606, 1.0259, 'Europe', 1.0, '', 'Kent'),
#  (320281, 'Andover', None, None, 'se', 'South East', 51.2066, -1.4798, 'Europe', 56.0, '', 'Hampshire'),
#  (320282, 'Aylesbury', None, None, 'se', 'South East', 51.8152, -0.8069, 'Europe', 78.0, '', 'Buckinghamshire'),
#  (320283, 'Banbury', None, None, 'se', 'South East', 52.0625, -1.3383, 'Europe', 99.0, '', 'Oxfordshire'),
#  (321943, 'Abingdon', None, None, 'se', 'South East', 51.6704, -1.2865, 'Europe', 52.0, '', 'Oxfordshire'),
#  (321983, 'Armagh', None, None, 'ni', 'Northern Ireland', 54.3463, -6.6512, 'Europe', 42.0, '', 'County Armagh'),
#  (322002, 'Ballycastle', None, None, 'ni', 'Northern Ireland', 55.2058, -6.239, 'Europe', 4.0, '', 'County Antrim'),
#  (322018, 'Battle', None, None, 'se', 'South East', 50.9169, 0.4853, 'Europe', 81.0, '', 'East Sussex'),
#  (322089, 'Canterbury', None, None, 'se', 'South East', 51.2797, 1.0806, 'Europe', 8.0, '', 'Kent'),
#  (322116, 'Coleraine', None, None, 'ni', 'Northern Ireland', 55.1385, -6.6681, 'Europe', 5.0, '', 'County Londonderry'),
#  (322172, 'Enniskillen', None, None, 'ni', 'Northern Ireland', 54.3446, -7.6313, 'Europe', 52.0, '', 'County Fermanagh'),
#  (322281, 'Hayes', None, None, 'se', 'South East', 51.5, -0.42, 'Europe', 32.0, '', 'Greater London'),
#  (322324, 'Isle Of Grain', None, None, 'se', 'South East', 51.45, 0.71, 'Europe', 1.0, '', 'Medway'),
#  (322381, 'Kingsnorth', None, None, 'se', 'South East', 51.43, 0.6, 'Europe', 1.0, '', 'Medway'),
#  (322462, 'Littlehampton', None, None, 'se', 'South East', 50.8105, -0.5371, 'Europe', 3.0, '', 'West Sussex'),
#  (322472, 'Londonderry (Derry)', None, None, 'ni', 'Northern Ireland', 54.9952, -7.3227, 'Europe', 35.0, '', 'County Londonderry'),
#  (322574, 'Newhaven', None, None, 'se', 'South East', 50.7925, 0.0472, 'Europe', 28.0, '', 'East Sussex'),
#  (322597, 'Omagh', None, None, 'ni', 'Northern Ireland', 54.6003, -7.3043, 'Europe', 81.0, '', 'County Tyrone'),
#  (322690, 'Ramsgate', None, None, 'se', 'South East', 51.3351, 1.4216, 'Europe', 15.0, '', 'Kent'),
#  (322937, 'Warrenpoint', None, None, 'ni', 'Northern Ireland', 54.101, -6.2543, 'Europe', 5.0, '', 'County Armagh'),
#  (322958, 'Yiewsley', None, None, 'se', 'South East', 51.52, -0.45, 'Europe', 43.0, '', 'Greater London'),
#  (324055, 'Dorking', None, None, 'se', 'South East', 51.2322, -0.3295, 'Europe', 64.0, '', 'Surrey'),
#  (324060, 'Horsham', None, None, 'se', 'South East', 51.0624, -0.3243, 'Europe', 50.0, '', 'West Sussex'),
#  (324063, 'Newbury', None, None, 'se', 'South East', 51.401, -1.3216, 'Europe', 74.0, '', 'West Berkshire'),
#  (324068, 'Selsey', None, None, 'se', 'South East', 50.7305, -0.7922, 'Europe', 6.0, '', 'West Sussex'),
#  (324075, 'Windsor', None, None, 'se', 'South East', 51.4813, -0.612, 'Europe', 23.0, '', 'Windsor and Maidenhead'),
#  (324149, 'Aldershot', None, None, 'se', 'South East', 51.2491, -0.7529, 'Europe', 91.0, '', 'Hampshire'),
#  (324150, 'Ashford', None, None, 'se', 'South East', 51.146, 0.8767, 'Europe', 45.0, '', 'Kent'),
#  (324151, 'Barnet', None, None, 'se', 'South East', 51.6528, -0.1991, 'Europe', 132.0, '', 'Greater London'),
#  (324152, 'Croydon', None, None, 'se', 'South East', 51.3775, -0.0933, 'Europe', 55.0, '', 'Greater London'),
#  (324153, 'Kingston Upon Thames', None, None, 'se', 'South East', 51.4119, -0.2991, 'Europe', 4.0, '', 'Greater London'),
#  (324154, 'Maidenhead', None, None, 'se', 'South East', 51.522, -0.7204, 'Europe', 27.0, '', 'Windsor and Maidenhead'),
#  (324155, 'Reigate', None, None, 'se', 'South East', 51.2376, -0.203, 'Europe', 87.0, '', 'Surrey'),
#  (324156, 'Uckfield', None, None, 'se', 'South East', 50.9659, 0.0975, 'Europe', 37.0, '', 'East Sussex'),
#  (324161, 'Amersham', None, None, 'se', 'South East', 51.6751, -0.6057, 'Europe', 150.0, '', 'Buckinghamshire'),
#  (324164, 'Barking', None, None, 'se', 'South East', 51.53926, 0.081146, 'Europe', 12.0, '', 'Greater London'),
#  (324169, 'Buckingham', None, None, 'se', 'South East', 51.9989, -0.9861, 'Europe', 81.0, '', 'Buckinghamshire'),
#  (324184, 'Farnham', None, None, 'se', 'South East', 51.2138, -0.7973, 'Europe', 68.0, '', 'Surrey'),
#  (324193, 'Henley On Thames', None, None, 'se', 'South East', 51.5353, -0.9014, 'Europe', 35.0, '', 'Oxfordshire'),
#  (324196, 'Hungerford', None, None, 'se', 'South East', 51.4119, -1.5165, 'Europe', 120.0, '', 'West Berkshire'),
#  (324199, 'Leatherhead', None, None, 'se', 'South East', 51.2916, -0.3241, 'Europe', 54.0, '', 'Surrey'),
#  (324237, 'Winslow', None, None, 'se', 'South East', 51.9445, -0.8772, 'Europe', 117.0, '', 'Buckinghamshire'),
#  (324239, 'Woking', None, None, 'se', 'South East', 51.3156, -0.5594, 'Europe', 37.0, '', 'Surrey'),
#  (324247, 'Haslemere', None, None, 'se', 'South East', 51.0893, -0.7102, 'Europe', 145.0, '', 'Surrey'),
#  (324248, 'Petersfield', None, None, 'se', 'South East', 51.0071, -0.9375, 'Europe', 69.0, 'South Downs National Park', 'Hampshire'),
#  (324257, 'Three Chimneys', None, None, 'se', 'South East', 51.1173, 0.6101, 'Europe', 50.0, '', 'Kent'),
#  (324377, 'Wembley Stadium', None, None, 'se', 'South East', 51.55602, -0.27956, 'Europe', 36.0, '', 'Greater London'),
#  (324382, 'The Royal Artillery Barracks', None, None, 'se', 'South East', 51.486, 0.062, 'Europe', 38.0, '', 'Greater London'),
#  (324383, 'All England Tennis Club Wimbledon', None, None, 'se', 'South East', 51.4337, -0.2141, 'Europe', 26.0, '', 'Greater London'),
#  (324386, 'Horseguards Parade', None, None, 'se', 'South East', 51.5047, -0.1283, 'Europe', 3.0, '', 'Greater London'),
#  (324387, 'Hyde Park', None, None, 'se', 'South East', 51.5077, -0.165, 'Europe', 22.0, '', 'Greater London'),
#  (350036, 'Addlestone', None, None, 'se', 'South East', 51.3689, -0.4886, 'Europe', 14.0, '', 'Surrey'),
#  (350060, 'Alfriston Youth Hostel', None, None, 'se', 'South East', 50.8024, 0.1566, 'Europe', 1.0, 'South Downs National Park', 'East Sussex'),
#  (350061, 'Alice Holt', None, None, 'se', 'South East', 51.1656, -0.8433, 'Europe', 115.0, 'South Downs National Park', 'Hampshire'),
#  (350068, 'Alpine Snowsports Farnborough', None, None, 'se', 'South East', 51.2598, -0.7477, 'Europe', 82.0, '', 'Hampshire'),
#  (350074, 'Alton', None, None, 'se', 'South East', 51.1501, -0.9749, 'Europe', 109.0, '', 'Hampshire'),
#  (350078, 'Alverstoke', None, None, 'se', 'South East', 50.7843, -1.146, 'Europe', 1.0, '', 'Hampshire'),
#  (350106, 'Gosport & Stokes Bay Golf Club', None, None, 'se', 'South East', 50.778, -1.1425, 'Europe', 1.0, '', 'Hampshire'),
#  (350114, 'Antrim', None, None, 'ni', 'Northern Ireland', 54.7193, -6.2069, 'Europe', 33.0, '', 'County Antrim'),
#  (350115, 'Antrim Castle Gardens', None, None, 'ni', 'Northern Ireland', 54.7188, -6.2316, 'Europe', 16.0, '', 'County Antrim'),
#  (350132, 'Ardress House (Nt)', None, None, 'ni', 'Northern Ireland', 54.4417, -6.5843, 'Europe', 18.0, '', 'County Armagh'),
#  (350142, 'Armagh Youth Hostel', None, None, 'ni', 'Northern Ireland', 54.3481, -6.6603, 'Europe', 50.0, '', 'County Armagh'),
#  (350150, 'Arsenal F.C.', None, None, 'se', 'South East', 51.5535, -0.1033, 'Europe', 32.0, '', 'Greater London'),
#  (350151, 'Arundel', None, None, 'se', 'South East', 50.8547, -0.5536, 'Europe', 18.0, '', 'West Sussex'),
#  (350152, 'Arundel Youth Hostel', None, None, 'se', 'South East', 50.8581, -0.5309, 'Europe', 10.0, 'South Downs National Park', 'West Sussex'),
#  (350153, 'Ascot Racecourse', None, None, 'se', 'South East', 51.4139, -0.677, 'Europe', 79.0, '', 'Windsor and Maidenhead'),
#  (350154, 'Ascott', None, None, 'se', 'South East', 51.8943, -0.7047, 'Europe', 120.0, '', 'Buckinghamshire'),
#  (350179, 'Augher', None, None, 'ni', 'Northern Ireland', 54.4286, -7.1312, 'Europe', 63.0, '', 'County Tyrone'),
#  (350180, 'Aughnacloy', None, None, 'ni', 'Northern Ireland', 54.4132, -6.9738, 'Europe', 51.0, '', 'County Tyrone'),
#  (350202, 'Bagshot', None, None, 'se', 'South East', 51.3602, -0.6967, 'Europe', 71.0, '', 'Surrey'),
#  (350220, 'Ballyclare', None, None, 'ni', 'Northern Ireland', 54.7524, -6.0022, 'Europe', 81.0, '', 'County Antrim'),
#  (350222, 'Ballymena', None, None, 'ni', 'Northern Ireland', 54.8635, -6.2777, 'Europe', 44.0, '', 'County Antrim'),
#  (350223, 'Ballymoney', None, None, 'ni', 'Northern Ireland', 55.0716, -6.508, 'Europe', 43.0, '', 'County Antrim'),
#  (350224, 'Ballynahinch', None, None, 'ni', 'Northern Ireland', 54.4025, -5.8963, 'Europe', 74.0, '', 'County Down'),
#  (350229, 'Banbridge', None, None, 'ni', 'Northern Ireland', 54.3518, -6.2659, 'Europe', 55.0, '', 'County Down'),
#  (350233, 'Bangor (North Down)', None, None, 'ni', 'Northern Ireland', 54.6629, -5.6619, 'Europe', 17.0, '', 'County Down'),
#  (350234, 'Bangor Castle', None, None, 'ni', 'Northern Ireland', 54.6509, -5.6662, 'Europe', 39.0, '', 'County Down'),
#  (350240, 'Banstead', None, None, 'se', 'South East', 51.3217, -0.2035, 'Europe', 160.0, '', 'Surrey'),
#  (350263, 'Bassett', None, None, 'se', 'South East', 50.9437, -1.4038, 'Europe', 76.0, '', 'Southampton'),
#  (350265, 'Bateman s', None, None, 'se', 'South East', 50.9892, 0.377, 'Europe', 44.0, '', 'East Sussex'),
#  (350273, 'Beaconsfield', None, None, 'se', 'South East', 51.602, -0.6427, 'Europe', 100.0, '', 'Buckinghamshire'),
#  (350286, 'Beckton', None, None, 'se', 'South East', 51.5145, 0.0582, 'Europe', 2.0, '', 'Greater London'),
#  (350290, 'Bedgebury', None, None, 'se', 'South East', 51.0751, 0.453, 'Europe', 70.0, '', 'Kent'),
#  (350291, 'Bedgebury National Pinetum', None, None, 'se', 'South East', 51.0759, 0.4583, 'Europe', 69.0, '', 'Kent'),
#  (350292, 'Bedhampton', None, None, 'se', 'South East', 50.8541, -1.0025, 'Europe', 11.0, '', 'Hampshire'),
#  (350346, 'Belcoo', None, None, 'ni', 'Northern Ireland', 54.2957, -7.8712, 'Europe', 54.0, '', 'County Fermanagh'),
#  (350347, 'Belfast', None, None, 'ni', 'Northern Ireland', 54.596, -5.9301, 'Europe', 13.0, '', 'County Antrim'),
#  (350348, 'Belfast International Airport', None, None, 'ni', 'Northern Ireland', 54.6561, -6.2144, 'Europe', 71.0, '', 'County Antrim'),
#  (350349, 'Belfast International Youth Hostel', None, None, 'ni', 'Northern Ireland', 54.5912, -5.9388, 'Europe', 4.0, '', 'County Antrim'),
#  (350394, 'Bentworth', None, None, 'se', 'South East', 51.1578, -1.0497, 'Europe', 171.0, '', 'Hampshire'),
#  (350395, 'Benvarden', None, None, 'ni', 'Northern Ireland', 55.1385, -6.5152, 'Europe', 29.0, '', 'County Antrim'),
#  (350400, 'Berri Court', None, None, 'se', 'South East', 50.8164, -0.623, 'Europe', 4.0, '', 'West Sussex'),
#  (350406, 'Bethersden', None, None, 'se', 'South East', 51.1288, 0.7557, 'Europe', 40.0, '', 'Kent'),
#  (350412, 'Bexhill', None, None, 'se', 'South East', 50.8412, 0.4774, 'Europe', 20.0, '', 'East Sussex'),
#  (350413, 'Bexley', None, None, 'se', 'South East', 51.4414, 0.1487, 'Europe', 36.0, '', 'Greater London'),
#  (350414, 'Bicester', None, None, 'se', 'South East', 51.8992, -1.1521, 'Europe', 72.0, '', 'Oxfordshire'),
#  (350426, 'Biggin Hill', None, None, 'se', 'South East', 51.3116, 0.0344, 'Europe', 170.0, '', 'Greater London'),
#  (350431, 'Billingshurst', None, None, 'se', 'South East', 51.0224, -0.4499, 'Europe', 30.0, '', 'West Sussex'),
#  (350441, 'Birchington', None, None, 'se', 'South East', 51.3729, 1.3082, 'Europe', 21.0, '', 'Kent'),
#  (350453, 'Bisham Abbey National Sports Centre', None, None, 'se', 'South East', 51.5583, -0.7758, 'Europe', 27.0, '', 'Windsor and Maidenhead'),
#  (350459, 'Bishop s Waltham', None, None, 'se', 'South East', 50.9522, -1.2123, 'Europe', 38.0, '', 'Hampshire'),
#  (350462, 'Bitterne', None, None, 'se', 'South East', 50.9161, -1.3552, 'Europe', 51.0, '', 'Southampton'),
#  (350466, 'Blackboys Youth Hostel', None, None, 'se', 'South East', 50.9703, 0.1707, 'Europe', 49.0, '', 'East Sussex'),
#  (350470, 'Blackgang Chine', None, None, 'se', 'South East', 50.5821, -1.3078, 'Europe', 64.0, '', 'Isle of Wight'),
#  (350492, 'Blenheim Palace', None, None, 'se', 'South East', 51.8394, -1.3579, 'Europe', 96.0, '', 'Oxfordshire'),
#  (350493, 'Bletchley', None, None, 'se', 'South East', 52.0018, -0.7486, 'Europe', 88.0, '', 'Milton Keynes'),
#  (350494, 'Blewbury', None, None, 'se', 'South East', 51.5664, -1.2326, 'Europe', 70.0, '', 'Oxfordshire'),
#  (350515, 'Borde Hill Garden', None, None, 'se', 'South East', 51.0239, -0.1291, 'Europe', 61.0, '', 'West Sussex'),
#  (350526, 'Oxford Botanic Garden', None, None, 'se', 'South East', 51.7479, -1.2445, 'Europe', 55.0, '', 'Oxfordshire'),
#  (350528, 'Botany Bay (Broadstairs)', None, None, 'se', 'South East', 51.3908, 1.4367, 'Europe', 0.0, '', 'Kent'),
#  (350530, 'Botley', None, None, 'se', 'South East', 50.9148, -1.2692, 'Europe', 8.0, '', 'Hampshire'),
#  (350532, 'Boughton Street', None, None, 'se', 'South East', 51.2967, 0.9493, 'Europe', 30.0, '', 'Kent'),
#  (350540, 'Bowles Outdoor Centre', None, None, 'se', 'South East', 51.0776, 0.1971, 'Europe', 104.0, '', 'East Sussex'),
#  (350548, 'Bracknell Ski & Snowboard Centre', None, None, 'se', 'South East', 51.4142, -0.7821, 'Europe', 67.0, '', 'Bracknell Forest'),
#  (350551, 'Bradenham Youth Hostel', None, None, 'se', 'South East', 51.6685, -0.7956, 'Europe', 146.0, '', 'Buckinghamshire'),
#  (350558, 'Bradwell Village Youth Hostel', None, None, 'se', 'South East', 52.0482, -0.7886, 'Europe', 70.0, '', 'Milton Keynes'),
#  (350571, 'Brands Hatch', None, None, 'se', 'South East', 51.3554, 0.2636, 'Europe', 144.0, '', 'Kent'),
#  (350602, 'Brighton Racecourse', None, None, 'se', 'South East', 50.8319, -0.1011, 'Europe', 109.0, '', 'Brighton and Hove'),
#  (350603, 'Brighton Youth Hostel', None, None, 'se', 'South East', 50.859, -0.1477, 'Europe', 62.0, '', 'Brighton and Hove'),
#  (350625, 'Broadstairs', None, None, 'se', 'South East', 51.3597, 1.4338, 'Europe', 42.0, '', 'Kent'),
#  (350626, 'Broadstairs Youth Hostel', None, None, 'se', 'South East', 51.3578, 1.4317, 'Europe', 42.0, '', 'Kent'),
#  (350629, 'Brockenhurst', None, None, 'se', 'South East', 50.8184, -1.5743, 'Europe', 18.0, 'New Forest National Park', 'Hampshire'),
#  (350635, 'Bromley (Greater London)', None, None, 'se', 'South East', 51.4056, 0.0148, 'Europe', 65.0, '', 'Greater London'),
#  (350638, 'Bromley Ski Centre', None, None, 'se', 'South East', 51.405, 0.1278, 'Europe', 60.0, '', 'Greater London'),
#  (350642, 'Brook Cottage Gardens (Alkerton)', None, None, 'se', 'South East', 52.0864, -1.4558, 'Europe', 172.0, '', 'Oxfordshire'),
#  (350643, 'Brookeborough', None, None, 'ni', 'Northern Ireland', 54.3141, -7.4058, 'Europe', 74.0, '', 'County Fermanagh'),
#  (350649, 'Broughshane', None, None, 'ni', 'Northern Ireland', 54.8938, -6.2023, 'Europe', 65.0, '', 'County Antrim'),
#  (350650, 'Broughton Castle', None, None, 'se', 'South East', 52.0458, -1.3934, 'Europe', 129.0, '', 'Oxfordshire'),
#  (350673, 'Burford', None, None, 'se', 'South East', 51.8067, -1.6353, 'Europe', 118.0, '', 'Oxfordshire'),
#  (350675, 'Burgess Hill', None, None, 'se', 'South East', 50.954, -0.1271, 'Europe', 48.0, '', 'West Sussex'),
#  (350677, 'Burley Youth Hostel', None, None, 'se', 'South East', 50.8238, -1.6892, 'Europe', 65.0, 'New Forest National Park', 'Hampshire'),
#  (350692, 'Buscot Park', None, None, 'se', 'South East', 51.6652, -1.6462, 'Europe', 99.0, '', 'Oxfordshire'),
#  (350695, 'Bushmills', None, None, 'ni', 'Northern Ireland', 55.2078, -6.5214, 'Europe', 7.0, '', 'County Antrim'),
#  (350719, 'Caldecotte', None, None, 'se', 'South East', 52.0058, -0.6958, 'Europe', 70.0, '', 'Milton Keynes'),
#  (350725, 'Calshot Activities Centre', None, None, 'se', 'South East', 50.8123, -1.3109, 'Europe', 1.0, 'New Forest National Park', 'Hampshire'),
#  (350726, 'Camberley', None, None, 'se', 'South East', 51.3349, -0.7413, 'Europe', 84.0, '', 'Surrey'),
#  (350734, 'Camden Town', None, None, 'se', 'South East', 51.5392, -0.1425, 'Europe', 25.0, '', 'Greater London'),
#  (350747, 'Canterbury Youth Hostel', None, None, 'se', 'South East', 51.2685, 1.0865, 'Europe', 41.0, '', 'Kent'),
#  (350750, 'Capel', None, None, 'se', 'South East', 51.1533, -0.3195, 'Europe', 89.0, '', 'Surrey'),
#  (350752, 'Capel Manor', None, None, 'se', 'South East', 51.6779, -0.0562, 'Europe', 33.0, '', 'Greater London'),
#  (350806, 'Carrick-A-Rede Rope Bridge (Nt)', None, None, 'ni', 'Northern Ireland', 55.2387, -6.3329, 'Europe', 55.0, '', 'County Antrim'),
#  (350807, 'Carrickfergus', None, None, 'ni', 'Northern Ireland', 54.7134, -5.8117, 'Europe', 5.0, '', 'County Antrim'),
#  (350811, 'Carryduff', None, None, 'ni', 'Northern Ireland', 54.5192, -5.8875, 'Europe', 119.0, '', 'County Down'),
#  (350813, 'Castle Archdale Country Park', None, None, 'ni', 'Northern Ireland', 54.4765, -7.7256, 'Europe', 68.0, '', 'County Fermanagh'),
#  (350816, 'Castle Caldwell', None, None, 'ni', 'Northern Ireland', 54.4843, -7.9792, 'Europe', 54.0, '', 'County Fermanagh'),
#  (350819, 'Castle Coole (Nt)', None, None, 'ni', 'Northern Ireland', 54.3373, -7.6149, 'Europe', 53.0, '', 'County Fermanagh'),
#  (350825, 'Castle Ward (Nt)', None, None, 'ni', 'Northern Ireland', 54.3666, -5.5776, 'Europe', 54.0, '', 'County Down'),
#  (350827, 'Castlederg', None, None, 'ni', 'Northern Ireland', 54.7063, -7.5909, 'Europe', 45.0, '', 'County Tyrone'),
#  (350835, 'Castlewellan', None, None, 'ni', 'Northern Ireland', 54.2571, -5.944, 'Europe', 112.0, '', 'County Down'),
#  (350837, 'Caterham', None, None, 'se', 'South East', 51.2798, -0.08, 'Europe', 135.0, '', 'Surrey'),
#  (350840, 'Catisfield', None, None, 'se', 'South East', 50.8528, -1.2233, 'Europe', 27.0, '', 'Hampshire'),
#  (350841, 'Catmore', None, None, 'se', 'South East', 51.519, -1.3465, 'Europe', 177.0, '', 'West Berkshire'),
#  (350852, 'Chalfont St. Peter', None, None, 'se', 'South East', 51.6046, -0.5528, 'Europe', 59.0, '', 'Buckinghamshire'),
#  (350863, 'Charlbury', None, None, 'se', 'South East', 51.8741, -1.4783, 'Europe', 118.0, '', 'Oxfordshire'),
#  (350864, 'Charlbury Youth Hostel', None, None, 'se', 'South East', 51.8804, -1.47, 'Europe', 129.0, '', 'Oxfordshire'),
#  (350867, 'Charleston Manor', None, None, 'se', 'South East', 50.7836, 0.1572, 'Europe', 29.0, 'South Downs National Park', 'East Sussex'),
#  (350868, 'Charlton Athletic F.C.', None, None, 'se', 'South East', 51.4862, 0.042, 'Europe', 31.0, '', 'Greater London'),
#  (350869, 'Chartham', None, None, 'se', 'South East', 51.2544, 1.0222, 'Europe', 15.0, '', 'Kent'),
#  (350870, 'Chartwell', None, None, 'se', 'South East', 51.2445, 0.09, 'Europe', 154.0, '', 'Kent'),
#  (350871, 'Chastleton House', None, None, 'se', 'South East', 51.9617, -1.6322, 'Europe', 166.0, '', 'Oxfordshire'),
#  (350872, 'Chatham Ski Centre', None, None, 'se', 'South East', 51.3532, 0.559, 'Europe', 95.0, '', 'Medway'),
#  (350881, 'Chelsea', None, None, 'se', 'South East', 51.4847, -0.1752, 'Europe', 4.0, '', 'Greater London'),
#  (350882, 'Chelsea F.C.', None, None, 'se', 'South East', 51.4816, -0.1918, 'Europe', 4.0, '', 'Greater London'),
#  (350886, 'Chertsey', None, None, 'se', 'South East', 51.3866, -0.5082, 'Europe', 16.0, '', 'Surrey'),
#  (350887, 'Chesham (Buckinghamshire)', None, None, 'se', 'South East', 51.709, -0.6108, 'Europe', 105.0, '', 'Buckinghamshire'),
#  (350890, 'Chessington World Of Adventures', None, None, 'se', 'South East', 51.3466, -0.3221, 'Europe', 69.0, '', 'Greater London'),
#  (350895, 'Chicheley', None, None, 'se', 'South East', 52.1022, -0.682, 'Europe', 76.0, '', 'Milton Keynes'),
#  (350896, 'Chichester', None, None, 'se', 'South East', 50.8371, -0.7734, 'Europe', 14.0, '', 'West Sussex'),
#  (350897, 'Chiddingstone Castle', None, None, 'se', 'South East', 51.1822, 0.1418, 'Europe', 49.0, '', 'Kent'),
#  (350901, 'Chilham Castle', None, None, 'se', 'South East', 51.2399, 0.9599, 'Europe', 58.0, '', 'Kent'),
#  (350906, 'Chipping Norton', None, None, 'se', 'South East', 51.9431, -1.5407, 'Europe', 207.0, '', 'Oxfordshire'),
#  (350918, 'Christ s College Ski Club Guildford', None, None, 'se', 'South East', 51.2609, -0.5777, 'Europe', 43.0, '', 'Surrey'),
#  (350921, 'Church Enstone', None, None, 'se', 'South East', 51.9243, -1.4506, 'Europe', 135.0, '', 'Oxfordshire'),
#  (350927, 'City Of Derry Airport', None, None, 'ni', 'Northern Ireland', 55.0413, -7.1576, 'Europe', 1.0, '', 'County Londonderry'),
#  (350928, 'City Of London', None, None, 'se', 'South East', 51.5102, -0.0837, 'Europe', 10.0, '', 'Greater London'),
#  (350929, 'City Of London Youth Hostel', None, None, 'se', 'South East', 51.5103, -0.0969, 'Europe', 1.0, '', 'Greater London'),
#  (350932, 'Clandon Park', None, None, 'se', 'South East', 51.2526, -0.5117, 'Europe', 67.0, '', 'Surrey'),
#  (350934, 'Claremont Landscape Garden', None, None, 'se', 'South East', 51.3554, -0.3741, 'Europe', 33.0, '', 'Surrey'),
#  (350938, 'Claydon House', None, None, 'se', 'South East', 51.9217, -0.9464, 'Europe', 100.0, '', 'Buckinghamshire'),
#  (350959, 'Cliveden', None, None, 'se', 'South East', 51.5568, -0.6846, 'Europe', 59.0, '', 'Buckinghamshire'),
#  (350966, 'Coalisland', None, None, 'ni', 'Northern Ireland', 54.5404, -6.6989, 'Europe', 31.0, '', 'County Tyrone'),
#  (350969, 'Cobham', None, None, 'se', 'South East', 51.3284, -0.4078, 'Europe', 23.0, '', 'Surrey'),
#  (350991, 'Comber', None, None, 'ni', 'Northern Ireland', 54.5505, -5.7444, 'Europe', 11.0, '', 'County Down'),
#  (351007, 'Cookstown', None, None, 'ni', 'Northern Ireland', 54.6454, -6.7455, 'Europe', 79.0, '', 'County Londonderry'),
#  (351010, 'Copnor', None, None, 'se', 'South East', 50.8156, -1.0632, 'Europe', 4.0, '', 'Portsmouth'),
#  (351021, 'Cosham', None, None, 'se', 'South East', 50.8448, -1.0623, 'Europe', 9.0, '', 'Portsmouth'),
#  (351029, 'County Ground Sussex C.C.C.', None, None, 'se', 'South East', 50.8299, -0.1623, 'Europe', 24.0, '', 'Brighton and Hove'),
#  (351048, 'Craigavon', None, None, 'ni', 'Northern Ireland', 54.4474, -6.372, 'Europe', 35.0, '', 'County Armagh'),
#  (351059, 'Cranbrook', None, None, 'se', 'South East', 51.0951, 0.5393, 'Europe', 70.0, '', 'Kent'),
#  (351060, 'Cranleigh', None, None, 'se', 'South East', 51.1416, -0.4818, 'Europe', 57.0, '', 'Surrey'),
#  (351088, 'Crom Estate (Nt)', None, None, 'ni', 'Northern Ireland', 54.1657, -7.4396, 'Europe', 43.0, '', 'County Fermanagh'),
#  (351102, 'Crossgar', None, None, 'ni', 'Northern Ireland', 54.3988, -5.7633, 'Europe', 19.0, '', 'County Down'),
#  (351104, 'Crossmaglen', None, None, 'ni', 'Northern Ireland', 54.0766, -6.6071, 'Europe', 137.0, '', 'County Armagh'),
#  (351106, 'Crowborough', None, None, 'se', 'South East', 51.0604, 0.1675, 'Europe', 185.0, '', 'East Sussex'),
#  (351112, 'Crowthorne', None, None, 'se', 'South East', 51.3657, -0.795, 'Europe', 87.0, '', 'Bracknell Forest'),
#  (351117, 'Crumlin', None, None, 'ni', 'Northern Ireland', 54.6206, -6.2167, 'Europe', 73.0, '', 'County Antrim'),
#  (351118, 'Crystal Palace F.C.', None, None, 'se', 'South East', 51.3971, -0.0848, 'Europe', 50.0, '', 'Greater London'),
#  (351119, 'Crystal Palace National Sports Centre', None, None, 'se', 'South East', 51.4213, -0.0702, 'Europe', 88.0, '', 'Greater London'),
#  (351120, 'Cuckfield', None, None, 'se', 'South East', 51.0053, -0.1421, 'Europe', 95.0, '', 'West Sussex'),
#  (351128, 'Cullybackey', None, None, 'ni', 'Northern Ireland', 54.8877, -6.3507, 'Europe', 68.0, '', 'County Antrim'),
#  (351142, 'Dagenham', None, None, 'se', 'South East', 51.54, 0.1478, 'Europe', 10.0, '', 'Greater London'),
#  (351167, 'Dartford', None, None, 'se', 'South East', 51.4457, 0.2185, 'Europe', 4.0, '', 'Kent'),
#  (351179, 'Deal', None, None, 'se', 'South East', 51.222, 1.4034, 'Europe', 2.0, '', 'Kent'),
#  (351186, 'Delamont Country Park', None, None, 'ni', 'Northern Ireland', 54.3784, -5.6794, 'Europe', 16.0, '', 'County Down'),
#  (351191, 'Denmans', None, None, 'se', 'South East', 50.8516, -0.6703, 'Europe', 20.0, '', 'West Sussex'),
#  (351198, 'Derrygonnelly', None, None, 'ni', 'Northern Ireland', 54.4189, -7.818, 'Europe', 65.0, '', 'County Fermanagh'),
#  (351199, 'Derrymore House (Nt)', None, None, 'ni', 'Northern Ireland', 54.19, -6.3948, 'Europe', 87.0, '', 'County Armagh'),
#  (351206, 'Didcot', None, None, 'se', 'South East', 51.6076, -1.2434, 'Europe', 67.0, '', 'Oxfordshire'),
#  (351216, 'Divis', None, None, 'ni', 'Northern Ireland', 54.6138, -6.0201, 'Europe', 483.0, '', 'County Antrim'),
#  (351222, 'Donaghadee', None, None, 'ni', 'Northern Ireland', 54.6417, -5.5351, 'Europe', 9.0, '', 'County Down'),
#  (351227, 'Dorney Court', None, None, 'se', 'South East', 51.5005, -0.6695, 'Europe', 21.0, '', 'Buckinghamshire'),
#  (351233, 'Dover Youth Hostel', None, None, 'se', 'South East', 51.1334, 1.2975, 'Europe', 23.0, '', 'Kent'),
#  (351234, 'Down House', None, None, 'se', 'South East', 51.3295, 0.0487, 'Europe', 139.0, '', 'Greater London'),
#  (351235, 'Down Royal Racecourse', None, None, 'ni', 'Northern Ireland', 54.4894, -6.1296, 'Europe', 33.0, '', 'County Antrim'),
#  (351239, 'Downpatrick', None, None, 'ni', 'Northern Ireland', 54.328, -5.7156, 'Europe', 4.0, '', 'County Down'),
#  (351240, 'Downpatrick Racecourse', None, None, 'ni', 'Northern Ireland', 54.3117, -5.7266, 'Europe', 8.0, '', 'County Down'),
#  (351241, 'Draperstown', None, None, 'ni', 'Northern Ireland', 54.7933, -6.7855, 'Europe', 76.0, '', 'County Londonderry'),
#  (351243, 'Drayton (Portsmouth)', None, None, 'se', 'South East', 50.8455, -1.0388, 'Europe', 10.0, '', 'Portsmouth'),
#  (351250, 'Dromara', None, None, 'ni', 'Northern Ireland', 54.3794, -6.017, 'Europe', 125.0, '', 'County Antrim'),
#  (351251, 'Dromore', None, None, 'ni', 'Northern Ireland', 54.4155, -6.1464, 'Europe', 82.0, '', 'County Down'),
#  (351277, 'Dundonald', None, None, 'ni', 'Northern Ireland', 54.5878, -5.7983, 'Europe', 24.0, '', 'County Down'),
#  (351280, 'Dungannon', None, None, 'ni', 'Northern Ireland', 54.5046, -6.7705, 'Europe', 106.0, '', 'County Tyrone'),
#  (351281, 'Dungannon Park', None, None, 'ni', 'Northern Ireland', 54.4933, -6.7636, 'Europe', 63.0, '', 'County Tyrone'),
#  (351282, 'Dungiven', None, None, 'ni', 'Northern Ireland', 54.9272, -6.9235, 'Europe', 81.0, '', 'County Londonderry'),
#  (351284, 'Dunmurry', None, None, 'ni', 'Northern Ireland', 54.5513, -6.0034, 'Europe', 26.0, '', 'County Antrim'),
#  (351297, 'Ealing', None, None, 'se', 'South East', 51.5117, -0.3023, 'Europe', 31.0, '', 'Greater London'),
#  (351301, 'Earl s Court Youth Hostel', None, None, 'se', 'South East', 51.4917, -0.1833, 'Europe', 6.0, '', 'Greater London'),
#  (351309, 'East Grinstead', None, None, 'se', 'South East', 51.1282, -0.0129, 'Europe', 125.0, '', 'West Sussex'),
#  (351316, 'East Meon', None, None, 'se', 'South East', 50.9939, -1.0362, 'Europe', 106.0, 'South Downs National Park', 'Hampshire'),
#  (351320, 'East Sussex National Golf Club', None, None, 'se', 'South East', 50.9396, 0.0953, 'Europe', 15.0, '', 'East Sussex'),
#  (351321, 'East Tisted', None, None, 'se', 'South East', 51.0834, -0.992, 'Europe', 153.0, 'South Downs National Park', 'Hampshire'),
#  (351322, 'East Wittering', None, None, 'se', 'South East', 50.7688, -0.87, 'Europe', 4.0, '', 'West Sussex'),
#  (351323, 'Eastbourne Youth Hostel', None, None, 'se', 'South East', 50.769, 0.255, 'Europe', 88.0, '', 'East Sussex'),
#  (351327, 'Eastleigh', None, None, 'se', 'South East', 50.9667, -1.3732, 'Europe', 15.0, '', 'Hampshire'),
#  (351328, 'Eastney', None, None, 'se', 'South East', 50.7877, -1.0517, 'Europe', 2.0, '', 'Portsmouth'),
#  (351344, 'Edenbridge', None, None, 'se', 'South East', 51.1958, 0.067, 'Europe', 41.0, '', 'Kent'),
#  (351362, 'Egham', None, None, 'se', 'South East', 51.4284, -0.5463, 'Europe', 17.0, '', 'Surrey'),
#  (351363, 'Eglinton', None, None, 'ni', 'Northern Ireland', 55.026, -7.1774, 'Europe', 14.0, '', 'County Londonderry'),
#  (351370, 'Ellen s Green', None, None, 'se', 'South East', 51.1078, -0.4291, 'Europe', 64.0, '', 'Surrey'),
#  (351374, 'Ellisfield', None, None, 'se', 'South East', 51.2119, -1.0902, 'Europe', 196.0, '', 'Hampshire'),
#  (351383, 'Emmetts Garden', None, None, 'se', 'South East', 51.2506, 0.1169, 'Europe', 196.0, '', 'Kent'),
#  (351385, 'Emsworth', None, None, 'se', 'South East', 50.8476, -0.9364, 'Europe', 3.0, '', 'Hampshire'),
#  (351387, 'Enfield', None, None, 'se', 'South East', 51.654, -0.0814, 'Europe', 30.0, '', 'Greater London'),
#  (351391, 'Epsom', None, None, 'se', 'South East', 51.3356, -0.2658, 'Europe', 43.0, '', 'Surrey'),
#  (351392, 'Epsom Downs Racecourse', None, None, 'se', 'South East', 51.307, -0.2518, 'Europe', 137.0, '', 'Surrey'),
#  (351401, 'Esher', None, None, 'se', 'South East', 51.3686, -0.3635, 'Europe', 38.0, '', 'Surrey'),
#  (351403, 'Eton', None, None, 'se', 'South East', 51.487, -0.6064, 'Europe', 20.0, '', 'Windsor and Maidenhead'),
#  (351409, 'Ewell', None, None, 'se', 'South East', 51.3507, -0.2513, 'Europe', 34.0, '', 'Surrey'),
#  (351410, 'Ewell Minnis', None, None, 'se', 'South East', 51.1437, 1.2308, 'Europe', 132.0, '', 'Kent'),
#  (351411, 'Exbury Gardens', None, None, 'se', 'South East', 50.7932, -1.4, 'Europe', 11.0, 'New Forest National Park', 'Hampshire'),
#  (351421, 'Eynsham', None, None, 'se', 'South East', 51.7812, -1.3755, 'Europe', 70.0, '', 'Oxfordshire'),
#  (351439, 'Fareham', None, None, 'se', 'South East', 50.8556, -1.1817, 'Europe', 20.0, '', 'Hampshire'),
#  (351440, 'Faringdon', None, None, 'se', 'South East', 51.6581, -1.5832, 'Europe', 100.0, '', 'Oxfordshire'),
#  (351441, 'Farlington', None, None, 'se', 'South East', 50.8467, -1.0286, 'Europe', 11.0, '', 'Portsmouth'),
#  (351442, 'Farnborough', None, None, 'se', 'South East', 51.2863, -0.7524, 'Europe', 70.0, '', 'Hampshire'),
#  (351448, 'Faversham', None, None, 'se', 'South East', 51.3155, 0.891, 'Europe', 9.0, '', 'Kent'),
#  (351456, 'Fenton House', None, None, 'se', 'South East', 51.5623, -0.1824, 'Europe', 114.0, '', 'Greater London'),
#  (351467, 'Fintona', None, None, 'ni', 'Northern Ireland', 54.4977, -7.3191, 'Europe', 101.0, '', 'County Tyrone'),
#  (351479, 'Fivemiletown', None, None, 'ni', 'Northern Ireland', 54.3773, -7.3169, 'Europe', 109.0, '', 'County Tyrone'),
#  (351481, 'Flamingo Park Hastings', None, None, 'se', 'South East', 50.8549, 0.5958, 'Europe', 1.0, '', 'East Sussex'),
#  (351482, 'Fleet', None, None, 'se', 'South East', 51.2768, -0.8411, 'Europe', 78.0, '', 'Hampshire'),
#  (351485, 'Florence Court (Nt)', None, None, 'ni', 'Northern Ireland', 54.257, -7.7303, 'Europe', 87.0, '', 'County Fermanagh'),
#  (351486, 'Florence Court Forest Park', None, None, 'ni', 'Northern Ireland', 54.237, -7.7523, 'Europe', 326.0, '', 'County Fermanagh'),
#  (351490, 'Folkestone Racecourse', None, None, 'se', 'South East', 51.092, 1.0317, 'Europe', 68.0, '', 'Kent'),
#  (351491, 'Folkestone Ski Centre', None, None, 'se', 'South East', 51.0856, 1.1652, 'Europe', 35.0, '', 'Kent'),
#  (351493, 'Fontwell Park Racecourse', None, None, 'se', 'South East', 50.8518, -0.6599, 'Europe', 21.0, '', 'West Sussex'),
#  (351497, 'Fordingbridge', None, None, 'se', 'South East', 50.9253, -1.7911, 'Europe', 28.0, '', 'Hampshire'),
#  (351506, 'Fort Fun Eastbourne', None, None, 'se', 'South East', 50.7823, 0.3192, 'Europe', 1.0, '', 'East Sussex'),
#  (351518, 'Freshwater', None, None, 'se', 'South East', 50.6802, -1.5217, 'Europe', 11.0, '', 'Isle of Wight'),
#  (351519, 'Frimley', None, None, 'se', 'South East', 51.3155, -0.7424, 'Europe', 66.0, '', 'Surrey'),
#  (351525, 'Fulham', None, None, 'se', 'South East', 51.4789, -0.1995, 'Europe', 1.0, '', 'Greater London'),
#  (351526, 'Fulham', None, None, 'se', 'South East', 51.4748, -0.2071, 'Europe', 22.0, '', 'Greater London'),
#  (351527, 'Fulham F.C.', None, None, 'se', 'South East', 51.4731, -0.2175, 'Europe', 1.0, '', 'Greater London'),
#  (351530, 'Furzey Gardens', None, None, 'se', 'South East', 50.9002, -1.6092, 'Europe', 74.0, 'New Forest National Park', 'Hampshire'),
#  (351546, 'Garvagh', None, None, 'ni', 'Northern Ireland', 54.9845, -6.6873, 'Europe', 74.0, '', 'County Londonderry'),
#  (351557, 'George Best Belfast City Airport', None, None, 'ni', 'Northern Ireland', 54.6249, -5.8704, 'Europe', 4.0, '', 'County Antrim'),
#  (351558, 'Gerrards Cross', None, None, 'se', 'South East', 51.5819, -0.556, 'Europe', 83.0, '', 'Buckinghamshire'),
#  (351559, 'Giant s Causeway', None, None, 'ni', 'Northern Ireland', 55.239, -6.5061, 'Europe', 80.0, '', 'County Antrim'),
#  (351568, 'Gilford', None, None, 'ni', 'Northern Ireland', 54.372, -6.3582, 'Europe', 26.0, '', 'County Down'),
#  (351571, 'Gillingham F.C.', None, None, 'se', 'South East', 51.3848, 0.5632, 'Europe', 34.0, '', 'Medway'),
#  (351593, 'Glenarm Castle Walled Garden', None, None, 'ni', 'Northern Ireland', 54.9621, -5.9612, 'Europe', 19.0, '', 'County Antrim'),
#  (351611, 'Glyndebourne', None, None, 'se', 'South East', 50.8798, 0.0561, 'Europe', 53.0, 'South Downs National Park', 'East Sussex'),
#  (351613, 'Godalming', None, None, 'se', 'South East', 51.1853, -0.6113, 'Europe', 46.0, '', 'Surrey'),
#  (351624, 'Goodnestone Park', None, None, 'se', 'South East', 51.2458, 1.2244, 'Europe', 51.0, '', 'Kent'),
#  (351625, 'Goodwood Racecourse', None, None, 'se', 'South East', 50.8986, -0.7322, 'Europe', 149.0, 'South Downs National Park', 'West Sussex'),
#  (351626, 'Goodworth Clatford', None, None, 'se', 'South East', 51.1779, -1.4846, 'Europe', 55.0, '', 'Hampshire'),
#  (351637, 'Gosport', None, None, 'se', 'South East', 50.7945, -1.1161, 'Europe', 1.0, '', 'Hampshire'),
#  (351652, 'Gray s Printing Press (Nt)', None, None, 'ni', 'Northern Ireland', 54.8148, -7.4542, 'Europe', 8.0, '', 'County Tyrone'),
#  (351659, 'Great Comp Garden', None, None, 'se', 'South East', 51.2836, 0.3475, 'Europe', 114.0, '', 'Kent'),
#  (351661, 'Great Dixter', None, None, 'se', 'South East', 50.9978, 0.5918, 'Europe', 40.0, '', 'East Sussex'),
#  (351669, 'Great Linford', None, None, 'se', 'South East', 52.0676, -0.7622, 'Europe', 84.0, '', 'Milton Keynes'),
#  (351683, 'Greenwich', None, None, 'se', 'South East', 51.4779, -0.01, 'Europe', 6.0, '', 'Greater London'),
#  (351688, 'Grey Abbey Physic Garden', None, None, 'ni', 'Northern Ireland', 54.5345, -5.5544, 'Europe', 18.0, '', 'County Down'),
#  (351689, 'Grey s Court', None, None, 'se', 'South East', 51.5471, -0.9503, 'Europe', 107.0, '', 'Oxfordshire'),
#  (351694, 'Groombridge Place Gardens', None, None, 'se', 'South East', 51.1166, 0.1832, 'Europe', 47.0, '', 'Kent'),
#  (351706, 'Guy L. Wilson Daffodil Garden', None, None, 'ni', 'Northern Ireland', 55.1445, -6.6688, 'Europe', 15.0, '', 'County Londonderry'),
#  (351713, 'Hackney', None, None, 'se', 'South East', 51.5458, -0.0549, 'Europe', 16.0, '', 'Greater London'),
#  (351723, 'Hailsham', None, None, 'se', 'South East', 50.8641, 0.2568, 'Europe', 29.0, '', 'East Sussex'),
#  (351733, 'Hall Place Garden (Leigh)', None, None, 'se', 'South East', 51.1955, 0.2094, 'Europe', 38.0, '', 'Kent'),
#  (351743, 'Hammersmith', None, None, 'se', 'South East', 51.49, -0.2256, 'Europe', 5.0, '', 'Greater London'),
#  (351744, 'Hammersmith', None, None, 'se', 'South East', 51.49234, -0.223635, 'Europe', 13.0, '', 'Greater London'),
#  (351746, 'Hampstead Heath Youth Hostel', None, None, 'se', 'South East', 51.5705, -0.1797, 'Europe', 97.0, '', 'Greater London'),
#  (351747, 'Hampton Court Palace', None, None, 'se', 'South East', 51.4007, -0.3337, 'Europe', 4.0, '', 'Greater London'),
#  (351755, 'Harbour Park Amusements Littlehampton', None, None, 'se', 'South East', 50.802, -0.5369, 'Europe', 1.0, '', 'West Sussex'),
#  (351761, 'Haremere Hall', None, None, 'se', 'South East', 51.0114, 0.4564, 'Europe', 19.0, '', 'East Sussex'),
#  (351763, 'Harringay', None, None, 'se', 'South East', 51.582, -0.1027, 'Europe', 19.0, '', 'Greater London'),
#  (351771, 'Harrow', None, None, 'se', 'South East', 51.5801, -0.3404, 'Europe', 64.0, '', 'Greater London'),
#  (351774, 'Hartley', None, None, 'se', 'South East', 51.3847, 0.3066, 'Europe', 101.0, '', 'Kent'),
#  (351779, 'Hastings Youth Hostel', None, None, 'se', 'South East', 50.8895, 0.623, 'Europe', 75.0, '', 'East Sussex'),
#  (351780, 'Hatchlands Park', None, None, 'se', 'South East', 51.261, -0.4717, 'Europe', 81.0, '', 'Surrey'),
#  (351790, 'Havant', None, None, 'se', 'South East', 50.8587, -0.9825, 'Europe', 11.0, '', 'Hampshire'),
#  (351796, 'Hawkhurst', None, None, 'se', 'South East', 51.0462, 0.5111, 'Europe', 71.0, '', 'Kent'),
#  (351808, 'Haywards Heath', None, None, 'se', 'South East', 50.9985, -0.1048, 'Europe', 74.0, '', 'West Sussex'),
#  (351822, 'Heathfield', None, None, 'se', 'South East', 50.9726, 0.2628, 'Europe', 182.0, '', 'East Sussex'),
#  (351832, 'Heckfield', None, None, 'se', 'South East', 51.3392, -0.9586, 'Europe', 74.0, '', 'Hampshire'),
#  (351836, 'Hedge End', None, None, 'se', 'South East', 50.9108, -1.3052, 'Europe', 38.0, '', 'Hampshire'),
#  (351852, 'Henfield', None, None, 'se', 'South East', 50.9293, -0.268, 'Europe', 32.0, '', 'West Sussex'),
#  (351856, 'Herne Bay', None, None, 'se', 'South East', 51.3704, 1.1295, 'Europe', 3.0, '', 'Kent'),
#  (351859, 'Herstmonceux Castle', None, None, 'se', 'South East', 50.8714, 0.341, 'Europe', 19.0, '', 'East Sussex'),
#  (351865, 'Hever Castle Gardens', None, None, 'se', 'South East', 51.1933, 0.1251, 'Europe', 44.0, '', 'Kent'),
#  (351871, 'Hezlett House (Nt)', None, None, 'ni', 'Northern Ireland', 55.1587, -6.7908, 'Europe', 31.0, '', 'County Londonderry'),
#  (351874, 'High Beeches (Handcross)', None, None, 'se', 'South East', 51.0595, -0.1728, 'Europe', 114.0, '', 'West Sussex'),
#  (351875, 'High Beeches (Uckfield)', None, None, 'se', 'South East', 50.9631, 0.0706, 'Europe', 25.0, '', 'East Sussex'),
#  (351879, 'High Wycombe', None, None, 'se', 'South East', 51.6282, -0.7467, 'Europe', 67.0, '', 'Buckinghamshire'),
#  (351884, 'Highcliffe', None, None, 'se', 'South East', 50.737, -1.693, 'Europe', 1.0, '', 'Dorset'),
#  (351896, 'Hillesden', None, None, 'se', 'South East', 51.9534, -1.0006, 'Europe', 102.0, '', 'Buckinghamshire'),
#  (351897, 'Hillingdon', None, None, 'se', 'South East', 51.5334, -0.4527, 'Europe', 51.0, '', 'Greater London'),
#  (351899, 'Hillsborough (Lisburn)', None, None, 'ni', 'Northern Ireland', 54.4631, -6.082, 'Europe', 91.0, '', 'County Antrim'),
#  (351901, 'Hilsea', None, None, 'se', 'South East', 50.8245, -1.0639, 'Europe', 4.0, '', 'Portsmouth'),
#  (351903, 'Hindhead Youth Hostel', None, None, 'se', 'South East', 51.1201, -0.7238, 'Europe', 171.0, '', 'Surrey'),
#  (351905, 'Hinton Ampner Garden', None, None, 'se', 'South East', 51.04, -1.1513, 'Europe', 79.0, 'South Downs National Park', 'Hampshire'),
#  (351918, 'Holland House Youth Hostel', None, None, 'se', 'South East', 51.502, -0.1998, 'Europe', 24.0, '', 'Greater London'),
#  (351921, 'Holmbury St. Mary Youth Hostel', None, None, 'se', 'South East', 51.1954, -0.4215, 'Europe', 160.0, '', 'Surrey'),
#  (351930, 'Holywood', None, None, 'ni', 'Northern Ireland', 54.6428, -5.8238, 'Europe', 25.0, '', 'County Down'),
#  (351935, 'Hook', None, None, 'se', 'South East', 51.2777, -0.9629, 'Europe', 87.0, '', 'Hampshire'),
#  (351941, 'Horley', None, None, 'se', 'South East', 51.173, -0.1705, 'Europe', 54.0, '', 'Surrey'),
#  (351943, 'Horndean', None, None, 'se', 'South East', 50.9154, -1.0008, 'Europe', 90.0, '', 'Hampshire'),
#  (351953, 'Houghton Lodge', None, None, 'se', 'South East', 51.0981, -1.5044, 'Europe', 33.0, '', 'Hampshire'),
#  (351956, 'Hounslow', None, None, 'se', 'South East', 51.4655, -0.3605, 'Europe', 20.0, '', 'Greater London'),
#  (351982, 'Hurstpierpoint', None, None, 'se', 'South East', 50.9339, -0.1783, 'Europe', 50.0, '', 'West Sussex'),
#  (351986, 'Hythe', None, None, 'se', 'South East', 51.0712, 1.0836, 'Europe', 8.0, '', 'Kent'),
#  (351989, 'Iden Croft Herbs Staplehurst', None, None, 'se', 'South East', 51.1525, 0.5609, 'Europe', 26.0, '', 'Kent'),
#  (351996, 'Ilford', None, None, 'se', 'South East', 51.5562, 0.0779, 'Europe', 12.0, '', 'Greater London'),
#  (352035, 'Isle Of Wight (Sandown) Airport', None, None, 'se', 'South East', 50.652, -1.1887, 'Europe', 36.0, '', 'Isle of Wight'),
#  (352036, 'Islington', None, None, 'se', 'South East', 51.5353, -0.102, 'Europe', 47.0, '', 'Greater London'),
#  (352037, 'Ivinghoe Youth Hostel', None, None, 'se', 'South East', 51.8328, -0.6301, 'Europe', 114.0, '', 'Buckinghamshire'),
#  (352042, 'Jenkyn Place Gardens', None, None, 'se', 'South East', 51.1925, -0.8842, 'Europe', 110.0, '', 'Hampshire'),
#  (352049, 'Jordans Youth Hostel', None, None, 'se', 'South East', 51.6086, -0.5832, 'Europe', 95.0, '', 'Buckinghamshire'),
#  (352055, 'Keady', None, None, 'ni', 'Northern Ireland', 54.2483, -6.7035, 'Europe', 157.0, '', 'County Armagh'),
# ...
#  (354379, 'The Mall', None, None, 'se', 'South East', 51.505, -0.132, 'Europe', 7.0, '', 'Greater London'),
#  (354380, 'Wembley Arena', None, None, 'se', 'South East', 51.558, -0.283, 'Europe', 38.0, '', 'Greater London'),
#  (354423, 'Magilligan Strand, Benone (Beach)', None, None, 'ni', 'Northern Ireland', 55.1683, -6.8155, 'Europe', 0.0, '', 'County Londonderry'),
#  (354424, 'Magilligan - Downhill (Beach)', None, None, 'ni', 'Northern Ireland', 55.1667, -6.8632, 'Europe', 0.0, '', 'County Londonderry'),
#  (354425, 'Portstewart (The Strand)(Beach)', None, None, 'ni', 'Northern Ireland', 55.1682, -6.7868, 'Europe', 0.0, '', 'County Londonderry'),
#  (354426, 'Portrush - Mill (West) Strand (Beach)', None, None, 'ni', 'Northern Ireland', 55.2045, -6.655, 'Europe', 0.0, '', 'County Londonderry'),
#  (354427, 'Portrush, Whiterocks (Beach)', None, None, 'ni', 'Northern Ireland', 55.2063, -6.6084, 'Europe', 0.0, '', 'County Londonderry'),
#  (354428, 'Portrush - Curran (East) Strand (Beach)', None, None, 'ni', 'Northern Ireland', 55.2238, -6.5244, 'Europe', 0.0, '', 'County Antrim'),
#  (354429, 'Ballygally (Beach)', None, None, 'ni', 'Northern Ireland', 54.8992, -5.8589, 'Europe', 0.0, '', 'County Antrim'),
#  (354430, 'Helens Bay (Beach)', None, None, 'ni', 'Northern Ireland', 54.672, -5.7342, 'Europe', 0.0, '', 'County Down'),
#  (354431, 'Murlough (Tyrella), Newcastle (Beach)', None, None, 'ni', 'Northern Ireland', 54.5681, -5.6876, 'Europe', 0.0, '', 'County Down'),
#  (354432, 'Tyrella Beach (Clough) (Beach)', None, None, 'ni', 'Northern Ireland', 54.2533, -5.8102, 'Europe', 0.0, '', 'County Down'),
#  (354647, 'Totland Bay (Beach)', None, None, 'se', 'South East', 50.6826, -1.5445, 'Europe', 0.0, '', 'Isle of Wight'),
#  (354648, 'Colwell Bay (Beach)', None, None, 'se', 'South East', 50.6918, -1.5353, 'Europe', 0.0, '', 'Isle of Wight'),
#  (354649, 'Cowes (Beach)', None, None, 'se', 'South East', 50.7672, -1.3079, 'Europe', 0.0, '', 'Isle of Wight'),
#  (354650, 'Ryde - East (Beach)', None, None, 'se', 'South East', 50.7315, -1.1519, 'Europe', 0.0, '', 'Isle of Wight'),
#  (354651, 'Seagrove (Beach)', None, None, 'se', 'South East', 50.7157, -1.1068, 'Europe', 0.0, '', 'Isle of Wight'),
#  (354652, 'St Helens (Beach)', None, None, 'se', 'South East', 50.6988, -1.0986, 'Europe', 0.0, '', 'Isle of Wight'),
#  (354653, 'Whitecliff Bay (Beach)', None, None, 'se', 'South East', 50.6699, -1.0969, 'Europe', 0.0, '', 'Isle of Wight'),
#  (354654, 'Sandown - Yaverland (Beach)', None, None, 'se', 'South East', 50.6613, -1.1357, 'Europe', 0.0, '', 'Isle of Wight'),
#  (354655, 'Sandown (Beach)', None, None, 'se', 'South East', 50.6545, -1.1518, 'Europe', 0.0, '', 'Isle of Wight'),
#  (354656, 'Ventnor (Beach)', None, None, 'se', 'South East', 50.5931, -1.2084, 'Europe', 0.0, '', 'Isle of Wight'),
#  (354657, 'Compton Bay (Beach)', None, None, 'se', 'South East', 50.658, -1.4708, 'Europe', 0.0, '', 'Isle of Wight'),
#  (354658, 'Christchurch Bay (Barton-On-Sea) (Beach)', None, None, 'se', 'South East', 50.7341, -1.6559, 'Europe', 0.0, '', 'Hampshire'),
#  (354659, 'Milford-On-Sea (Beach)', None, None, 'se', 'South East', 50.7225, -1.5981, 'Europe', 0.0, '', 'Hampshire'),
#  (354660, 'Lepe (Beach)', None, None, 'se', 'South East', 50.784, -1.3528, 'Europe', 0.0, '', 'Hampshire'),
#  (354661, 'Calshot (Beach)', None, None, 'se', 'South East', 50.809, -1.3186, 'Europe', 0.0, '', 'Hampshire'),
#  (354662, 'Hill Head (Beach)', None, None, 'se', 'South East', 50.8129, -1.2231, 'Europe', 0.0, '', 'Hampshire'),
#  (354663, 'Lee-On-Solent (Beach)', None, None, 'se', 'South East', 50.8008, -1.2038, 'Europe', 0.0, '', 'Hampshire'),
#  (354664, 'Old Portsmouth Beach (Victoria Pier) (Beach)', None, None, 'se', 'South East', 50.7901, -1.108, 'Europe', 0.0, '', 'Portsmouth'),
#  (354665, 'Eastney (Beach)', None, None, 'se', 'South East', 50.7849, -1.0469, 'Europe', 0.0, '', 'Portsmouth'),
#  (354666, 'Hayling Island - West Hayling (Beach)', None, None, 'se', 'South East', 50.7845, -0.9974, 'Europe', 0.0, '', 'Hampshire'),
#  (354667, 'Hayling Island - West Beachlands (Beach)', None, None, 'se', 'South East', 50.7838, -0.9889, 'Europe', 0.0, '', 'Hampshire'),
#  (354668, 'Hayling Island - West Of Eastoke (Beach)', None, None, 'se', 'South East', 50.781, -0.9671, 'Europe', 0.0, '', 'Hampshire'),
#  (354669, 'West Wittering (Beach)', None, None, 'se', 'South East', 50.7768, -0.9104, 'Europe', 0.0, '', 'West Sussex'),
#  (354670, 'Bracklesham Bay (Beach)', None, None, 'se', 'South East', 50.7609, -0.8604, 'Europe', 0.0, '', 'West Sussex'),
#  (354671, 'Selsey (Beach)', None, None, 'se', 'South East', 50.7278, -0.78, 'Europe', 0.0, '', 'West Sussex'),
#  (354672, 'Pagham (Beach)', None, None, 'se', 'South East', 50.7675, -0.7375, 'Europe', 0.0, '', 'West Sussex'),
#  (354673, 'Bognor Regis - East (Beach)', None, None, 'se', 'South East', 50.7821, -0.6709, 'Europe', 0.0, '', 'West Sussex'),
#  (354674, 'Felpham (Beach)', None, None, 'se', 'South East', 50.7876, -0.6409, 'Europe', 0.0, '', 'West Sussex'),
#  (354675, 'Middleton-On-Sea (Beach)', None, None, 'se', 'South East', 50.7909, -0.6048, 'Europe', 0.0, '', 'West Sussex'),
#  (354676, 'Littlehampton (Beach)', None, None, 'se', 'South East', 50.8022, -0.5282, 'Europe', 0.0, '', 'West Sussex'),
#  (354677, 'Worthing (Beach)', None, None, 'se', 'South East', 50.8075, -0.3837, 'Europe', 0.0, '', 'West Sussex'),
#  (354678, 'Southwick (Beach)', None, None, 'se', 'South East', 50.8287, -0.2368, 'Europe', 0.0, '', 'West Sussex'),
#  (354679, 'Hove West (Beach)', None, None, 'se', 'South East', 50.8223, -0.1592, 'Europe', 0.0, '', 'Brighton and Hove'),
#  (354680, 'Saltdean (Beach)', None, None, 'se', 'South East', 50.8002, -0.0415, 'Europe', 0.0, '', 'East Sussex'),
#  (354681, 'Newhaven - West Quay (Beach)', None, None, 'se', 'South East', 50.7805, 0.0503, 'Europe', 0.0, '', 'East Sussex'),
#  (354682, 'Seaford Bay (Beach)', None, None, 'se', 'South East', 50.7743, 0.0892, 'Europe', 0.0, '', 'East Sussex'),
#  (354683, 'Birling Gap (Beach)', None, None, 'se', 'South East', 50.743, 0.2004, 'Europe', 0.0, '', 'East Sussex'),
#  (354684, 'Eastbourne (Beach)', None, None, 'se', 'South East', 50.7626, 0.2878, 'Europe', 0.0, '', 'East Sussex'),
#  (354685, 'Pevensey Bay (Beach)', None, None, 'se', 'South East', 50.8109, 0.3516, 'Europe', 0.0, '', 'East Sussex'),
#  (354686, 'Normans Bay (Beach)', None, None, 'se', 'South East', 50.8223, 0.3832, 'Europe', 0.0, '', 'East Sussex'),
#  (354687, 'Cooden Beach (Beach)', None, None, 'se', 'South East', 50.8327, 0.431, 'Europe', 0.0, '', 'East Sussex'),
#  (354688, 'St. Leonards (Beach)', None, None, 'se', 'South East', 50.8505, 0.5534, 'Europe', 0.0, '', 'East Sussex'),
#  (354689, 'Winchelsea (Beach)', None, None, 'se', 'South East', 50.9131, 0.7289, 'Europe', 0.0, '', 'East Sussex'),
#  (354690, 'Brighton (Beach)', None, None, 'se', 'South East', 50.8179, -0.1296, 'Europe', 0.0, '', 'Brighton and Hove'),
#  (354691, 'Dymchurch (Beach)', None, None, 'se', 'South East', 51.0339, 1.0122, 'Europe', 0.0, '', 'Kent'),
#  (354692, 'Hythe (Beach)', None, None, 'se', 'South East', 51.0653, 1.0836, 'Europe', 0.0, '', 'Kent'),
#  (354693, 'Sandgate Beach', None, None, 'se', 'South East', 51.0721, 1.1348, 'Europe', 0.0, '', 'Kent'),
#  (354694, 'Folkestone (Beach)', None, None, 'se', 'South East', 51.0816, 1.191, 'Europe', 0.0, '', 'Kent'),
#  (354695, 'Dover Harbour (Beach)', None, None, 'se', 'South East', 51.1211, 1.3144, 'Europe', 0.0, '', 'Kent'),
#  (354696, 'St Margarets Bay (Beach)', None, None, 'se', 'South East', 51.1493, 1.387, 'Europe', 0.0, '', 'Kent'),
#  (354697, 'Sandwich Bay (Beach)', None, None, 'se', 'South East', 51.2819, 1.3801, 'Europe', 0.0, '', 'Kent'),
#  (354698, 'Ramsgate - Pegwell Bay (Beach)', None, None, 'se', 'South East', 51.3348, 1.4279, 'Europe', 0.0, '', 'Kent'),
#  (354699, 'Joss Bay (Beach)', None, None, 'se', 'South East', 51.3794, 1.4464, 'Europe', 0.0, '', 'Kent'),
#  (354700, 'Margate - Fulsam Rock (Beach)', None, None, 'se', 'South East', 51.3928, 1.3858, 'Europe', 0.0, '', 'Kent'),
#  (354701, 'Westbrook Bay (Beach)', None, None, 'se', 'South East', 51.3856, 1.3632, 'Europe', 0.0, '', 'Kent'),
#  (354702, 'Leysdown-On-Sea (Beach)', None, None, 'se', 'South East', 51.4024, 0.9174, 'Europe', 0.0, '', 'Kent'),
#  (354703, 'Sheerness (Beach)', None, None, 'se', 'South East', 51.4404, 0.7719, 'Europe', 0.0, '', 'Kent'),
#  (354704, 'Minster Leas (Beach)', None, None, 'se', 'South East', 51.4332, 0.8041, 'Europe', 0.0, '', 'Kent'),
#  (354853, 'Tolleymore Forest Park', None, None, 'ni', 'Northern Ireland', 54.2185, -5.9457, 'Europe', 110.0, 'The Mournes', 'County Down'),
#  (354854, 'Kilbroney Park Rostrevor', None, None, 'ni', 'Northern Ireland', 54.0956, -6.1888, 'Europe', 30.0, 'The Mournes', 'County Armagh'),
#  (354855, 'Donard Park Newcastle', None, None, 'ni', 'Northern Ireland', 54.2026, -5.8994, 'Europe', 63.0, 'The Mournes', 'County Down'),
#  (354871, 'Ditchling Beacon', None, None, 'se', 'South East', 50.9009, -0.1083, 'Europe', 230.0, 'South Downs National Park', 'East Sussex'),
#  (354992, 'Burley', None, None, 'se', 'South East', 50.8264, -1.7017, 'Europe', 70.0, 'New Forest National Park', 'Hampshire'),
#  (354993, 'Butser Hill', None, None, 'se', 'South East', 50.9778, -0.9803, 'Europe', 260.0, 'South Downs National Park', 'Hampshire'),
#  (354996, 'South Harting', None, None, 'se', 'South East', 50.9698, -0.8824, 'Europe', 64.0, 'South Downs National Park', 'West Sussex'),
#  (354997, 'Littleton Down', None, None, 'se', 'South East', 50.9257, -0.6572, 'Europe', 178.0, 'South Downs National Park', 'West Sussex'),
#  (354998, 'Chanctonbury Hill', None, None, 'se', 'South East', 50.8956, -0.3931, 'Europe', 248.0, 'South Downs National Park', 'West Sussex'),
#  (355001, 'Spelga Dam', None, None, 'ni', 'Northern Ireland', 54.1747, -6.0618, 'Europe', 334.0, 'The Mournes', 'County Armagh'),
#  (370092, 'Eastbourne (Aurn)', None, None, 'se', 'South East', 50.7617, 0.2843, 'Europe', 28.0, '', 'East Sussex'),
#  (371330, 'Agnew s Hill', None, None, 'ni', 'Northern Ireland', 54.8466, -5.9358, 'Europe', 476.0, '', 'County Antrim'),
#  (371348, 'Belfast Newforge', None, None, 'ni', 'Northern Ireland', 54.56056, -5.94232, 'Europe', 40.0, '', 'County Antrim'),
#  (371351, 'Benbradagh', None, None, 'ni', 'Northern Ireland', 54.9423, -6.8677, 'Europe', 468.0, '', 'County Londonderry'),
#  (371366, 'Bodiam', None, None, 'se', 'South East', 50.99523, 0.54399, 'Europe', 22.0, '', 'East Sussex'),
#  (371385, 'Carnanelly', None, None, 'ni', 'Northern Ireland', 54.7726, -6.9498, 'Europe', 564.0, '', 'County Tyrone'),
#  (371390, 'Carntogher', None, None, 'ni', 'Northern Ireland', 54.8962, -6.7602, 'Europe', 464.0, '', 'County Londonderry'),
#  (371395, 'Chimney Rock', None, None, 'ni', 'Northern Ireland', 54.1643, -5.9124, 'Europe', 655.0, '', 'County Armagh'),
#  (371397, 'Claudy', None, None, 'ni', 'Northern Ireland', 54.9133, -7.1545, 'Europe', 113.0, '', 'County Londonderry'),
#  (371399, 'Cock Mountain', None, None, 'ni', 'Northern Ireland', 54.1736, -6.0778, 'Europe', 507.0, '', 'County Armagh'),
#  (371417, 'Crockbrack', None, None, 'ni', 'Northern Ireland', 54.8042, -6.8869, 'Europe', 528.0, '', 'County Londonderry'),
#  (371425, 'Dart Mountain', None, None, 'ni', 'Northern Ireland', 54.8112, -7.0608, 'Europe', 619.0, '', 'County Tyrone'),
#  (371441, 'Eagle Mountain', None, None, 'ni', 'Northern Ireland', 54.1397, -6.0951, 'Europe', 635.0, '', 'County Armagh'),
#  (371444, 'Edenbridge', None, None, 'se', 'South East', 51.20346, 0.1362, 'Europe', 45.0, '', 'Kent'),
#  (371457, 'Faversham', None, None, 'se', 'South East', 51.29654, 0.87959, 'Europe', 46.0, '', 'Kent'),
#  (371460, 'Finlieve', None, None, 'ni', 'Northern Ireland', 54.1181, -6.1083, 'Europe', 575.0, '', 'County Armagh'),
#  (371494, 'Hampton W Wks', None, None, 'se', 'South East', 51.41194, -0.3781, 'Europe', 12.0, '', 'Greater London'),
#  (371521, 'Iniscarn Forest', None, None, 'ni', 'Northern Ireland', 54.7467, -6.7381, 'Europe', 496.0, '', 'County Londonderry'),
#  (371523, 'Invinestown', None, None, 'ni', 'Northern Ireland', 54.4748, -7.6331, 'Europe', 97.0, '', 'County Fermanagh'),
#  (371531, 'Knocklayd', None, None, 'ni', 'Northern Ireland', 55.1622, -6.2494, 'Europe', 517.0, '', 'County Antrim'),
#  (371547, 'Lough Cowey', None, None, 'ni', 'Northern Ireland', 54.41412, -5.53801, 'Europe', 10.0, '', 'County Down'),
#  (371554, 'Martyr Worthy', None, None, 'se', 'South East', 51.10244, -1.26151, 'Europe', 85.0, '', 'Hampshire'),
#  (371556, 'Meenard Mountain', None, None, 'ni', 'Northern Ireland', 54.8295, -6.9533, 'Europe', 628.0, '', 'County Tyrone'),
#  (371573, 'Mullaghaneany', None, None, 'ni', 'Northern Ireland', 54.8313, -6.9342, 'Europe', 631.0, '', 'County Tyrone'),
#  (371574, 'Mullaghash', None, None, 'ni', 'Northern Ireland', 54.8623, -6.9995, 'Europe', 480.0, '', 'County Londonderry'),
#  (371575, 'Mullaghcarn', None, None, 'ni', 'Northern Ireland', 54.6742, -7.2038, 'Europe', 542.0, '', 'County Tyrone'),
#  (371576, 'Mullaghcloga', None, None, 'ni', 'Northern Ireland', 54.8058, -7.1317, 'Europe', 636.0, '', 'County Tyrone'),
#  (371577, 'Mullaghclogher', None, None, 'ni', 'Northern Ireland', 54.7982, -7.1767, 'Europe', 577.0, '', 'County Tyrone'),
#  (371578, 'Mullaghmore', None, None, 'ni', 'Northern Ireland', 54.8508, -6.8493, 'Europe', 556.0, '', 'County Londonderry'),
#  (371586, 'North Heath', None, None, 'se', 'South East', 50.99321, -0.47659, 'Europe', 21.0, '', 'West Sussex'),
#  (371587, 'Nutt s Corner', None, None, 'ni', 'Northern Ireland', 54.638, -6.1443, 'Europe', 104.0, '', 'County Antrim'),
#  (371589, 'Oughtvabeg', None, None, 'ni', 'Northern Ireland', 54.8085, -6.9712, 'Europe', 480.0, '', 'County Tyrone'),
#  (371608, 'Reading University, Whiteknights', None, None, 'se', 'South East', 51.44128, -0.93813, 'Europe', 66.0, '', 'Wokingham'),
#  (371622, 'Sawel Mountain', None, None, 'ni', 'Northern Ireland', 54.8191, -7.0365, 'Europe', 683.0, '', 'County Londonderry'),
#  (371635, 'Slieve Bearnagh', None, None, 'ni', 'Northern Ireland', 54.1872, -5.9885, 'Europe', 730.0, '', 'County Down'),
#  (371636, 'Slieve Binnian', None, None, 'ni', 'Northern Ireland', 54.1447, -5.9823, 'Europe', 747.0, '', 'County Armagh'),
#  (371637, 'Slieve Croob', None, None, 'ni', 'Northern Ireland', 54.3399, -5.974, 'Europe', 535.0, '', 'County Down'),
#  (371638, 'Slieve Donard', None, None, 'ni', 'Northern Ireland', 54.1816, -5.9233, 'Europe', 852.0, '', 'County Armagh'),
#  (371639, 'Slieve Gallion', None, None, 'ni', 'Northern Ireland', 54.7311, -6.7605, 'Europe', 528.0, '', 'County Londonderry'),
#  (371640, 'Slieve Gullion', None, None, 'ni', 'Northern Ireland', 54.121, -6.432, 'Europe', 577.0, '', 'County Armagh'),
#  (371641, 'Slieve Much', None, None, 'ni', 'Northern Ireland', 54.1599, -6.0393, 'Europe', 674.0, '', 'County Armagh'),
#  (371642, 'Slieveanorra', None, None, 'ni', 'Northern Ireland', 55.0739, -6.2235, 'Europe', 511.0, '', 'County Antrim'),
#  (371643, 'Slieveavaddy', None, None, 'ni', 'Northern Ireland', 54.7736, -6.9174, 'Europe', 488.0, '', 'County Londonderry'),
#  (371644, 'Slievelamagan', None, None, 'ni', 'Northern Ireland', 54.1687, -5.9658, 'Europe', 702.0, '', 'County Armagh'),
#  (371645, 'Slievemartin', None, None, 'ni', 'Northern Ireland', 54.0942, -6.1628, 'Europe', 485.0, '', 'County Armagh'),
#  (371646, 'Slievenanee', None, None, 'ni', 'Northern Ireland', 55.0272, -6.1781, 'Europe', 543.0, '', 'County Antrim'),
#  (371650, 'St Helens', None, None, 'se', 'South East', 50.697, -1.1123, 'Europe', 28.0, '', 'Isle of Wight'),
#  (371658, 'Templepatrick', None, None, 'ni', 'Northern Ireland', 54.7029, -6.0971, 'Europe', 56.0, '', 'County Antrim'),
#  (371666, 'Toome Bridge', None, None, 'ni', 'Northern Ireland', 54.7512, -6.4545, 'Europe', 18.0, '', 'County Antrim'),
#  (371667, 'Trostan', None, None, 'ni', 'Northern Ireland', 55.0456, -6.1524, 'Europe', 554.0, '', 'County Antrim'),
#  (371682, 'White Mountain', None, None, 'ni', 'Northern Ireland', 54.8611, -6.8453, 'Europe', 536.0, '', 'County Londonderry')]

# %% [markdown]
# ## Filtering NULL Values
# Query data and filter rows with a condition in NULL fields
# ```sql
# SELECT field1, field 2 FROM Table
# WHERE field IS [NOT] NULL
# ```
# Example: Query all data from table cat_locations where region is equal to NULL

# %%
# %%sql
# SELECT * FROM cat_locations WHERE region IS NULL;
# Out:
#  * sqlite:///weather.db
# Done.
# [(400003, 'High Beach', None, 'UK', None, '', 51.66, 0.04, 'Europe', 110.0, None, None),
#  (400004, 'London St James Park', None, 'UK', None, '', 51.5, 0.13, 'Europe', 5.0, None, None)]

# %% [markdown]
# ## Ordering Results
# Sort the result set in ascending or descending order
# ```sql
# SELECT field1, field 2 FROM Table
# ORDER BY Field ASC [DESC]
# ```
# Example: Select all fields from cat_locations where region is not 'se' and order it by Location

# %%
# %%sql
# SELECT * FROM cat_locations
# WHERE region <> 'se' ORDER BY Location ;
# Out:
#  * sqlite:///weather.db
# Done.
# [(350001, 'A  Bhuidheanach Bheag', None, None, 'ta', 'Central Tayside and Fife', 56.8716, -4.1969, 'Europe', 936.0, '', 'Perth and Kinross'),
#  (350024, 'A Chailleach (Fannaich Region)', None, None, 'he', 'Highlands and Eilean Siar', 57.6926, -5.1328, 'Europe', 999.0, '', 'Highland'),
#  (350025, 'A Chailleach (Monadh Liath Region)', None, None, 'he', 'Highlands and Eilean Siar', 57.1087, -4.1776, 'Europe', 930.0, 'Cairngorms National Park', 'Highland'),
#  (350029, 'A Chralaig', None, None, 'he', 'Highlands and Eilean Siar', 57.1825, -5.1542, 'Europe', 1120.0, '', 'Highland'),
#  (350044, 'A Ghlas-Bheinn', None, None, 'he', 'Highlands and Eilean Siar', 57.2549, -5.3033, 'Europe', 918.0, '', 'Highland'),
#  (350089, 'A Mhaighdean', None, None, 'he', 'Highlands and Eilean Siar', 57.7209, -5.3464, 'Europe', 967.0, '', 'Highland'),
#  (350090, 'A Mharconaich', None, None, 'he', 'Highlands and Eilean Siar', 56.859, -4.2929, 'Europe', 975.0, 'Cairngorms National Park', 'Highland'),
#  (350002, 'Abbey Dore Court Garden', None, None, 'wm', 'West Midlands', 51.9716, -2.8842, 'Europe', 117.0, '', 'Herefordshire'),
#  (350003, 'Abbey Hulton', None, None, 'wm', 'West Midlands', 53.0333, -2.14, 'Europe', 128.0, '', 'Stoke-on-Trent'),
#  (350004, 'Abbeydale', None, None, 'yh', 'Yorkshire and the Humber', 53.3353, -1.5091, 'Europe', 110.0, '', 'South Yorkshire'),
#  (350005, 'Abbots Bromley', None, None, 'wm', 'West Midlands', 52.8177, -1.8807, 'Europe', 110.0, '', 'Staffordshire'),
#  (350006, 'Abbotsbury Sub-Tropical Gardens', None, None, 'sw', 'South West', 50.6602, -2.611, 'Europe', 14.0, '', 'Dorset'),
#  (354829, 'Aber Mawr Bay (Beach)', None, None, 'wl', 'Wales', 51.9692, -5.0838, 'Europe', 0.0, '', 'Pembrokeshire'),
#  (324077, 'Aberaeron', None, None, 'wl', 'Wales', 52.2425, -4.2569, 'Europe', 5.0, '', 'Ceredigion'),
#  (350007, 'Abercarn', None, None, 'wl', 'Wales', 51.6459, -3.1323, 'Europe', 128.0, '', 'Caerphilly'),
#  (350008, 'Aberconwy House', None, None, 'wl', 'Wales', 53.289, -3.8456, 'Europe', 4.0, '', 'Conwy'),
#  (350009, 'Aberdare', None, None, 'wl', 'Wales', 51.7158, -3.4505, 'Europe', 140.0, '', 'Rhondda Cynon Taff'),
#  (3405, 'Aberdaron', None, None, 'wl', 'Wales', 52.789, -4.742, 'Europe', 95.0, '', 'Gwynedd'),
#  (310170, 'Aberdeen', None, None, 'gr', 'Grampian', 57.1498, -2.0927, 'Europe', 19.0, '', 'Aberdeen'),
#  (350010, 'Aberdeen Airport', None, None, 'gr', 'Grampian', 57.2073, -2.2032, 'Europe', 64.0, '', 'Aberdeen'),
#  (3091, 'Aberdeen Dyce', None, None, 'gr', 'Grampian', 57.206, -2.202, 'Europe', 65.0, '', 'Aberdeen'),
#  (350011, 'Aberdeen F.C.(Pittodrie)', None, None, 'gr', 'Grampian', 57.1588, -2.0885, 'Europe', 13.0, '', 'Aberdeen'),
#  (350012, 'Aberdeen Youth Hostel', None, None, 'gr', 'Grampian', 57.145, -2.1432, 'Europe', 81.0, '', 'Aberdeen'),
#  (350013, 'Aberdour', None, None, 'ta', 'Central Tayside and Fife', 56.0547, -3.3013, 'Europe', 32.0, '', 'Fife'),
#  (350014, 'Aberdovey', None, None, 'wl', 'Wales', 52.5437, -4.0449, 'Europe', 6.0, 'Snowdonia National Park', 'Gwynedd'),
#  (354830, 'Abereiddy Bay - Slipway (Beach)', None, None, 'wl', 'Wales', 51.9363, -5.2059, 'Europe', 0.0, '', 'Pembrokeshire'),
#  (321942, 'Aberfeldy', None, None, 'ta', 'Central Tayside and Fife', 56.6218, -3.8656, 'Europe', 89.0, '', 'Perth and Kinross'),
#  (354810, 'Aberffraw Bay (Traeth Mawr) (Beach)', None, None, 'wl', 'Wales', 53.1818, -4.4622, 'Europe', 0.0, '', 'Isle of Anglesey'),
#  (350015, 'Aberfoyle', None, None, 'ta', 'Central Tayside and Fife', 56.1814, -4.3864, 'Europe', 80.0, 'Loch Lomond and the Trossachs National Park', 'Stirling'),
#  (324264, 'Abergavenny', None, None, 'wl', 'Wales', 51.825, -3.0181, 'Europe', 60.0, '', 'Monmouthshire'),
#  (354849, 'Abergavenny Castle', None, None, 'wl', 'Wales', 51.82, -3.0177, 'Europe', 48.0, 'Brecon Beacons National Park', 'Monmouthshire'),
#  (350017, 'Abergele', None, None, 'wl', 'Wales', 53.2841, -3.5801, 'Europe', 16.0, '', 'Conwy'),
#  (350018, 'Aberglasney Gardens', None, None, 'wl', 'Wales', 51.8766, -4.0612, 'Europe', 45.0, '', 'Carmarthenshire'),
#  (350019, 'Aberlour', None, None, 'gr', 'Grampian', 57.4751, -3.2155, 'Europe', 84.0, '', 'Moray'),
#  (3502, 'Aberporth', None, None, 'wl', 'Wales', 52.139, -4.571, 'Europe', 133.0, '', 'Ceredigion'),
#  (354824, 'Aberporth (Beach)', None, None, 'wl', 'Wales', 52.1349, -4.5473, 'Europe', 0.0, '', 'Ceredigion'),
#  (324078, 'Abersoch', None, None, 'wl', 'Wales', 52.8242, -4.5042, 'Europe', 9.0, '', 'Gwynedd'),
#  (354812, 'Abersoch (Beach)', None, None, 'wl', 'Wales', 52.8224, -4.4998, 'Europe', 0.0, '', 'Gwynedd'),
#  (350020, 'Abertillery', None, None, 'wl', 'Wales', 51.7313, -3.1336, 'Europe', 210.0, '', 'Blaenau Gwent'),
#  (350021, 'Aberystwyth', None, None, 'wl', 'Wales', 52.415, -4.0817, 'Europe', 9.0, '', 'Ceredigion'),
#  (354820, 'Aberystwyth - South (Beach)', None, None, 'wl', 'Wales', 52.4121, -4.0898, 'Europe', 0.0, '', 'Ceredigion'),
#  (3080, 'Aboyne', None, None, 'gr', 'Grampian', 57.077, -2.836, 'Europe', 140.0, '', 'Aberdeenshire'),
#  (350022, 'Aboyne', None, None, 'gr', 'Grampian', 57.0768, -2.7788, 'Europe', 129.0, '', 'Aberdeenshire'),
#  (350023, 'Accrington', None, None, 'nw', 'North West', 53.7534, -2.3707, 'Europe', 138.0, '', 'Lancashire'),
#  (350026, 'Achamore Gardens', None, None, 'st', 'Strathclyde', 55.6672, -5.7488, 'Europe', 22.0, '', 'Argyll and Bute'),
#  (350027, 'Achininver Youth Hostel', None, None, 'he', 'Highlands and Eilean Siar', 57.9968, -5.3138, 'Europe', 21.0, '', 'Highland'),
#  (354405, 'Achmelvich Bay (Beach)', None, None, 'he', 'Highlands and Eilean Siar', 58.17, -5.3061, 'Europe', 0.0, '', 'Highland'),
#  (350028, 'Achmelvich Youth Hostel', None, None, 'he', 'Highlands and Eilean Siar', 58.1699, -5.3, 'Europe', 9.0, '', 'Highland'),
#  (350030, 'Ackers Trust Ski Centre', None, None, 'wm', 'West Midlands', 52.4583, -1.8569, 'Europe', 112.0, '', 'West Midlands Conurbation'),
#  (350031, 'Acle', None, None, 'ee', 'East of England', 52.6379, 1.5524, 'Europe', 4.0, '', 'Norfolk'),
#  (350032, 'Acock s Green', None, None, 'wm', 'West Midlands', 52.4428, -1.8285, 'Europe', 132.0, '', 'West Midlands Conurbation'),
#  (350033, 'Acomb Youth Hostel', None, None, 'ne', 'North East England', 54.9955, -2.1065, 'Europe', 75.0, '', 'Northumberland'),
#  (350034, 'Acorn Bank Garden', None, None, 'nw', 'North West', 54.6537, -2.5914, 'Europe', 161.0, '', 'Cumbria'),
#  (350035, 'Adderley Green', None, None, 'wm', 'West Midlands', 53.0007, -2.118, 'Europe', 175.0, '', 'Stoke-on-Trent'),
#  (350037, 'Adel', None, None, 'yh', 'Yorkshire and the Humber', 53.8543, -1.5929, 'Europe', 145.0, '', 'West Yorkshire'),
#  (350038, 'Adlington', None, None, 'nw', 'North West', 53.6108, -2.6049, 'Europe', 93.0, '', 'Lancashire'),
#  (350039, 'Adventure Island', None, None, 'ee', 'East of England', 51.5322, 0.7199, 'Europe', 1.0, '', 'Southend-on-Sea'),
#  (350040, 'Adventure Wonderland', None, None, 'sw', 'South West', 50.7734, -1.8417, 'Europe', 10.0, '', 'Dorset'),
#  (350041, 'Adwick Le Street', None, None, 'yh', 'Yorkshire and the Humber', 53.5673, -1.1932, 'Europe', 28.0, '', 'South Yorkshire'),
#  (350042, 'Ae Mountain Bike Trail Centre', None, None, 'dg', 'Dumfries Galloway Lothian and Borders', 55.1954, -3.5944, 'Europe', 161.0, '', 'Dumfries and Galloway'),
#  (350043, 'Afan Forest', None, None, 'wl', 'Wales', 51.6374, -3.7012, 'Europe', 224.0, '', 'Neath Port Talbot'),
#  (371330, 'Agnew s Hill', None, None, 'ni', 'Northern Ireland', 54.8466, -5.9358, 'Europe', 476.0, '', 'County Antrim'),
#  (350045, 'Ainsdale', None, None, 'nw', 'North West', 53.6022, -3.0365, 'Europe', 11.0, '', 'Merseyside'),
#  (371331, 'Ainshval', None, None, 'he', 'Highlands and Eilean Siar', 56.9659, -6.3137, 'Europe', 781.0, '', 'Highland'),
#  (350046, 'Aintree', None, None, 'nw', 'North West', 53.4791, -2.9359, 'Europe', 16.0, '', 'Merseyside'),
#  (350047, 'Aintree Racecourse', None, None, 'nw', 'North West', 53.474, -2.9339, 'Europe', 20.0, '', 'Merseyside'),
#  (350048, 'Airdrie', None, None, 'st', 'Strathclyde', 55.8663, -3.9612, 'Europe', 139.0, '', 'North Lanarkshire'),
#  (3238, 'Albemarle', None, None, 'ne', 'North East England', 55.02, -1.88, 'Europe', 146.0, '', 'Northumberland'),
#  (350049, 'Alcester', None, None, 'wm', 'West Midlands', 52.2149, -1.8662, 'Europe', 40.0, '', 'Warwickshire'),
#  (350050, 'Aldeburgh', None, None, 'ee', 'East of England', 52.1549, 1.6022, 'Europe', 12.0, '', 'Suffolk'),
#  (350051, 'Alder Forest', None, None, 'nw', 'North West', 53.4929, -2.3696, 'Europe', 27.0, '', 'Greater Manchester'),
#  (3917, 'Aldergrove', None, None, 'ni', 'Northern Ireland', 54.664, -6.224, 'Europe', 63.0, '', 'County Antrim'),
#  (350052, 'Alderley Edge', None, None, 'nw', 'North West', 53.3013, -2.2358, 'Europe', 81.0, '', 'Cheshire East'),
#  (350053, 'Alderman s Green', None, None, 'wm', 'West Midlands', 52.4487, -1.4706, 'Europe', 86.0, '', 'West Midlands Conurbation'),
#  (350054, 'Alderney Airport', None, None, 'sw', 'South West', 49.7092, -2.2137, 'Europe', 70.0, '', 'Guernsey'),
#  (350055, 'Aldridge', None, None, 'wm', 'West Midlands', 52.6057, -1.9143, 'Europe', 161.0, '', 'West Midlands Conurbation'),
#  (350056, 'Alexandria', None, None, 'st', 'Strathclyde', 55.9841, -4.5848, 'Europe', 42.0, '', 'West Dunbartonshire'),
#  (350057, 'Alford (Aberdeenshire)', None, None, 'gr', 'Grampian', 57.2335, -2.7032, 'Europe', 146.0, '', 'Aberdeenshire'),
#  (350058, 'Alford (Lincolnshire)', None, None, 'em', 'East Midlands', 53.263, 0.185, 'Europe', 5.0, '', 'Lincolnshire'),
#  (350059, 'Alford Ski Centre', None, None, 'gr', 'Grampian', 57.2294, -2.7063, 'Europe', 163.0, '', 'Aberdeenshire'),
#  (324158, 'Alfreton', None, None, 'em', 'East Midlands', 53.0972, -1.3807, 'Europe', 133.0, '', 'Derbyshire'),
#  (371332, 'Allen Crags', None, None, 'nw', 'North West', 54.4662, -3.1778, 'Europe', 785.0, 'Lake District National Park', 'Cumbria'),
#  (350063, 'Allerton (Merseyside)', None, None, 'nw', 'North West', 53.3669, -2.8925, 'Europe', 30.0, '', 'Merseyside'),
#  (350064, 'Allerton (West Yorkshire)', None, None, 'yh', 'Yorkshire and the Humber', 53.8029, -1.8197, 'Europe', 226.0, '', 'West Yorkshire'),
#  (350065, 'Allesley', None, None, 'wm', 'West Midlands', 52.4241, -1.565, 'Europe', 110.0, '', 'West Midlands Conurbation'),
#  (324159, 'Alloa', None, None, 'ta', 'Central Tayside and Fife', 56.1141, -3.7905, 'Europe', 12.0, '', 'Clackmannanshire'),
#  (350066, 'Almondbury', None, None, 'yh', 'Yorkshire and the Humber', 53.6263, -1.7467, 'Europe', 121.0, '', 'West Yorkshire'),
#  (350067, 'Alness', None, None, 'he', 'Highlands and Eilean Siar', 57.6962, -4.2554, 'Europe', 17.0, '', 'Highland'),
#  (324048, 'Alnwick', None, None, 'ne', 'North East England', 55.4127, -1.7047, 'Europe', 63.0, '', 'Northumberland'),
#  (371333, 'Alphin Pike', None, None, 'nw', 'North West', 53.5218, -1.9955, 'Europe', 465.0, 'Peak District National Park', 'Greater Manchester'),
#  (350069, 'Alsager', None, None, 'nw', 'North West', 53.0951, -2.3032, 'Europe', 91.0, '', 'Cheshire East'),
#  (350070, 'Alston', None, None, 'nw', 'North West', 54.8121, -2.4372, 'Europe', 299.0, '', 'Cumbria'),
#  (350071, 'Alston Youth Hostel', None, None, 'nw', 'North West', 54.8052, -2.4369, 'Europe', 308.0, '', 'Cumbria'),
#  (350072, 'Alt', None, None, 'nw', 'North West', 53.526, -2.0786, 'Europe', 159.0, '', 'Greater Manchester'),
#  (350073, 'Althorp House', None, None, 'em', 'East Midlands', 52.2815, -1.0006, 'Europe', 94.0, '', 'Northamptonshire'),
#  (3044, 'Altnaharra Saws', None, None, 'he', 'Highlands and Eilean Siar', 58.288, -4.442, 'Europe', 81.0, '', 'Highland'),
#  (99121, 'Altnahinch Filters', None, None, 'ni', 'Northern Ireland', 55.048, -6.254, 'Europe', 213.0, '', 'County Antrim'),
#  (324160, 'Alton Towers Leisure Park', None, None, 'wm', 'West Midlands', 52.9869, -1.8891, 'Europe', 170.0, '', 'Staffordshire'),
#  (350075, 'Altrincham', None, None, 'nw', 'North West', 53.3899, -2.3495, 'Europe', 42.0, '', 'Greater Manchester'),
#  (350076, 'Alum Rock', None, None, 'wm', 'West Midlands', 52.4867, -1.8308, 'Europe', 112.0, '', 'West Midlands Conurbation'),
#  (350077, 'Alva', None, None, 'ta', 'Central Tayside and Fife', 56.153, -3.798, 'Europe', 23.0, '', 'Clackmannanshire'),
#  (350079, 'Alwoodley', None, None, 'yh', 'Yorkshire and the Humber', 53.8632, -1.5398, 'Europe', 145.0, '', 'West Yorkshire'),
#  (350080, 'Alyth', None, None, 'ta', 'Central Tayside and Fife', 56.6259, -3.2254, 'Europe', 104.0, '', 'Perth and Kinross'),
#  (350081, 'Am Basteir', None, None, 'he', 'Highlands and Eilean Siar', 57.2474, -6.2007, 'Europe', 935.0, '', 'Highland'),
#  (350082, 'Am Bodach', None, None, 'he', 'Highlands and Eilean Siar', 56.7428, -4.9823, 'Europe', 1032.0, '', 'Highland'),
#  (350083, 'Am Faochagach', None, None, 'he', 'Highlands and Eilean Siar', 57.7715, -4.8545, 'Europe', 954.0, '', 'Highland'),
#  (350084, 'Amble', None, None, 'ne', 'North East England', 55.3314, -1.5837, 'Europe', 11.0, '', 'Northumberland'),
#  (354771, 'Amble Links (Beach)', None, None, 'ne', 'North East England', 55.3255, -1.5547, 'Europe', 0.0, '', 'Northumberland'),
#  (350085, 'Amblecote', None, None, 'wm', 'West Midlands', 52.4679, -2.149, 'Europe', 70.0, '', 'West Midlands Conurbation'),
#  (350086, 'Ambleside', None, None, 'nw', 'North West', 54.4286, -2.9599, 'Europe', 60.0, 'Lake District National Park', 'Cumbria'),
#  (350087, 'Ambleside Youth Hostel', None, None, 'nw', 'North West', 54.419, -2.961, 'Europe', 37.0, 'Lake District National Park', 'Cumbria'),
#  (350088, 'Amesbury', None, None, 'sw', 'South West', 51.1745, -1.7777, 'Europe', 80.0, '', 'Wiltshire'),
#  (350091, 'Amlwch', None, None, 'wl', 'Wales', 53.4104, -4.3445, 'Europe', 29.0, '', 'Isle of Anglesey'),
#  (350092, 'Ammanford', None, None, 'wl', 'Wales', 51.7925, -3.9872, 'Europe', 38.0, '', 'Carmarthenshire'),
#  (350093, 'Ampney St. Peter', None, None, 'sw', 'South West', 51.7118, -1.8771, 'Europe', 100.0, '', 'Gloucestershire'),
#  (324162, 'Ampthill', None, None, 'ee', 'East of England', 52.0308, -0.4946, 'Europe', 100.0, '', 'Central Bedfordshire'),
#  (354480, 'Amroth (Beach)', None, None, 'wl', 'Wales', 51.7313, -4.6563, 'Europe', 0.0, '', 'Pembrokeshire'),
#  (350094, 'An Caisteal', None, None, 'ta', 'Central Tayside and Fife', 56.3384, -4.6282, 'Europe', 995.0, 'Loch Lomond and the Trossachs National Park', 'Stirling'),
#  (350095, 'An Cala Garden', None, None, 'st', 'Strathclyde', 56.2961, -5.638, 'Europe', 91.0, '', 'Argyll and Bute'),
#  (350096, 'An Coileachan', None, None, 'he', 'Highlands and Eilean Siar', 57.6686, -4.9476, 'Europe', 923.0, '', 'Highland'),
#  (350097, 'An Gearanach', None, None, 'he', 'Highlands and Eilean Siar', 56.7602, -4.9664, 'Europe', 982.0, '', 'Highland'),
#  (350098, 'An Riabhachan', None, None, 'he', 'Highlands and Eilean Siar', 57.3647, -5.0992, 'Europe', 1129.0, '', 'Highland'),
#  (350099, 'An Sgarsoch', None, None, 'gr', 'Grampian', 56.9345, -3.7491, 'Europe', 1006.0, 'Cairngorms National Park', 'Aberdeenshire'),
#  (350100, 'An Socach (Glen Ey)', None, None, 'gr', 'Grampian', 56.9055, -3.51, 'Europe', 944.0, 'Cairngorms National Park', 'Aberdeenshire'),
#  (350101, 'An Socach (Highland)', None, None, 'he', 'Highlands and Eilean Siar', 57.2574, -5.1679, 'Europe', 920.0, '', 'Highland'),
#  (350102, 'An Socach (Loch Mullardoch)', None, None, 'he', 'Highlands and Eilean Siar', 57.3508, -5.1563, 'Europe', 1069.0, '', 'Highland'),
#  (350103, 'An Stuc', None, None, 'ta', 'Central Tayside and Fife', 56.5605, -4.2145, 'Europe', 1118.0, '', 'Perth and Kinross'),
#  (350104, 'Ancoats', None, None, 'nw', 'North West', 53.4849, -2.2172, 'Europe', 50.0, '', 'Greater Manchester'),
#  (350105, 'Ancrum Outdoor Education Centre', None, None, 'ta', 'Central Tayside and Fife', 56.4655, -3.0103, 'Europe', 139.0, '', 'Dundee'),
#  (354737, 'Anderby (Beach)', None, None, 'em', 'East Midlands', 53.2597, 0.3257, 'Europe', 0.0, '', 'Lincolnshire'),
#  (3684, 'Andrewsfield', None, None, 'ee', 'East of England', 51.896, 0.453, 'Europe', 87.0, '', 'Essex'),
#  (354862, 'Angle', None, None, 'wl', 'Wales', 51.6757, -5.0792, 'Europe', 16.0, 'Pembrokeshire Coast National Park', 'Pembrokeshire'),
#  (350107, 'Anglesey Abbey', None, None, 'ee', 'East of England', 52.2377, 0.2402, 'Europe', 6.0, '', 'Cambridgeshire'),
#  (350108, 'Annan', None, None, 'dg', 'Dumfries Galloway Lothian and Borders', 54.9902, -3.2584, 'Europe', 15.0, '', 'Dumfries and Galloway'),
#  (350109, 'Anne Hathaway s Cottage', None, None, 'wm', 'West Midlands', 52.1894, -1.7388, 'Europe', 65.0, '', 'Warwickshire'),
#  (350110, 'Annfield Plain', None, None, 'ne', 'North East England', 54.8564, -1.7308, 'Europe', 238.0, '', 'Durham'),
#  (350111, 'Anniesland', None, None, 'st', 'Strathclyde', 55.8895, -4.3441, 'Europe', 18.0, '', 'Glasgow'),
#  (354602, 'Ansteys Cove (Beach)', None, None, 'sw', 'South West', 50.473, -3.5021, 'Europe', 0.0, '', 'Torbay'),
#  (350112, 'Anstruther', None, None, 'ta', 'Central Tayside and Fife', 56.223, -2.699, 'Europe', 1.0, '', 'Fife'),
#  (324270, 'Ansty', None, None, 'sw', 'South West', 50.83, -2.33, 'Europe', 150.0, '', 'Dorset'),
#  (350113, 'Antony House', None, None, 'sw', 'South West', 50.3847, -4.2288, 'Europe', 26.0, '', 'Cornwall'),
#  (350114, 'Antrim', None, None, 'ni', 'Northern Ireland', 54.7193, -6.2069, 'Europe', 33.0, '', 'County Antrim'),
#  (350115, 'Antrim Castle Gardens', None, None, 'ni', 'Northern Ireland', 54.7188, -6.2316, 'Europe', 16.0, '', 'County Antrim'),
#  (354858, 'Antur Stiniog', None, None, 'wl', 'Wales', 53.007, -3.9422, 'Europe', 273.0, 'Snowdonia National Park', 'Gwynedd'),
#  (350116, 'Aonach Air Chrith', None, None, 'he', 'Highlands and Eilean Siar', 57.123, -5.2228, 'Europe', 1021.0, '', 'Highland'),
#  (350117, 'Aonach Beag (1238m)', None, None, 'he', 'Highlands and Eilean Siar', 56.7981, -4.9508, 'Europe', 1238.0, '', 'Highland'),
#  (350118, 'Aonach Beag (Highland)', None, None, 'he', 'Highlands and Eilean Siar', 56.8348, -4.5266, 'Europe', 1114.0, '', 'Highland'),
#  (350120, 'Aonach Meadhoin', None, None, 'he', 'Highlands and Eilean Siar', 57.1709, -5.2325, 'Europe', 1003.0, '', 'Highland'),
#  (3041, 'Aonach Mor', None, None, 'he', 'Highlands and Eilean Siar', 56.822, -4.97, 'Europe', 1130.0, '', 'Highland'),
#  (350119, 'Aonach Mor', None, None, 'he', 'Highlands and Eilean Siar', 56.8122, -4.9575, 'Europe', 1219.0, '', 'Highland'),
#  (350121, 'Apperley Bridge', None, None, 'yh', 'Yorkshire and the Humber', 53.8338, -1.7086, 'Europe', 65.0, '', 'West Yorkshire'),
#  (350122, 'Appleby-In-Westmorland', None, None, 'nw', 'North West', 54.5782, -2.4882, 'Europe', 123.0, '', 'Cumbria'),
#  (321971, 'Appledore', None, None, 'sw', 'South West', 51.05, -4.2, 'Europe', 34.0, '', 'Devon'),
#  (350123, 'Appley', None, None, 'sw', 'South West', 50.9859, -3.3237, 'Europe', 123.0, '', 'Somerset'),
#  (371334, 'Aran Benllyn', None, None, 'wl', 'Wales', 52.8036, -3.6812, 'Europe', 885.0, 'Snowdonia National Park', 'Gwynedd'),
#  (371335, 'Aran Fawddwy', None, None, 'wl', 'Wales', 52.7867, -3.6866, 'Europe', 905.0, 'Snowdonia National Park', 'Gwynedd'),
#  (350124, 'Arbourthorne', None, None, 'yh', 'Yorkshire and the Humber', 53.365, -1.4433, 'Europe', 150.0, '', 'South Yorkshire'),
#  (321976, 'Arbroath', None, None, 'ta', 'Central Tayside and Fife', 56.5592, -2.59, 'Europe', 15.0, '', 'Angus'),
#  (354449, 'Arbroath (Beach)', None, None, 'gr', 'Grampian', 56.5504, -2.6052, 'Europe', 0.0, '', 'Angus'),
#  (350125, 'Arbuthnott House', None, None, 'gr', 'Grampian', 56.8664, -2.3333, 'Europe', 39.0, '', 'Aberdeenshire'),
#  (354388, 'Archirondel (Beach)', None, None, 'sw', 'South West', 49.1955, -2.0305, 'Europe', 0.0, '', 'Jersey'),
#  (350126, 'Ardanaiseig Gardens', None, None, 'st', 'Strathclyde', 56.3751, -5.0916, 'Europe', 53.0, '', 'Argyll and Bute'),
#  (350127, 'Ardchattan Gardens', None, None, 'st', 'Strathclyde', 56.4648, -5.2885, 'Europe', 27.0, '', 'Argyll and Bute'),
#  (350128, 'Ardencraig Gardens', None, None, 'st', 'Strathclyde', 55.8391, -5.0348, 'Europe', 94.0, '', 'Argyll and Bute'),
#  (350129, 'Ardgarten Youth Hostel', None, None, 'st', 'Strathclyde', 56.1879, -4.7833, 'Europe', 11.0, 'Loch Lomond and the Trossachs National Park', 'Argyll and Bute'),
#  (350130, 'Ardkinglas Woodland Garden', None, None, 'st', 'Strathclyde', 56.2522, -4.9313, 'Europe', 137.0, '', 'Argyll and Bute'),
#  (354872, 'Ardlui', None, None, 'st', 'Strathclyde', 56.304, -4.7205, 'Europe', 14.0, 'Loch Lomond and the Trossachs National Park', 'Argyll and Bute'),
#  (350131, 'Ardlussa', None, None, 'st', 'Strathclyde', 56.0226, -5.778, 'Europe', 19.0, '', 'Argyll and Bute'),
#  (350132, 'Ardress House (Nt)', None, None, 'ni', 'Northern Ireland', 54.4417, -6.5843, 'Europe', 18.0, '', 'County Armagh'),
#  (321979, 'Ardrossan', None, None, 'st', 'Strathclyde', 55.6439, -4.8106, 'Europe', 6.0, '', 'North Ayrshire'),
#  (354419, 'Ardrossan (Beach)', None, None, 'st', 'Strathclyde', 55.6493, -4.8181, 'Europe', 0.0, '', 'North Ayrshire'),
#  (350133, 'Ardsley', None, None, 'yh', 'Yorkshire and the Humber', 53.5448, -1.4118, 'Europe', 79.0, '', 'South Yorkshire'),
#  (350134, 'Ardtornish', None, None, 'he', 'Highlands and Eilean Siar', 56.5636, -5.7386, 'Europe', 10.0, '', 'Highland'),
#  (350135, 'Arduaine Gardens', None, None, 'st', 'Strathclyde', 56.2341, -5.5604, 'Europe', 28.0, '', 'Argyll and Bute'),
#  (350136, 'Ardwell House', None, None, 'dg', 'Dumfries Galloway Lothian and Borders', 54.7682, -4.951, 'Europe', 22.0, '', 'Dumfries and Galloway'),
#  (371336, 'Arenig Fawr', None, None, 'wl', 'Wales', 52.9168, -3.7447, 'Europe', 854.0, 'Snowdonia National Park', 'Gwynedd'),
#  (371337, 'Argyll', None, None, 'st', 'Strathclyde', 56.4291, -5.239, 'Europe', 22.0, '', 'Argyll and Bute'),
#  (324306, 'Arinagour Isle Of Coll', None, None, 'st', 'Strathclyde', 56.6239, -6.527, 'Europe', 10.0, '', 'Argyll and Bute'),
#  (350137, 'Arisaig', None, None, 'he', 'Highlands and Eilean Siar', 56.91, -5.8419, 'Europe', 16.0, '', 'Highland'),
#  (350138, 'Arley Hall', None, None, 'nw', 'North West', 53.3199, -2.4887, 'Europe', 59.0, '', 'Cheshire East'),
#  (350139, 'Arlington Court', None, None, 'sw', 'South West', 51.1445, -3.9894, 'Europe', 165.0, '', 'Devon'),
#  (350140, 'Armadale', None, None, 'dg', 'Dumfries Galloway Lothian and Borders', 55.8978, -3.7008, 'Europe', 179.0, '', 'West Lothian'),
#  (350141, 'Armadale Pier', None, None, 'he', 'Highlands and Eilean Siar', 57.0647, -5.8939, 'Europe', 8.0, '', 'Highland'),
#  (321983, 'Armagh', None, None, 'ni', 'Northern Ireland', 54.3463, -6.6512, 'Europe', 42.0, '', 'County Armagh'),
#  (350142, 'Armagh Youth Hostel', None, None, 'ni', 'Northern Ireland', 54.3481, -6.6603, 'Europe', 50.0, '', 'County Armagh'),
#  (350143, 'Armathwaite', None, None, 'nw', 'North West', 54.8073, -2.7686, 'Europe', 57.0, '', 'Cumbria'),
#  (350144, 'Armley', None, None, 'yh', 'Yorkshire and the Humber', 53.7973, -1.5731, 'Europe', 50.0, '', 'West Yorkshire'),
#  (350145, 'Armthorpe', None, None, 'yh', 'Yorkshire and the Humber', 53.5369, -1.0512, 'Europe', 10.0, '', 'South Yorkshire'),
#  (354924, 'Arncliffe', None, None, 'yh', 'Yorkshire and the Humber', 54.1422, -2.1059, 'Europe', 213.0, 'Yorkshire Dales National Park', 'North Yorkshire'),
#  (350147, 'Arno s Vale', None, None, 'sw', 'South West', 51.439, -2.5613, 'Europe', 30.0, '', 'Bristol'),
#  (350146, 'Arnold', None, None, 'em', 'East Midlands', 53.0004, -1.1303, 'Europe', 65.0, '', 'Nottinghamshire'),
#  (350148, 'Arnside', None, None, 'nw', 'North West', 54.2036, -2.8313, 'Europe', 9.0, '', 'Cumbria'),
#  (350149, 'Arnside Youth Hostel', None, None, 'nw', 'North West', 54.1952, -2.8418, 'Europe', 38.0, '', 'Cumbria'),
#  (354856, 'Arrochar', None, None, 'st', 'Strathclyde', 56.1967, -4.7459, 'Europe', 15.0, 'Loch Lomond and the Trossachs National Park', 'Argyll and Bute'),
#  (350155, 'Ashbourne', None, None, 'em', 'East Midlands', 53.0163, -1.7307, 'Europe', 118.0, '', 'Derbyshire'),
#  (350156, 'Ashburton', None, None, 'sw', 'South West', 50.5153, -3.7502, 'Europe', 78.0, 'Dartmoor National Park', 'Devon'),
#  (350157, 'Ashby De La Zouch', None, None, 'em', 'East Midlands', 52.7489, -1.4671, 'Europe', 129.0, '', 'Leicestershire'),
#  (350158, 'Ashcott', None, None, 'sw', 'South West', 51.1312, -2.8076, 'Europe', 64.0, '', 'Somerset'),
#  (350159, 'Ashington', None, None, 'ne', 'North East England', 55.1829, -1.5644, 'Europe', 34.0, '', 'Northumberland'),
#  (350160, 'Ashley Down', None, None, 'sw', 'South West', 51.4756, -2.5833, 'Europe', 59.0, '', 'Bristol'),
#  (371338, 'Ashover No 2', None, None, 'em', 'East Midlands', 53.16221, -1.47829, 'Europe', 178.0, '', 'Derbyshire'),
#  (350161, 'Ashton-In-Makerfield', None, None, 'nw', 'North West', 53.4867, -2.6412, 'Europe', 51.0, '', 'Greater Manchester'),
#  (350162, 'Ashton-Under-Lyne', None, None, 'nw', 'North West', 53.494, -2.1026, 'Europe', 111.0, '', 'Greater Manchester'),
#  (350163, 'Askern', None, None, 'yh', 'Yorkshire and the Humber', 53.617, -1.1542, 'Europe', 21.0, '', 'South Yorkshire'),
#  (371339, 'Askival', None, None, 'he', 'Highlands and Eilean Siar', 56.9747, -6.2905, 'Europe', 812.0, '', 'Highland'),
#  (324281, 'Askrigg', None, None, 'yh', 'Yorkshire and the Humber', 54.3145, -2.08, 'Europe', 220.0, 'Yorkshire Dales National Park', 'North Yorkshire'),
#  (354925, 'Askrigg Common', None, None, 'yh', 'Yorkshire and the Humber', 54.3362, -2.0851, 'Europe', 477.0, 'Yorkshire Dales National Park', 'North Yorkshire'),
#  (350164, 'Aspatria', None, None, 'nw', 'North West', 54.7633, -3.3317, 'Europe', 76.0, '', 'Cumbria'),
#  (350165, 'Aspley', None, None, 'em', 'East Midlands', 52.9725, -1.201, 'Europe', 58.0, '', 'Nottingham'),
#  (350166, 'Aspull', None, None, 'nw', 'North West', 53.568, -2.5869, 'Europe', 127.0, '', 'Greater Manchester'),
#  (350167, 'Astley Bridge', None, None, 'nw', 'North West', 53.6064, -2.428, 'Europe', 129.0, '', 'Greater Manchester'),
#  (350168, 'Aston', None, None, 'wm', 'West Midlands', 52.4956, -1.8838, 'Europe', 104.0, '', 'West Midlands Conurbation'),
#  (350169, 'Aston Villa F.C.', None, None, 'wm', 'West Midlands', 52.5095, -1.8838, 'Europe', 99.0, '', 'West Midlands Conurbation'),
#  (350170, 'Atherstone', None, None, 'wm', 'West Midlands', 52.5763, -1.5423, 'Europe', 84.0, '', 'Warwickshire'),
#  (350171, 'Atherton', None, None, 'nw', 'North West', 53.5238, -2.4908, 'Europe', 58.0, '', 'Greater Manchester'),
#  (350172, 'Attercliffe', None, None, 'yh', 'Yorkshire and the Humber', 53.3946, -1.4327, 'Europe', 47.0, '', 'South Yorkshire'),
#  (350173, 'Atterton', None, None, 'em', 'East Midlands', 52.584, -1.4811, 'Europe', 88.0, '', 'Leicestershire'),
#  (350174, 'Attleborough', None, None, 'ee', 'East of England', 52.5177, 1.0173, 'Europe', 38.0, '', 'Norfolk'),
#  (350175, 'Auchinleck', None, None, 'st', 'Strathclyde', 55.4734, -4.2973, 'Europe', 161.0, '', 'East Ayrshire'),
#  (350176, 'Auchterarder', None, None, 'ta', 'Central Tayside and Fife', 56.3007, -3.6986, 'Europe', 87.0, '', 'Perth and Kinross'),
#  (350177, 'Auchtermuchty', None, None, 'ta', 'Central Tayside and Fife', 56.2923, -3.2346, 'Europe', 59.0, '', 'Fife'),
#  (350178, 'Audenshaw', None, None, 'nw', 'North West', 53.4734, -2.1237, 'Europe', 97.0, '', 'Greater Manchester'),
#  (350179, 'Augher', None, None, 'ni', 'Northern Ireland', 54.4286, -7.1312, 'Europe', 63.0, '', 'County Tyrone'),
#  (350180, 'Aughnacloy', None, None, 'ni', 'Northern Ireland', 54.4132, -6.9738, 'Europe', 51.0, '', 'County Tyrone'),
#  (3034, 'Aultbea', None, None, 'he', 'Highlands and Eilean Siar', 57.859, -5.636, 'Europe', 11.0, '', 'Highland'),
#  (350181, 'Auskerry Sound', None, None, 'os', 'Orkney and Shetland', 59.0513, -2.5946, 'Europe', None, '', 'Orkney Islands'),
#  (350182, 'Austhorpe', None, None, 'yh', 'Yorkshire and the Humber', 53.7961, -1.4383, 'Europe', 89.0, '', 'West Yorkshire'),
#  (354926, 'Austwick', None, None, 'yh', 'Yorkshire and the Humber', 54.1124, -2.3564, 'Europe', 147.0, 'Yorkshire Dales National Park', 'North Yorkshire'),
#  (350183, 'Avebury', None, None, 'sw', 'South West', 51.429, -1.8495, 'Europe', 160.0, '', 'Wiltshire'),
#  (350184, 'Avebury Manor & Garden', None, None, 'sw', 'South West', 51.4279, -1.8591, 'Europe', 152.0, '', 'Wiltshire'),
#  (3063, 'Aviemore', None, None, 'he', 'Highlands and Eilean Siar', 57.206, -3.827, 'Europe', 228.0, 'Cairngorms National Park', 'Highland'),
#  (350185, 'Aviemore', None, None, 'he', 'Highlands and Eilean Siar', 57.1946, -3.8224, 'Europe', 210.0, 'Cairngorms National Park', 'Highland'),
#  (350186, 'Aviemore Youth Hostel', None, None, 'he', 'Highlands and Eilean Siar', 57.1809, -3.8276, 'Europe', 206.0, 'Cairngorms National Park', 'Highland'),
#  (354976, 'Avon Dam Reservoir', None, None, 'sw', 'South West', 50.473, -3.8665, 'Europe', 325.0, 'Dartmoor National Park', 'Devon'),
#  (350187, 'Avon Ski Centre', None, None, 'sw', 'South West', 51.326, -2.8093, 'Europe', 87.0, '', 'Somerset'),
#  (310176, 'Avonmouth', None, None, 'sw', 'South West', 51.503, -2.6971, 'Europe', 4.0, '', 'Bristol'),
#  (350188, 'Awliscombe', None, None, 'sw', 'South West', 50.8095, -3.2261, 'Europe', 116.0, '', 'Devon'),
#  (350189, 'Axminster', None, None, 'sw', 'South West', 50.7822, -2.9936, 'Europe', 52.0, '', 'Devon'),
#  (350190, 'Aylsham', None, None, 'ee', 'East of England', 52.7963, 1.2541, 'Europe', 29.0, '', 'Norfolk'),
#  (350191, 'Ayr', None, None, 'st', 'Strathclyde', 55.4585, -4.6279, 'Europe', 10.0, '', 'South Ayrshire'),
#  (350192, 'Ayr Bay', None, None, 'st', 'Strathclyde', 55.4911, -4.674, 'Europe', None, '', 'South Ayrshire'),
#  (350193, 'Ayr Racecourse', None, None, 'st', 'Strathclyde', 55.465, -4.6073, 'Europe', 18.0, '', 'South Ayrshire'),
#  (354374, 'Ayr United F.C.', None, None, 'st', 'Strathclyde', 55.46968, -4.62004, 'Europe', 15.0, '', 'South Ayrshire'),
#  (350194, 'Ayr Youth Hostel', None, None, 'st', 'Strathclyde', 55.4554, -4.6386, 'Europe', 3.0, '', 'South Ayrshire'),
#  (354927, 'Aysgarth', None, None, 'yh', 'Yorkshire and the Humber', 54.2899, -1.988, 'Europe', 221.0, 'Yorkshire Dales National Park', 'North Yorkshire'),
#  (350195, 'Aysgarth Falls Youth Hostel', None, None, 'yh', 'Yorkshire and the Humber', 54.2913, -1.9756, 'Europe', 187.0, 'Yorkshire Dales National Park', 'North Yorkshire'),
#  (350196, 'Babbacombe Bay', None, None, 'sw', 'South West', 50.5107, -3.4625, 'Europe', None, '', 'Devon'),
#  (371340, 'Bache Hill', None, None, 'wl', 'Wales', 52.2649, -3.152, 'Europe', 610.0, '', 'Powys'),
#  (350197, 'Bacton', None, None, 'ee', 'East of England', 52.2643, 1.0089, 'Europe', 58.0, '', 'Suffolk'),
#  (350198, 'Bacup', None, None, 'nw', 'North West', 53.7069, -2.1998, 'Europe', 269.0, '', 'Lancashire'),
#  (350199, 'Badby Youth Hostel', None, None, 'em', 'East Midlands', 52.2218, -1.1791, 'Europe', 141.0, '', 'Northamptonshire'),
#  (350200, 'Badsey', None, None, 'wm', 'West Midlands', 52.0836, -1.8923, 'Europe', 37.0, '', 'Worcestershire'),
#  (350201, 'Bagendon', None, None, 'sw', 'South West', 51.7598, -1.9838, 'Europe', 152.0, '', 'Gloucestershire'),
#  (350203, 'Bagslate Moor', None, None, 'nw', 'North West', 53.618, -2.1982, 'Europe', 160.0, '', 'Greater Manchester'),
#  (350204, 'Baguley', None, None, 'nw', 'North West', 53.3991, -2.2754, 'Europe', 38.0, '', 'Greater Manchester'),
#  (350205, 'Baildon', None, None, 'yh', 'Yorkshire and the Humber', 53.8525, -1.7666, 'Europe', 167.0, '', 'West Yorkshire'),
#  (350206, 'Baillieston', None, None, 'st', 'Strathclyde', 55.8458, -4.11, 'Europe', 62.0, '', 'Glasgow'),
#  (354928, 'Bainbridge', None, None, 'yh', 'Yorkshire and the Humber', 54.3068, -2.1033, 'Europe', 215.0, 'Yorkshire Dales National Park', 'North Yorkshire'),
#  (350207, 'Bainton', None, None, 'yh', 'Yorkshire and the Humber', 53.9562, -0.531, 'Europe', 34.0, '', 'East Riding of Yorkshire'),
#  (324163, 'Bakewell', None, None, 'em', 'East Midlands', 53.2149, -1.6747, 'Europe', 125.0, 'Peak District National Park', 'Derbyshire'),
#  (350208, 'Bakewell Youth Hostel', None, None, 'em', 'East Midlands', 53.2166, -1.6805, 'Europe', 161.0, 'Peak District National Park', 'Derbyshire'),
#  (3409, 'Bala', None, None, 'wl', 'Wales', 52.917, -3.583, 'Europe', 163.0, '', 'Gwynedd'),
#  (324263, 'Bala', None, None, 'wl', 'Wales', 52.9096, -3.6003, 'Europe', 168.0, 'Snowdonia National Park', 'Gwynedd'),
#  (354891, 'Bala Lake Railway', None, None, 'wl', 'Wales', 52.8561, -3.6636, 'Europe', 171.0, 'Snowdonia National Park', 'Gwynedd'),
#  (350210, 'Balblair Trails', None, None, 'he', 'Highlands and Eilean Siar', 57.9143, -4.3475, 'Europe', 119.0, '', 'Highland'),
#  (350211, 'Baldersdale Youth Hostel', None, None, 'ne', 'North East England', 54.5527, -2.1129, 'Europe', 364.0, '', 'Durham'),
#  (350212, 'Baldock', None, None, 'ee', 'East of England', 51.9888, -0.1877, 'Europe', 65.0, '', 'Hertfordshire'),
#  (350213, 'Ball Green', None, None, 'wm', 'West Midlands', 53.0723, -2.1599, 'Europe', 182.0, '', 'Staffordshire'),
#  (350214, 'Ballaheannagh', None, None, 'nw', 'North West', 54.2225, -4.4395, 'Europe', 155.0, '', ''),
#  (350215, 'Ballantrae Bay', None, None, 'st', 'Strathclyde', 55.1058, -5.0169, 'Europe', 0.0, '', 'South Ayrshire'),
#  (350216, 'Ballater', None, None, 'gr', 'Grampian', 57.0501, -3.0351, 'Europe', 197.0, 'Cairngorms National Park', 'Aberdeenshire'),
#  (350217, 'Ballater Ski Slope', None, None, 'gr', 'Grampian', 57.0539, -3.0424, 'Europe', 218.0, 'Cairngorms National Park', 'Aberdeenshire'),
#  (371341, 'Ballencleuch Law', None, None, 'st', 'Strathclyde', 55.3273, -3.6784, 'Europe', 689.0, '', 'South Lanarkshire'),
#  (350218, 'Ballinluig', None, None, 'ta', 'Central Tayside and Fife', 56.6555, -3.657, 'Europe', 144.0, '', 'Perth and Kinross'),
#  (354999, 'Balloch', None, None, 'st', 'Strathclyde', 56.003, -4.5835, 'Europe', 6.0, 'Loch Lomond and the Trossachs National Park', 'West Dunbartonshire'),
#  (350219, 'Ballochroy', None, None, 'st', 'Strathclyde', 55.7098, -5.6173, 'Europe', 7.0, '', 'Argyll and Bute'),
#  (322002, 'Ballycastle', None, None, 'ni', 'Northern Ireland', 55.2058, -6.239, 'Europe', 4.0, '', 'County Antrim'),
#  (350220, 'Ballyclare', None, None, 'ni', 'Northern Ireland', 54.7524, -6.0022, 'Europe', 81.0, '', 'County Antrim'),
#  (354429, 'Ballygally (Beach)', None, None, 'ni', 'Northern Ireland', 54.8992, -5.8589, 'Europe', 0.0, '', 'County Antrim'),
#  (350221, 'Ballygrant', None, None, 'st', 'Strathclyde', 55.8182, -6.1598, 'Europe', 58.0, '', 'Argyll and Bute'),
#  (3908, 'Ballykelly Samos', None, None, 'ni', 'Northern Ireland', 55.057, -7.008, 'Europe', 4.0, '', 'County Londonderry'),
#  (350222, 'Ballymena', None, None, 'ni', 'Northern Ireland', 54.8635, -6.2777, 'Europe', 44.0, '', 'County Antrim'),
#  (350223, 'Ballymoney', None, None, 'ni', 'Northern Ireland', 55.0716, -6.508, 'Europe', 43.0, '', 'County Antrim'),
#  (350224, 'Ballynahinch', None, None, 'ni', 'Northern Ireland', 54.4025, -5.8963, 'Europe', 74.0, '', 'County Down'),
#  (3916, 'Ballypatrick Forest', None, None, 'ni', 'Northern Ireland', 55.181, -6.153, 'Europe', 156.0, '', 'County Antrim'),
#  (354901, 'Balmaha', None, None, 'ta', 'Central Tayside and Fife', 56.0837, -4.5424, 'Europe', 6.0, 'Loch Lomond and the Trossachs National Park', 'Stirling'),
#  (354441, 'Balmedie Country Park (Beach)', None, None, 'gr', 'Grampian', 57.2444, -2.042, 'Europe', 0.0, '', 'Aberdeenshire'),
#  (354873, 'Balmoral Castle', None, None, 'gr', 'Grampian', 57.0406, -3.2298, 'Europe', 266.0, 'Cairngorms National Park', 'Aberdeenshire'),
#  (350225, 'Balnain Bike Park', None, None, 'he', 'Highlands and Eilean Siar', 57.3348, -4.5785, 'Europe', 118.0, '', 'Highland'),
#  (350226, 'Balornock', None, None, 'st', 'Strathclyde', 55.8892, -4.2142, 'Europe', 93.0, '', 'Glasgow'),
#  (3002, 'Baltasound', None, None, 'os', 'Orkney and Shetland', 60.749, -0.854, 'Europe', 15.0, '', 'Shetland Islands'),
#  (350227, 'Bamber Bridge', None, None, 'nw', 'North West', 53.7357, -2.6645, 'Europe', 39.0, '', 'Lancashire'),
#  (354776, 'Bamburgh Castle (Beach)', None, None, 'ne', 'North East England', 55.6109, -1.7036, 'Europe', 0.0, '', 'Northumberland'),
#  (350228, 'Bamford', None, None, 'nw', 'North West', 53.6105, -2.2055, 'Europe', 142.0, '', 'Greater Manchester'),
#  (99131, 'Banagher  Caugh Hill', None, None, 'ni', 'Northern Ireland', 54.885, -6.966, 'Europe', 216.0, '', 'County Londonderry'),
#  (350229, 'Banbridge', None, None, 'ni', 'Northern Ireland', 54.3518, -6.2659, 'Europe', 55.0, '', 'County Down'),
#  (350230, 'Banchory', None, None, 'gr', 'Grampian', 57.054, -2.4894, 'Europe', 71.0, '', 'Aberdeenshire'),
#  (350231, 'Banff', None, None, 'gr', 'Grampian', 57.6667, -2.5225, 'Europe', 27.0, '', 'Aberdeenshire'),
#  (350232, 'Bangor (Gwynedd)', None, None, 'wl', 'Wales', 53.2271, -4.128, 'Europe', 17.0, '', 'Gwynedd'),
#  (350233, 'Bangor (North Down)', None, None, 'ni', 'Northern Ireland', 54.6629, -5.6619, 'Europe', 17.0, '', 'County Down'),
#  (350234, 'Bangor Castle', None, None, 'ni', 'Northern Ireland', 54.6509, -5.6662, 'Europe', 39.0, '', 'County Down'),
#  (350235, 'Bangor Youth Hostel', None, None, 'wl', 'Wales', 53.2292, -4.1134, 'Europe', 58.0, '', 'Gwynedd'),
#  (350236, 'Bangor-On-Dee Racecourse', None, None, 'wl', 'Wales', 52.9947, -2.9291, 'Europe', 16.0, '', 'Wrexham'),
#  (350237, 'Bank Top', None, None, 'yh', 'Yorkshire and the Humber', 53.8254, -1.7374, 'Europe', 198.0, '', 'West Yorkshire'),
#  (350238, 'Bankfoot', None, None, 'ta', 'Central Tayside and Fife', 56.5014, -3.5169, 'Europe', 70.0, '', 'Perth and Kinross'),
#  (350239, 'Bannockburn', None, None, 'ta', 'Central Tayside and Fife', 56.0918, -3.907, 'Europe', 34.0, '', 'Stirling'),
#  (354586, 'Bantham (Beach)', None, None, 'sw', 'South West', 50.2784, -3.8785, 'Europe', 0.0, '', 'Devon'),
#  (354494, 'Barafundle Bay (Beach)', None, None, 'wl', 'Wales', 51.6176, -4.9034, 'Europe', 0.0, '', 'Pembrokeshire'),
#  (350241, 'Bardney', None, None, 'em', 'East Midlands', 53.2103, -0.3171, 'Europe', 10.0, '', 'Lincolnshire'),
#  (350242, 'Bardsley', None, None, 'nw', 'North West', 53.5118, -2.1071, 'Europe', 130.0, '', 'Greater Manchester'),
#  (350243, 'Bargany Gardens', None, None, 'st', 'Strathclyde', 55.2651, -4.7462, 'Europe', 43.0, '', 'South Ayrshire'),
#  (350244, 'Bargoed', None, None, 'wl', 'Wales', 51.6845, -3.2284, 'Europe', 199.0, '', 'Caerphilly'),
#  (350245, 'Barguillean Garden', None, None, 'st', 'Strathclyde', 56.4113, -5.2706, 'Europe', 100.0, '', 'Argyll and Bute'),
#  (350246, 'Barley', None, None, 'ee', 'East of England', 52.0272, 0.0368, 'Europe', 97.0, '', 'Hertfordshire'),
#  (350247, 'Barlow Moor', None, None, 'nw', 'North West', 53.4271, -2.2659, 'Europe', 31.0, '', 'Greater Manchester'),
#  (350248, 'Barmouth', None, None, 'wl', 'Wales', 52.7226, -4.0548, 'Europe', 5.0, '', 'Gwynedd'),
#  (354817, 'Barmouth (Beach)', None, None, 'wl', 'Wales', 52.7207, -4.0576, 'Europe', 0.0, '', 'Gwynedd'),
#  (350249, 'Barnard Castle', None, None, 'ne', 'North East England', 54.5451, -1.9222, 'Europe', 165.0, '', 'Durham'),
#  (350250, 'Barne Barton', None, None, 'sw', 'South West', 50.4037, -4.1924, 'Europe', 25.0, '', 'Plymouth'),
#  (350251, 'Barnoldswick', None, None, 'nw', 'North West', 53.9128, -2.1854, 'Europe', 180.0, '', 'Lancashire'),
#  (350252, 'Barnsdale Gardens (Oakham)', None, None, 'em', 'East Midlands', 52.6832, -0.6528, 'Europe', 128.0, '', 'Rutland'),
#  (310022, 'Barnsley', None, None, 'yh', 'Yorkshire and the Humber', 53.5524, -1.4782, 'Europe', 98.0, '', 'South Yorkshire'),
#  (350253, 'Barnsley Fc', None, None, 'yh', 'Yorkshire and the Humber', 53.5544, -1.4649, 'Europe', 78.0, '', 'South Yorkshire'),
#  (320284, 'Barnstaple', None, None, 'sw', 'South West', 51.0777, -4.0571, 'Europe', 2.0, '', 'Devon'),
#  (350254, 'Barnton', None, None, 'dg', 'Dumfries Galloway Lothian and Borders', 55.9625, -3.2903, 'Europe', 56.0, '', 'Edinburgh'),
#  (350255, 'Barra (Traigh MhÃ²r) Airport', None, None, 'he', 'Highlands and Eilean Siar', 57.0232, -7.4442, 'Europe', 0.0, '', 'Na h-Eileanan Siar'),
#  (350256, 'Barrhead', None, None, 'st', 'Strathclyde', 55.7967, -4.3964, 'Europe', 61.0, '', 'East Renfrewshire'),
#  (350257, 'Barrington Court', None, None, 'sw', 'South West', 50.9608, -2.86, 'Europe', 21.0, '', 'Somerset'),
#  (310023, 'Barrow-In-Furness', None, None, 'nw', 'North West', 54.1088, -3.2175, 'Europe', 9.0, '', 'Cumbria'),
#  (371342, 'Barrowden', None, None, 'em', 'East Midlands', 52.5914, -0.6021, 'Europe', 57.0, '', 'Rutland'),
#  (322011, 'Barry', None, None, 'wl', 'Wales', 51.3993, -3.2813, 'Europe', 17.0, '', 'Vale of Glamorgan'),
#  (350258, 'Barry Island Pleasure Park', None, None, 'wl', 'Wales', 51.3897, -3.2645, 'Europe', 30.0, '', 'Vale of Glamorgan'),
#  (350259, 'Bartlow', None, None, 'ee', 'East of England', 52.084, 0.3116, 'Europe', 53.0, '', 'Cambridgeshire'),
#  (350260, 'Barton Upon Irwell', None, None, 'nw', 'North West', 53.4757, -2.354, 'Europe', 21.0, '', 'Greater Manchester'),
#  (350261, 'Barton-Upon-Humber', None, None, 'yh', 'Yorkshire and the Humber', 53.6864, -0.4417, 'Europe', 8.0, '', 'North Lincolnshire'),
#  (350262, 'Basford', None, None, 'wm', 'West Midlands', 53.0165, -2.2066, 'Europe', 150.0, '', 'Stoke-on-Trent'),
#  (310024, 'Basildon', None, None, 'ee', 'East of England', 51.5756, 0.4904, 'Europe', 20.0, '', 'Essex'),
#  (350264, 'Bassingbourn Snowsports Centre', None, None, 'ee', 'East of England', 52.0873, -0.0456, 'Europe', 29.0, '', 'Cambridgeshire'),
#  (371343, 'Bastifell', None, None, 'nw', 'North West', 54.4589, -2.2687, 'Europe', 620.0, '', 'Cumbria'),
#  (310026, 'Bath', None, None, 'sw', 'South West', 51.3754, -2.3585, 'Europe', 50.0, '', 'Bath and North East Somerset'),
#  (350266, 'Bath Racecourse', None, None, 'sw', 'South West', 51.4118, -2.4057, 'Europe', 185.0, '', 'Bath and North East Somerset'),
#  (350267, 'Bath Youth Hostel', None, None, 'sw', 'South West', 51.3736, -2.3412, 'Europe', 103.0, '', 'Bath and North East Somerset'),
#  (350268, 'Bathgate', None, None, 'dg', 'Dumfries Galloway Lothian and Borders', 55.9024, -3.6417, 'Europe', 141.0, '', 'West Lothian'),
#  (350269, 'Batley', None, None, 'yh', 'Yorkshire and the Humber', 53.7168, -1.6336, 'Europe', 59.0, '', 'West Yorkshire'),
#  (350270, 'Batsford Arboretum', None, None, 'sw', 'South West', 51.9996, -1.7343, 'Europe', 195.0, '', 'Gloucestershire'),
#  (350271, 'Battlefield', None, None, 'st', 'Strathclyde', 55.821, -4.276, 'Europe', 32.0, '', 'Glasgow'),
#  (350272, 'Bawtry', None, None, 'yh', 'Yorkshire and the Humber', 53.431, -1.0169, 'Europe', 9.0, '', 'South Yorkshire'),
#  (354600, 'Beacon Cove (Beach)', None, None, 'sw', 'South West', 50.4576, -3.5235, 'Europe', 0.0, '', 'Torbay'),
#  (354774, 'Beadnell Bay (Beach)', None, None, 'ne', 'North East England', 55.5414, -1.6344, 'Europe', 0.0, '', 'Northumberland'),
#  (3039, 'Bealach Na Ba', None, None, 'he', 'Highlands and Eilean Siar', 57.4175, -5.689, 'Europe', 773.0, '', 'Highland'),
#  (350274, 'Beaminster', None, None, 'sw', 'South West', 50.8101, -2.7446, 'Europe', 63.0, '', 'Dorset'),
#  (354964, 'Beardown Tors', None, None, 'sw', 'South West', 50.5791, -3.9755, 'Europe', 513.0, 'Dartmoor National Park', 'Devon'),
#  (350275, 'Bearsden', None, None, 'st', 'Strathclyde', 55.9217, -4.3342, 'Europe', 59.0, '', 'East Dunbartonshire'),
#  (350276, 'Bearsden Ski Centre', None, None, 'st', 'Strathclyde', 55.9299, -4.3342, 'Europe', 67.0, '', 'East Dunbartonshire'),
#  (350277, 'Bearwood', None, None, 'sw', 'South West', 50.7678, -1.9292, 'Europe', 30.0, '', 'Poole'),
#  (350278, 'Beauchief', None, None, 'yh', 'Yorkshire and the Humber', 53.3316, -1.4892, 'Europe', 171.0, '', 'South Yorkshire'),
#  (350279, 'Beauly', None, None, 'he', 'Highlands and Eilean Siar', 57.4836, -4.459, 'Europe', 2.0, '', 'Highland'),
#  (350280, 'Beauly Firth', None, None, 'he', 'Highlands and Eilean Siar', 57.4971, -4.3532, 'Europe', None, '', 'Highland'),
#  (350281, 'Beaumaris', None, None, 'wl', 'Wales', 53.2656, -4.0907, 'Europe', 8.0, '', 'Isle of Anglesey'),
#  (354792, 'Beaumaris (Beach)', None, None, 'wl', 'Wales', 53.2625, -4.0899, 'Europe', 0.0, '', 'Isle of Anglesey'),
#  (350282, 'Beaumont Leys', None, None, 'em', 'East Midlands', 52.6703, -1.168, 'Europe', 88.0, '', 'Leicester'),
#  (354394, 'Beauport (Beach)', None, None, 'sw', 'South West', 49.1794, -2.2078, 'Europe', 0.0, '', 'Jersey'),
#  (350283, 'Bebington', None, None, 'nw', 'North West', 53.3509, -3.0055, 'Europe', 30.0, '', 'Merseyside'),
#  (350284, 'Beccles', None, None, 'ee', 'East of England', 52.4589, 1.5678, 'Europe', 10.0, '', 'Suffolk'),
#  (350285, 'Beccles Heliport', None, None, 'ee', 'East of England', 52.4326, 1.6159, 'Europe', 22.0, '', 'Suffolk'),
#  (350287, 'Bedale', None, None, 'yh', 'Yorkshire and the Humber', 54.2899, -1.5899, 'Europe', 39.0, '', 'North Yorkshire'),
#  (350288, 'Beddgelert', None, None, 'wl', 'Wales', 53.0125, -4.1002, 'Europe', 56.0, 'Snowdonia National Park', 'Gwynedd'),
#  (3560, 'Bedford', None, None, 'ee', 'East of England', 52.225, -0.464, 'Europe', 85.0, '', 'Bedford'),
#  (350289, 'Bedford', None, None, 'ee', 'East of England', 52.1339, -0.4614, 'Europe', 24.0, '', 'Bedford'),
#  (350293, 'Bedlington', None, None, 'ne', 'North East England', 55.1316, -1.5979, 'Europe', 59.0, '', 'Northumberland'),
#  (350294, 'Bedminster', None, None, 'sw', 'South West', 51.4382, -2.6021, 'Europe', 22.0, '', 'Bristol'),
#  (350295, 'Bedwas', None, None, 'wl', 'Wales', 51.5924, -3.1985, 'Europe', 67.0, '', 'Caerphilly'),
#  (350296, 'Bedworth', None, None, 'wm', 'West Midlands', 52.481, -1.4674, 'Europe', 100.0, '', 'Warwickshire'),
#  (350297, 'Beech Lane', None, None, 'wm', 'West Midlands', 52.4721, -1.9706, 'Europe', 188.0, '', 'West Midlands Conurbation'),
#  (354612, 'Beer (Beach)', None, None, 'sw', 'South West', 50.6964, -3.0903, 'Europe', 0.0, '', 'Devon'),
#  (350298, 'Beer Youth Hostel', None, None, 'sw', 'South West', 50.7012, -3.1005, 'Europe', 59.0, '', 'Devon'),
#  (350299, 'Beeston (Nottinghamshire)', None, None, 'em', 'East Midlands', 52.9236, -1.2109, 'Europe', 29.0, '', 'Nottinghamshire'),
#  (350300, 'Beeston (West Yorkshire)', None, None, 'yh', 'Yorkshire and the Humber', 53.7738, -1.5636, 'Europe', 73.0, '', 'West Yorkshire'),
#  (350301, 'Beetley', None, None, 'ee', 'East of England', 52.7186, 0.9172, 'Europe', 40.0, '', 'Norfolk'),
#  (350302, 'Beighton', None, None, 'yh', 'Yorkshire and the Humber', 53.3485, -1.3357, 'Europe', 46.0, '', 'South Yorkshire'),
#  (350303, 'Beinn A  Chaorainn (Aberdeenshire)', None, None, 'gr', 'Grampian', 57.0959, -3.5755, 'Europe', 1082.0, 'Cairngorms National Park', 'Moray'),
#  (350304, 'Beinn A  Chaorainn (Highland)', None, None, 'he', 'Highlands and Eilean Siar', 56.9255, -4.6546, 'Europe', 1050.0, '', 'Highland'),
#  (350305, 'Beinn A  Chlachair', None, None, 'he', 'Highlands and Eilean Siar', 56.8683, -4.5081, 'Europe', 1087.0, '', 'Highland'),
#  (350306, 'Beinn A  Chlaidheimh', None, None, 'he', 'Highlands and Eilean Siar', 57.7464, -5.2592, 'Europe', 914.0, '', 'Highland'),
#  (350307, 'Beinn A  Chleibh', None, None, 'st', 'Strathclyde', 56.3907, -4.832, 'Europe', 917.0, '', 'Stirling'),
#  (350308, 'Beinn A  Chochuil', None, None, 'st', 'Strathclyde', 56.4478, -5.0666, 'Europe', 980.0, '', 'Argyll and Bute'),
#  (350309, 'Beinn A  Chreachain', None, None, 'ta', 'Central Tayside and Fife', 56.5563, -4.6451, 'Europe', 1081.0, '', 'Perth and Kinross'),
#  (350310, 'Beinn A  Chroin', None, None, 'ta', 'Central Tayside and Fife', 56.3304, -4.6039, 'Europe', 940.0, 'Loch Lomond and the Trossachs National Park', 'Stirling'),
#  (371344, 'Beinn A  Chruinnich', None, None, 'gr', 'Grampian', 57.203, -3.2632, 'Europe', 778.0, 'Cairngorms National Park', 'Moray'),
#  (350311, 'Beinn Achaladair', None, None, 'st', 'Strathclyde', 56.5496, -4.6897, 'Europe', 1038.0, '', 'Perth and Kinross'),
#  (350312, 'Beinn An Dothaidh', None, None, 'st', 'Strathclyde', 56.5286, -4.714, 'Europe', 1002.0, '', 'Argyll and Bute'),
#  (371345, 'Beinn An Oir', None, None, 'st', 'Strathclyde', 55.9025, -6.0031, 'Europe', 785.0, '', 'Argyll and Bute'),
#  (350313, 'Beinn Bheoil', None, None, 'he', 'Highlands and Eilean Siar', 56.8137, -4.4284, 'Europe', 1019.0, '', 'Highland'),
#  (350314, 'Beinn Bhreac', None, None, 'gr', 'Grampian', 57.0573, -3.5561, 'Europe', 931.0, 'Cairngorms National Park', 'Aberdeenshire'),
# ...
#  (371379, 'Calf Top', None, None, 'nw', 'North West', 54.265, -2.5152, 'Europe', 610.0, 'Yorkshire Dales National Park', 'Cumbria'),
#  (350721, 'Callakille', None, None, 'he', 'Highlands and Eilean Siar', 57.5219, -5.8543, 'Europe', 22.0, '', 'Highland'),
#  (350722, 'Callander', None, None, 'ta', 'Central Tayside and Fife', 56.2451, -4.2103, 'Europe', 78.0, 'Loch Lomond and the Trossachs National Park', 'Stirling'),
#  (350723, 'Callington', None, None, 'sw', 'South West', 50.5018, -4.3146, 'Europe', 156.0, '', 'Cornwall'),
#  (350724, 'Calne', None, None, 'sw', 'South West', 51.4389, -2.0025, 'Europe', 71.0, '', 'Wiltshire'),
#  (350727, 'Camblesforth', None, None, 'yh', 'Yorkshire and the Humber', 53.73, -1.0171, 'Europe', 6.0, '', 'North Yorkshire'),
#  (350728, 'Cambo Estate', None, None, 'ta', 'Central Tayside and Fife', 56.2952, -2.6531, 'Europe', 28.0, '', 'Fife'),
#  (3808, 'Camborne', None, None, 'sw', 'South West', 50.218, -5.33, 'Europe', 87.0, '', 'Cornwall'),
#  (350729, 'Camborne', None, None, 'sw', 'South West', 50.2122, -5.2937, 'Europe', 103.0, '', 'Cornwall'),
#  (310042, 'Cambridge', None, None, 'ee', 'East of England', 52.2075, 0.124, 'Europe', 7.0, '', 'Cambridgeshire'),
#  (99123, 'Cambridge  Niab', None, None, 'ee', 'East of England', 52.245, 0.103, 'Europe', 26.0, '', 'Cambridgeshire'),
#  (350730, 'Cambridge City Airport', None, None, 'ee', 'East of England', 52.2054, 0.1765, 'Europe', 11.0, '', 'Cambridgeshire'),
#  (350731, 'Cambridge University Botanic Gardens', None, None, 'ee', 'East of England', 52.1937, 0.1268, 'Europe', 11.0, '', 'Cambridgeshire'),
#  (350732, 'Cambridge Youth Hostel', None, None, 'ee', 'East of England', 52.1994, 0.1358, 'Europe', 14.0, '', 'Cambridgeshire'),
#  (350733, 'Cambuslang', None, None, 'st', 'Strathclyde', 55.821, -4.1636, 'Europe', 20.0, '', 'South Lanarkshire'),
#  (350735, 'Camelford', None, None, 'sw', 'South West', 50.6216, -4.6812, 'Europe', 219.0, '', 'Cornwall'),
#  (350736, 'Camelot Theme Park (Charnock Richard)', None, None, 'nw', 'North West', 53.6424, -2.7033, 'Europe', 44.0, '', 'Lancashire'),
#  (350737, 'Camp Town', None, None, 'yh', 'Yorkshire and the Humber', 53.8516, -1.5531, 'Europe', 136.0, '', 'West Yorkshire'),
#  (310184, 'Campbeltown', None, None, 'st', 'Strathclyde', 55.4241, -5.6042, 'Europe', 5.0, '', 'Argyll and Bute'),
#  (350738, 'Campbeltown Airport', None, None, 'st', 'Strathclyde', 55.4445, -5.6957, 'Europe', 14.0, '', 'Argyll and Bute'),
#  (350739, 'Camperdown', None, None, 'ne', 'North East England', 55.0425, -1.5758, 'Europe', 67.0, '', 'North Tyneside'),
#  (350740, 'Camusrory', None, None, 'he', 'Highlands and Eilean Siar', 57.0029, -5.53, 'Europe', 4.0, '', 'Highland'),
#  (350741, 'Canford Heath', None, None, 'sw', 'South West', 50.7488, -1.9721, 'Europe', 10.0, '', 'Poole'),
#  (350742, 'Canklow', None, None, 'yh', 'Yorkshire and the Humber', 53.4109, -1.3582, 'Europe', 42.0, '', 'South Yorkshire'),
#  (350743, 'Canley', None, None, 'wm', 'West Midlands', 52.3872, -1.5454, 'Europe', 92.0, '', 'West Midlands Conurbation'),
#  (350744, 'Cannich Youth Hostel', None, None, 'he', 'Highlands and Eilean Siar', 57.3423, -4.7607, 'Europe', 58.0, '', 'Highland'),
#  (301168, 'Cannington', None, None, 'sw', 'South West', 51.153, -3.065, 'Europe', 11.0, '', 'Somerset'),
#  (324170, 'Cannock', None, None, 'wm', 'West Midlands', 52.6868, -2.025, 'Europe', 137.0, '', 'Staffordshire'),
#  (350745, 'Canon Pyon', None, None, 'wm', 'West Midlands', 52.1384, -2.7896, 'Europe', 93.0, '', 'Herefordshire'),
#  (350746, 'Canons Ashby House', None, None, 'em', 'East Midlands', 52.1539, -1.1595, 'Europe', 160.0, '', 'Northamptonshire'),
#  (350748, 'Canvey Island', None, None, 'ee', 'East of England', 51.5166, 0.5801, 'Europe', 2.0, '', 'Essex'),
#  (350749, 'Caol Raineach', None, None, 'he', 'Highlands and Eilean Siar', 58.5477, -4.3325, 'Europe', None, '', 'Highland'),
#  (3305, 'Capel Curig Saws', None, None, 'wl', 'Wales', 53.093, -3.941, 'Europe', 216.0, 'Snowdonia National Park', 'Conwy'),
#  (350751, 'Capel Curig Youth Hostel', None, None, 'wl', 'Wales', 53.1059, -3.9012, 'Europe', 233.0, 'Snowdonia National Park', 'Conwy'),
#  (371380, 'Capel Fell', None, None, 'dg', 'Dumfries Galloway Lothian and Borders', 55.349, -3.3185, 'Europe', 678.0, '', 'Scottish Borders'),
#  (350753, 'Capel-Y-Ffin Youth Hostel', None, None, 'wl', 'Wales', 51.9847, -3.0923, 'Europe', 535.0, 'Brecon Beacons National Park', 'Powys'),
#  (350754, 'Capesthorne Hall', None, None, 'nw', 'North West', 53.2538, -2.2362, 'Europe', 94.0, '', 'Cheshire East'),
#  (354545, 'Carbis Bay Beach (Station) (Beach)', None, None, 'sw', 'South West', 50.1984, -5.4624, 'Europe', 0.0, '', 'Cornwall'),
#  (350755, 'Carbisdale Castle Youth Hostel', None, None, 'he', 'Highlands and Eilean Siar', 57.9254, -4.4078, 'Europe', 50.0, '', 'Highland'),
#  (350756, 'Carbisdale Trails', None, None, 'he', 'Highlands and Eilean Siar', 57.9227, -4.4242, 'Europe', 106.0, '', 'Highland'),
#  (350757, 'Carbrook', None, None, 'yh', 'Yorkshire and the Humber', 53.4054, -1.4204, 'Europe', 34.0, '', 'South Yorkshire'),
#  (350758, 'Cardiff', None, None, 'wl', 'Wales', 51.4812, -3.1778, 'Europe', 11.0, '', 'Cardiff'),
#  (350759, 'Cardiff City F.C.', None, None, 'wl', 'Wales', 51.4724, -3.2018, 'Europe', 9.0, '', 'Cardiff'),
#  (350760, 'Cardiff International Airport', None, None, 'wl', 'Wales', 51.3973, -3.3489, 'Europe', 66.0, '', 'Vale of Glamorgan'),
#  (350762, 'Cardiff Ski Centre', None, None, 'wl', 'Wales', 51.4925, -3.2378, 'Europe', 35.0, '', 'Cardiff'),
#  (350763, 'Cardiff Youth Hostel', None, None, 'wl', 'Wales', 51.5038, -3.1783, 'Europe', 20.0, '', 'Cardiff'),
#  (371381, 'Cardiff, Bute Park', None, None, 'wl', 'Wales', 51.4878, -3.1873, 'Europe', 9.0, '', 'Cardiff'),
#  (350764, 'Cardigan', None, None, 'wl', 'Wales', 52.0834, -4.6597, 'Europe', 10.0, '', 'Ceredigion'),
#  (3823, 'Cardinham', None, None, 'sw', 'South West', 50.502, -4.667, 'Europe', 200.0, '', 'Cornwall'),
#  (350765, 'Cardonald', None, None, 'st', 'Strathclyde', 55.8476, -4.3561, 'Europe', 20.0, '', 'Glasgow'),
#  (354860, 'Carew Castle And Tidal Mill', None, None, 'wl', 'Wales', 51.6985, -4.8305, 'Europe', 2.0, 'Pembrokeshire Coast National Park', 'Pembrokeshire'),
#  (3220, 'Carlisle', None, None, 'nw', 'North West', 54.933, -2.963, 'Europe', 28.0, '', 'Cumbria'),
#  (350766, 'Carlisle', None, None, 'nw', 'North West', 54.8924, -2.9315, 'Europe', 21.0, '', 'Cumbria'),
#  (14, 'Carlisle Airport', None, None, 'nw', 'North West', 54.9375, -2.8092, 'Europe', 50.0, '', 'Cumbria'),
#  (350767, 'Carlisle Park (Morpeth)', None, None, 'ne', 'North East England', 55.1631, -1.6889, 'Europe', 50.0, '', 'Northumberland'),
#  (350768, 'Carlisle Racecourse', None, None, 'nw', 'North West', 54.8634, -2.9324, 'Europe', 46.0, '', 'Cumbria'),
#  (350769, 'Carlisle Snowsports Club', None, None, 'nw', 'North West', 54.8978, -2.9445, 'Europe', 10.0, '', 'Cumbria'),
#  (350770, 'Carlton (Nottinghamshire)', None, None, 'em', 'East Midlands', 52.9663, -1.0818, 'Europe', 29.0, '', 'Nottinghamshire'),
#  (350771, 'Carlton (South Yorkshire)', None, None, 'yh', 'Yorkshire and the Humber', 53.5873, -1.4476, 'Europe', 65.0, '', 'South Yorkshire'),
#  (350772, 'Carluke', None, None, 'st', 'Strathclyde', 55.7354, -3.8352, 'Europe', 200.0, '', 'South Lanarkshire'),
#  (324079, 'Carmarthen', None, None, 'wl', 'Wales', 51.8571, -4.3153, 'Europe', 26.0, '', 'Carmarthenshire'),
#  (350773, 'Carmyle', None, None, 'st', 'Strathclyde', 55.8315, -4.155, 'Europe', 22.0, '', 'Glasgow'),
#  (350774, 'Carn A  Chlamain', None, None, 'ta', 'Central Tayside and Fife', 56.8668, -3.7812, 'Europe', 963.0, '', 'Perth and Kinross'),
#  (350775, 'Carn A  Coire Bhoidheach', None, None, 'gr', 'Grampian', 56.9457, -3.2704, 'Europe', 1110.0, 'Cairngorms National Park', 'Aberdeenshire'),
#  (350776, 'Carn A  Gheoidh', None, None, 'gr', 'Grampian', 56.8729, -3.4658, 'Europe', 975.0, 'Cairngorms National Park', 'Perth and Kinross'),
#  (350777, 'Carn A  Mhaim', None, None, 'gr', 'Grampian', 57.0364, -3.6533, 'Europe', 1037.0, 'Cairngorms National Park', 'Aberdeenshire'),
#  (350778, 'Carn An Fhidhleir', None, None, 'ta', 'Central Tayside and Fife', 56.9384, -3.8009, 'Europe', 994.0, '', 'Highland'),
#  (350779, 'Carn An Righ', None, None, 'ta', 'Central Tayside and Fife', 56.8779, -3.5866, 'Europe', 1029.0, '', 'Perth and Kinross'),
#  (350780, 'Carn An T-Sagairt Mor', None, None, 'gr', 'Grampian', 56.9433, -3.3013, 'Europe', 1047.0, 'Cairngorms National Park', 'Aberdeenshire'),
#  (350781, 'Carn An Tuirc', None, None, 'gr', 'Grampian', 56.9094, -3.3592, 'Europe', 1019.0, 'Cairngorms National Park', 'Aberdeenshire'),
#  (350782, 'Carn Aosda', None, None, 'gr', 'Grampian', 56.8963, -3.4259, 'Europe', 917.0, 'Cairngorms National Park', 'Aberdeenshire'),
#  (350783, 'Carn Bhac', None, None, 'gr', 'Grampian', 56.9296, -3.5595, 'Europe', 946.0, 'Cairngorms National Park', 'Aberdeenshire'),
#  (350784, 'Carn Dearg (1034m)', None, None, 'he', 'Highlands and Eilean Siar', 56.8533, -4.4549, 'Europe', 1034.0, '', 'Highland'),
#  (350785, 'Carn Dearg (939m)', None, None, 'he', 'Highlands and Eilean Siar', 56.7625, -4.5873, 'Europe', 939.0, '', 'Highland'),
#  (350786, 'Carn Dearg (945m)', None, None, 'he', 'Highlands and Eilean Siar', 57.0984, -4.2608, 'Europe', 945.0, 'Cairngorms National Park', 'Highland'),
#  (350787, 'Carn Dearg Youth Hostel', None, None, 'he', 'Highlands and Eilean Siar', 57.7332, -5.7578, 'Europe', 38.0, '', 'Highland'),
#  (371382, 'Carn Ealasaid', None, None, 'gr', 'Grampian', 57.1905, -3.278, 'Europe', 792.0, 'Cairngorms National Park', 'Aberdeenshire'),
#  (350788, 'Carn Eige', None, None, 'he', 'Highlands and Eilean Siar', 57.2881, -5.1143, 'Europe', 1183.0, '', 'Highland'),
#  (350789, 'Carn Ghluasaid', None, None, 'he', 'Highlands and Eilean Siar', 57.1655, -5.0661, 'Europe', 957.0, '', 'Highland'),
#  (350790, 'Carn Gorm', None, None, 'ta', 'Central Tayside and Fife', 56.6221, -4.2223, 'Europe', 1029.0, '', 'Perth and Kinross'),
#  (371383, 'Carn Liath', None, None, 'gr', 'Grampian', 57.2282, -3.237, 'Europe', 792.0, 'Cairngorms National Park', 'Aberdeenshire'),
#  (350791, 'Carn Liath (Highland)', None, None, 'he', 'Highlands and Eilean Siar', 56.9794, -4.5111, 'Europe', 1006.0, '', 'Highland'),
#  (350792, 'Carn Liath (Perth & Kinross)', None, None, 'ta', 'Central Tayside and Fife', 56.8073, -3.742, 'Europe', 975.0, '', 'Perth and Kinross'),
#  (350794, 'Carn Mairg', None, None, 'ta', 'Central Tayside and Fife', 56.6348, -4.1442, 'Europe', 1042.0, '', 'Perth and Kinross'),
#  (371384, 'Carn Mor', None, None, 'gr', 'Grampian', 57.2501, -3.217, 'Europe', 804.0, 'Cairngorms National Park', 'Aberdeenshire'),
#  (350793, 'Carn Mor Dearg', None, None, 'he', 'Highlands and Eilean Siar', 56.8056, -4.9838, 'Europe', 1223.0, '', 'Highland'),
#  (350795, 'Carn Na Caim', None, None, 'he', 'Highlands and Eilean Siar', 56.9107, -4.1761, 'Europe', 941.0, 'Cairngorms National Park', 'Perth and Kinross'),
#  (350796, 'Carn Nan Gabhar', None, None, 'ta', 'Central Tayside and Fife', 56.8403, -3.6862, 'Europe', 1121.0, '', 'Perth and Kinross'),
#  (350797, 'Carn Nan Gobhar (Glen Strathfarrar)', None, None, 'he', 'Highlands and Eilean Siar', 57.4529, -4.8715, 'Europe', 992.0, '', 'Highland'),
#  (350798, 'Carn Nan Gobhar (Loch Mullardoch)', None, None, 'he', 'Highlands and Eilean Siar', 57.3648, -5.0223, 'Europe', 992.0, '', 'Highland'),
#  (350799, 'Carn Sgulain', None, None, 'he', 'Highlands and Eilean Siar', 57.125, -4.1747, 'Europe', 920.0, 'Cairngorms National Park', 'Highland'),
#  (371385, 'Carnanelly', None, None, 'ni', 'Northern Ireland', 54.7726, -6.9498, 'Europe', 564.0, '', 'County Tyrone'),
#  (371387, 'Carnedd Dafydd', None, None, 'wl', 'Wales', 53.1475, -3.9996, 'Europe', 1044.0, 'Snowdonia National Park', 'Conwy'),
#  (371386, 'Carnedd Gwenllian', None, None, 'wl', 'Wales', 53.1827, -3.9647, 'Europe', 926.0, 'Snowdonia National Park', 'Conwy'),
#  (371388, 'Carnedd Llywelyn', None, None, 'wl', 'Wales', 53.1599, -3.9691, 'Europe', 1064.0, 'Snowdonia National Park', 'Conwy'),
#  (371389, 'Carnedd Moel-Siabod', None, None, 'wl', 'Wales', 53.0729, -3.9328, 'Europe', 872.0, 'Snowdonia National Park', 'Conwy'),
#  (350800, 'Carnforth', None, None, 'nw', 'North West', 54.1272, -2.7667, 'Europe', 22.0, '', 'Lancashire'),
#  (350801, 'Carnoustie', None, None, 'ta', 'Central Tayside and Fife', 56.5026, -2.7017, 'Europe', 9.0, '', 'Angus'),
#  (354451, 'Carnoustie (Beach)', None, None, 'gr', 'Grampian', 56.5005, -2.7019, 'Europe', 0.0, '', 'Angus'),
#  (350802, 'Carnoustie Golf Links', None, None, 'ta', 'Central Tayside and Fife', 56.4923, -2.7238, 'Europe', 3.0, '', 'Angus'),
#  (371390, 'Carntogher', None, None, 'ni', 'Northern Ireland', 54.8962, -6.7602, 'Europe', 464.0, '', 'County Londonderry'),
#  (350803, 'Carntyne', None, None, 'st', 'Strathclyde', 55.8609, -4.1966, 'Europe', 37.0, '', 'Glasgow'),
#  (350804, 'Carnwadric', None, None, 'st', 'Strathclyde', 55.8074, -4.3245, 'Europe', 28.0, '', 'East Renfrewshire'),
#  (350805, 'Carradale Garden', None, None, 'st', 'Strathclyde', 55.5838, -5.4807, 'Europe', 3.0, '', 'Argyll and Bute'),
#  (354899, 'Carreg Cennen', None, None, 'wl', 'Wales', 51.8543, -3.9356, 'Europe', 231.0, 'Brecon Beacons National Park', 'Carmarthenshire'),
#  (350806, 'Carrick-A-Rede Rope Bridge (Nt)', None, None, 'ni', 'Northern Ireland', 55.2387, -6.3329, 'Europe', 55.0, '', 'County Antrim'),
#  (350807, 'Carrickfergus', None, None, 'ni', 'Northern Ireland', 54.7134, -5.8117, 'Europe', 5.0, '', 'County Antrim'),
#  (350808, 'Carrington', None, None, 'em', 'East Midlands', 52.9753, -1.156, 'Europe', 67.0, '', 'Nottingham'),
#  (350809, 'Carrock Fell Youth Hostel', None, None, 'nw', 'North West', 54.7075, -2.9898, 'Europe', 217.0, 'Lake District National Park', 'Cumbria'),
#  (350810, 'Carron Valley Mountain Bike Trails', None, None, 'ta', 'Central Tayside and Fife', 56.0293, -4.0581, 'Europe', 224.0, '', 'North Lanarkshire'),
#  (350811, 'Carryduff', None, None, 'ni', 'Northern Ireland', 54.5192, -5.8875, 'Europe', 119.0, '', 'County Down'),
#  (354857, 'Carter Bar', None, None, 'dg', 'Dumfries Galloway Lothian and Borders', 55.3543, -2.4776, 'Europe', 406.0, 'Northumberland National Park', 'Scottish Borders'),
#  (350812, 'Cartmel Racecourse', None, None, 'nw', 'North West', 54.2024, -2.9587, 'Europe', 47.0, '', 'Cumbria'),
#  (99003, 'Cassley', None, None, 'he', 'Highlands and Eilean Siar', 58.167, -4.733, 'Europe', 99.0, '', 'Highland'),
#  (354909, 'Castell Henllys', None, None, 'wl', 'Wales', 52.0165, -4.7445, 'Europe', 52.0, 'Pembrokeshire Coast National Park', 'Pembrokeshire'),
#  (350813, 'Castle Archdale Country Park', None, None, 'ni', 'Northern Ireland', 54.4765, -7.7256, 'Europe', 68.0, '', 'County Fermanagh'),
#  (350814, 'Castle Ashby', None, None, 'em', 'East Midlands', 52.2258, -0.7353, 'Europe', 78.0, '', 'Northamptonshire'),
#  (350815, 'Castle Bromwich', None, None, 'wm', 'West Midlands', 52.5025, -1.7903, 'Europe', 104.0, '', 'West Midlands Conurbation'),
#  (350816, 'Castle Caldwell', None, None, 'ni', 'Northern Ireland', 54.4843, -7.9792, 'Europe', 54.0, '', 'County Fermanagh'),
#  (350817, 'Castle Cary', None, None, 'sw', 'South West', 51.0882, -2.5118, 'Europe', 89.0, '', 'Somerset'),
#  (350818, 'Castle Combe Motor Racing Circuit', None, None, 'sw', 'South West', 51.4874, -2.2058, 'Europe', 124.0, '', 'Wiltshire'),
#  (350819, 'Castle Coole (Nt)', None, None, 'ni', 'Northern Ireland', 54.3373, -7.6149, 'Europe', 53.0, '', 'County Fermanagh'),
#  (350820, 'Castle Douglas', None, None, 'dg', 'Dumfries Galloway Lothian and Borders', 54.9403, -3.9301, 'Europe', 51.0, '', 'Dumfries and Galloway'),
#  (350821, 'Castle Drogo', None, None, 'sw', 'South West', 50.6989, -3.8053, 'Europe', 254.0, 'Dartmoor National Park', 'Devon'),
#  (350822, 'Castle Hedingham Youth Hostel', None, None, 'ee', 'East of England', 51.9941, 0.6015, 'Europe', 60.0, '', 'Essex'),
#  (350823, 'Castle Howard', None, None, 'yh', 'Yorkshire and the Humber', 54.118, -0.9023, 'Europe', 73.0, '', 'North Yorkshire'),
#  ...]

# %% [markdown]
# ## Aggregations
# Some times we want to get **aggregated results** with respect to a particular field. To do  this we ca use the following syntax:
# ```sql
# SELECT field1, Agg_func(field) FROM Table
# GROUP BY Field
# ```
# Some aggregation functions can be (total count, minimum, maximum, average, standard deviation):
# ```sql
# COUNT(), MIN(), MAX(), AVG(), STD()
# ```
# Example: Obtain the min, max and average latitude by region

# %%
# %%sql
# SELECT Region,
# MIN(Latitude), MAX(Latitude), AVG(Latitude), MIN(Longitude), MAX(Longitude), AVG(Longitude)
# FROM cat_locations GROUP BY Region ORDER BY Region
# Out:
#  * sqlite:///weather.db
# Done.
# [(None, 51.5, 51.66, 51.58, 0.04, 0.13, 0.085),
#  ('', 51.799, 55.366, 53.332750000000004, -10.25, -7.333, -8.958499999999999),
#  ('dg', 54.7347, 56.0639, 55.57700701834862, -5.1239, -2.0895, -3.327039357798166),
#  ('ee', 51.4626, 53.0043, 52.1672879347826, -0.6591, 1.7553, 0.5955755163043479),
#  ('em', 52.027, 53.58, 52.942183851132675, -2.008, 0.355, -0.9601029126213589),
#  ('gr', 56.5005, 58.5974, 57.24074115384615, -3.7491, -1.7824, -2.8300918846153857),
#  ('he', 54.2469, 58.6321, 57.38218110539839, -8.5744, -1.0621, -5.077283084832905),
#  ('ne', 54.5044, 55.7702, 54.96097154929579, -2.5837, -0.863, -1.677218873239438),
#  ('ni', 54.063, 55.239, 54.61890180952383, -7.9792, -5.5317, -6.472643476190473),
#  ('nw', 53.0024, 55.05, 53.804646687797124, -4.7573, -1.9857, -2.6660667068145822),
#  ('os', 58.859, 60.749, 59.68981426229507, -3.3814, -0.7467, -2.0740595081967212),
#  ('se', 50.577, 52.1544, 51.2219089039039, -1.8166, 1.4464, -0.4008686021021018),
#  ('st', 55.1058, 56.6281, 55.87593788343556, -6.887, -3.5101, -4.738817484662579),
#  ('sw', 49.1772, 52.0877, 50.7895911810013, -6.3336, -1.6583, -3.312220836970474),
#  ('ta', 55.9961, 56.9384, 56.40524963157893, -4.773, -2.4646, -3.637772052631579),
#  ('wl', 51.3831, 53.4104, 52.27757070312499, -5.3048, -2.6725, -3.8914222070312503),
#  ('wm', 51.8547, 53.1866, 52.55005912162164, -3.0985, -1.2635, -2.0481902252252238),
#  ('yh', 53.3146, 54.5016, 53.81445102316605, -2.5065, 0.115, -1.4050860810810806)]

# %% [markdown]
# # Exercises
# MySQL can open multiple databases so we need to specify the name of the database (e.g. `DATABASE_NAME.TABLE_NAME`).
# But `SQLite` (the SQL database that we use in this notebook) opens only one database at a time and we don't use the name of the database. As an example the table `cat_regions` is:
# - **MySQL**: `weather_db.cat_regions`
# - **SQLite**: `cat_regions`

# %% [markdown]
# ## Exercise 1
# How many records are there in the table cat_locations with region description equal to Northern Ireland?
# ## Exercise 2
# Which region has the highest elevation in the cat_locations table and what is this elevation?
# ## Exercise 3
# What were the mean visibility, temperature, windspeed, and humidity on January 4th?
# ## Exercise 4
# What is the average temperature per `pressuretendency` type?
# ## Exercise 5
# How many records are there in the table `metoffice_dailyweatherdata` where `winddirection` is `null`? Why?
# ## Exercise 6
# What is the average humidity in table `metoffice_dailyweatherdata` where temperature is between 5 and 10 degrees?
# ## Exercise 7
# How many records are there in the table `cat_locations` where both postcode and country are NULL?

# %% [markdown]
# # Solutions

# %%
# %%sql
# -- EXERCISE 1
# SELECT count(*) FROM cat_locations WHERE region = 'ni';
# Out:
#  * sqlite:///weather.db
# Done.
# [(210,)]

# %%
# %%sql
# -- EXERCISE 2
# SELECT region, elevation FROM cat_locations ORDER BY elevation DESC LIMIT 5;
# -- LIMIT 5 prints only 5 but we only need the first one
# Out:
#  * sqlite:///weather.db
# Done.
# [('he', 1344.0),
#  ('gr', 1309.0),
#  ('he', 1296.0),
#  ('gr', 1291.0),
#  ('gr', 1258.0)]

# %%
# %%sql
# -- Exercise 3
# SELECT obs_date, AVG(visibility), AVG(temperature), AVG(windspeed), AVG(humidity)
# FROM metoffice_dailyweatherdata
# WHERE obs_date = '2020-01-04' GROUP BY obs_date;
# Out:
#  * sqlite:///weather.db
# Done.
# [('2020-01-04', 26725.96899224806, 6.011469534050176, 16.318840579710145, 85.06829710144923)]

# %%
# %%sql
# -- Exercise 4
# SELECT pressuretendency, AVG(temperature) FROM metoffice_dailyweatherdata
# GROUP BY pressuretendency;
# Out:
#  * sqlite:///weather.db
# Done.
# [('F', 7.231950067476386),
#  ('NULL', 3.215279878971255),
#  ('R', 6.449528023598823),
#  ('S', 7.447619047619048)]

# %%
# %%sql
# --Exercise 5
# SELECT count(*) FROM metoffice_dailyweatherdata WHERE winddirection IS NULL;
# Out:
#  * sqlite:///weather.db
# Done.
# [(0,)]

# %% [markdown]
# Looks like for Exercise 5 are no `NULL` entries. To verify this we will print few rows

# %%
# %%sql
# -- Exercise 5 continued
# select winddirection from metoffice_dailyweatherdata LIMIt 10;
# Out:
#  * sqlite:///weather.db
# Done.
# [('NULL',),
#  ('NULL',),
#  ('NULL',),
#  ('NULL',),
#  ('NULL',),
#  ('NULL',),
#  ('NULL',),
#  ('NULL',),
#  ('NULL',),
#  ('NULL',)]

# %% [markdown]
# We there are entries of the string "NULL" instead of the value `NULL`

# %%
# %%sql
# -- Exercise 5 continued
# SELECT count(*) FROM metoffice_dailyweatherdata WHERE winddirection = 'NULL';
# Out:
#  * sqlite:///weather.db
# Done.
# [(9857,)]

# %%
# %%sql
# -- Exercise 6
# SELECT AVG(humidity) FROM metoffice_dailyweatherdata
# WHERE temperature BETWEEN 5 and 10;
# Out:
#  * sqlite:///weather.db
# Done.
# [(86.41444931429352,)]

# %%
# %%sql
# -- Exercise 7
# SELECT count(*) FROM  cat_locations WHERE postcode IS NULL AND country IS NULL;
# Out:
#  * sqlite:///weather.db
# Done.
# [(5968,)]
